# %% [markdown]
# # Build Education Index

# %% [markdown]
# ## 1. Data Collection
#
# - Number of educational services: from educational dataset
#
# - Distance to centers: polygon or compute distances
#
# - Region density over number of places offered: Oferta inicial de plazas escolares de los estudios obligatorios
#
# - Ratio of students over teacher: Alumnos matriculados por enseñanza y unidades de centros docentes, Personal docente en centros públicos titularidad del Departamento de Educación, Conciertos educativos: unidad, alumnos, dotación de plantilla y gasto
#
# - Academic Performance:
#
# - School Dropout Rate:
#
# - School Status - Pulic, Private or Charter: from educational dataset
#
# - School Type Ponderation - School/Kindergarten, Library/Studying Room, Civic Center: from educational dataset
#
# - Standarized Characteristics: international, religious, etc - dataset?

# %% [markdown]
# ### Load Dataset with all Education Services

# %%
pip install pandas fuzzywuzzy[speedup]
# Out:
# Requirement already satisfied: pandas in /Users/mariatormo02/opt/anaconda3/lib/python3.9/site-packages (1.4.2)
# Requirement already satisfied: fuzzywuzzy[speedup] in /Users/mariatormo02/opt/anaconda3/lib/python3.9/site-packages (0.18.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/mariatormo02/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/mariatormo02/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in /Users/mariatormo02/opt/anaconda3/lib/python3.9/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: python-levenshtein>=0.12 in /Users/mariatormo02/opt/anaconda3/lib/python3.9/site-packages (from fuzzywuzzy[speedup]) (0.25.1)
# Requirement already satisfied: six>=1.5 in /Users/mariatormo02/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: Levenshtein==0.25.1 in /Users/mariatormo02/opt/anaconda3/lib/python3.9/site-packages (from python-levenshtein>=0.12->fuzzywuzzy[speedup]) (0.25.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.8.0 in /Users/mariatormo02/opt/anaconda3/lib/python3.9/site-packages (from Levenshtein==0.25.1->python-levenshtein>=0.12->fuzzywuzzy[speedup]) (3.9.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# IMPORTS
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
# Get rid of warnings
import warnings
warnings.filterwarnings("ignore")

# %%
import chardet

def detect_encoding(file_path):
    with open(file_path, 'rb') as f:
        result = chardet.detect(f.read())
    return result['encoding']

# Usage
#encoded = detect_encoding(file_name)
#print(encoded)

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# Dataset Files
cleaned_educ_file = "/Users/mariatormo02/Desktop/TFG-Code/2.1 Data Processing/cleaned_education.csv"

encoded = detect_encoding(cleaned_educ_file)
print(encoded)

# Read CSV
cleaned_educ_df = pd.read_csv(cleaned_educ_file, encoding='utf-8')
# Out:
# utf-8

# %%
display(cleaned_educ_df)
# Out:
#       Unnamed: 0                                               Name  \
# 0              0  Facultat d'Informació i Mitjans Audiovisuals - UB
# 1              1                                 Institut Fort Pius
# 2              2                       Escola Pia de Nostra Senyora
# 3              3                            Institut Salvador Seguí
# 4              4                            Escola de Música Kostka
# ...          ...                                                ...
# 1352        1475           Biblioteca Trinitat Vella - José Barbero
# 1353        1479                Biblioteca Poblenou - Manuel Arranz
# 1354        1480                      Biblioteca Ramon d'Alòs-Moner
# 1355        1483               Biblioteca Poble Sec - Francesc Boix
# 1356        1486              Biblioteca Collserola - Josep Miracle
#
#                    Road Name  Street Number  Neighborhood ID  \
# 0           Melcior de Palau          140.0               18
# 1              C Ausiàs Marc           78.0                5
# 2     Carrer de la Diputació          277.0                7
# 3                C Santander            7.0               73
# 4              Rier Can Toda           29.0               30
# ...                      ...            ...              ...
# 1352                     NaN            NaN               57
# 1353                     NaN            NaN               68
# 1354                     NaN            NaN               70
# 1355                     NaN            NaN               11
# 1356                     NaN            NaN               22
#
#                           Neighborhood Name  District ID        District Name  \
# 0                                     Sants            3       Sants-Montjuïc
# 1                             el Fort Pienc            2             Eixample
# 2                    la Dreta de l'Eixample            2             Eixample
# 3                       la Verneda i la Pau           10           Sant Martí
# 4                                  la Salut            6               Gràcia
# ...                                     ...          ...                  ...
# 1352                      la Trinitat Vella            9          Sant Andreu
# 1353                            el Poblenou           10           Sant Martí
# 1354                  el Besòs i el Maresme           10           Sant Martí
# 1355                           el Poble Sec            3       Sants-Montjuïc
# 1356  Vallvidrera, el Tibidabo i les Planes            5  Sarrià-Sant Gervasi
#
#       ZipCode           Service Type  geo_epgs_25831_x  geo_epgs_25831_y  \
# 0        8014             University     427989.387049      4.581443e+06
# 1        8013       Secondary School     431433.012280      4.582861e+06
# 2        8007  Secondary School & FP     430435.525044      4.582521e+06
# 3        8020                     FP     432882.376561      4.586038e+06
# 4        8024           Music School     429568.000936      4.585099e+06
# ...       ...                    ...               ...               ...
# 1352        0   Library & Study Room               NaN               NaN
# 1353        0   Library & Study Room               NaN               NaN
# 1354        0   Library & Study Room               NaN               NaN
# 1355        0   Library & Study Room               NaN               NaN
# 1356        0   Library & Study Room               NaN               NaN
#
#        Latitude  Longitude   Simple Service Type
# 0     41.381286   2.138788            University
# 1     41.394359   2.179807           High School
# 2     41.391216   2.167916           High School
# 3     41.423094   2.196790                    FP
# 4     41.414357   2.157240          Music School
# ...         ...        ...                   ...
# 1352  41.449283   2.190749  Library & Study Room
# 1353  41.401373   2.204526  Library & Study Room
# 1354  41.416309   2.211483  Library & Study Room
# 1355  41.373922   2.164025  Library & Study Room
# 1356  41.415359   2.102529  Library & Study Room
#
# [1357 rows x 15 columns]

# %%
# Drop Unnecessary columns
cols_to_drop = ['Unnamed: 0', 'Road Name', 'Street Number', 'geo_epgs_25831_x', 'geo_epgs_25831_y']

cleaned_educ_df.drop(columns=cols_to_drop, inplace=True)
cleaned_educ_df.head(10)
# Out:
#                                                 Name  Neighborhood ID  \
# 0  Facultat d'Informació i Mitjans Audiovisuals - UB               18
# 1                                 Institut Fort Pius                5
# 2                       Escola Pia de Nostra Senyora                7
# 3                            Institut Salvador Seguí               73
# 4                            Escola de Música Kostka               30
# 5               Centre Educatiu Sagrat Cor-Diputació                7
# 6              Centre Educatiu Sant Francesc d'Assís               10
# 7                         Centre Educatiu Sant Josep               31
# 8                        Escola Molí de Finestrelles               60
# 9                                       Escola Casas               65
#
#         Neighborhood Name  District ID   District Name  ZipCode  \
# 0                   Sants            3  Sants-Montjuïc     8014
# 1           el Fort Pienc            2        Eixample     8013
# 2  la Dreta de l'Eixample            2        Eixample     8007
# 3     la Verneda i la Pau           10      Sant Martí     8020
# 4                la Salut            6          Gràcia     8024
# 5  la Dreta de l'Eixample            2        Eixample     8009
# 6             Sant Antoni            2        Eixample     8007
# 7       la Vila de Gràcia            6          Gràcia     8012
# 8             Sant Andreu            9     Sant Andreu     8030
# 9                 el Clot           10      Sant Martí     8018
#
#                                Service Type   Latitude  Longitude  \
# 0                                University  41.381286   2.138788
# 1                          Secondary School  41.394359   2.179807
# 2                     Secondary School & FP  41.391216   2.167916
# 3                                        FP  41.423094   2.196790
# 4                              Music School  41.414357   2.157240
# 5  Kindergarten, Primary & Secondary School  41.395298   2.174295
# 6             Kindergarten & Primary School  41.385181   2.163444
# 7  Kindergarten, Primary & Secondary School  41.402367   2.155367
# 8             Kindergarten & Primary School  41.438824   2.189559
# 9             Kindergarten & Primary School  41.408477   2.192800
#
#                   Simple Service Type
# 0                          University
# 1                         High School
# 2                         High School
# 3                                  FP
# 4                        Music School
# 5  General School (with kindergarten)
# 6       Kindergarten & Primary School
# 7  General School (with kindergarten)
# 8       Kindergarten & Primary School
# 9       Kindergarten & Primary School

# %%
# Move Simple Service Type column order
column_to_move = 'Simple Service Type'
new_position = 7 # start pos at 0

# Pop the col and insert at new position
column_pop = cleaned_educ_df.pop(column_to_move)
cleaned_educ_df.insert(new_position, column_to_move, column_pop)

cleaned_educ_df.head(10)
# Out:
#                                                 Name  Neighborhood ID  \
# 0  Facultat d'Informació i Mitjans Audiovisuals - UB               18
# 1                                 Institut Fort Pius                5
# 2                       Escola Pia de Nostra Senyora                7
# 3                            Institut Salvador Seguí               73
# 4                            Escola de Música Kostka               30
# 5               Centre Educatiu Sagrat Cor-Diputació                7
# 6              Centre Educatiu Sant Francesc d'Assís               10
# 7                         Centre Educatiu Sant Josep               31
# 8                        Escola Molí de Finestrelles               60
# 9                                       Escola Casas               65
#
#         Neighborhood Name  District ID   District Name  ZipCode  \
# 0                   Sants            3  Sants-Montjuïc     8014
# 1           el Fort Pienc            2        Eixample     8013
# 2  la Dreta de l'Eixample            2        Eixample     8007
# 3     la Verneda i la Pau           10      Sant Martí     8020
# 4                la Salut            6          Gràcia     8024
# 5  la Dreta de l'Eixample            2        Eixample     8009
# 6             Sant Antoni            2        Eixample     8007
# 7       la Vila de Gràcia            6          Gràcia     8012
# 8             Sant Andreu            9     Sant Andreu     8030
# 9                 el Clot           10      Sant Martí     8018
#
#                                Service Type  \
# 0                                University
# 1                          Secondary School
# 2                     Secondary School & FP
# 3                                        FP
# 4                              Music School
# 5  Kindergarten, Primary & Secondary School
# 6             Kindergarten & Primary School
# 7  Kindergarten, Primary & Secondary School
# 8             Kindergarten & Primary School
# 9             Kindergarten & Primary School
#
#                   Simple Service Type   Latitude  Longitude
# 0                          University  41.381286   2.138788
# 1                         High School  41.394359   2.179807
# 2                         High School  41.391216   2.167916
# 3                                  FP  41.423094   2.196790
# 4                        Music School  41.414357   2.157240
# 5  General School (with kindergarten)  41.395298   2.174295
# 6       Kindergarten & Primary School  41.385181   2.163444
# 7  General School (with kindergarten)  41.402367   2.155367
# 8       Kindergarten & Primary School  41.438824   2.189559
# 9       Kindergarten & Primary School  41.408477   2.192800

# %% [markdown]
# ### 1.1 Create Dataframe for neighborhoods

# %%
print("Array of Neighborhood IDs:", cleaned_educ_df['Neighborhood ID'].unique())
print("Min Neighborhood ID:", min(cleaned_educ_df['Neighborhood ID'].unique()))
print("Min Neighborhood ID:", max(cleaned_educ_df['Neighborhood ID'].unique()))
# Out:
# Array of Neighborhood IDs: [18  5  7 73 30 10 31 60 65 13 71 24  1 35  9 45 72 68  8 22  4 23 63 52
#   6 61 25 20 21 53 41 59 67 15 26 11 39 33 37 70 17  3 19 62 40 36 14 28
#  51 27 43 48 66 64 44 12  2 16 47 46 55 58 29 50 34 32 56 42 57 69 49 54
#   0 38]
# Min Neighborhood ID: 0
# Min Neighborhood ID: 73

# %%
# Zone IDs
neighborhood_ids = sorted(cleaned_educ_df['Neighborhood ID'].unique())

# Column Names
column_names = {
    0: 'Neighborhood Name',
    1: 'District Name Associated',
    2: 'Number of Services',
    3: 'Distances',
    4: 'Density over Places Ratio',
    5: 'Avg. Students per Teacher Ratio',
    6: 'School Status',
    7: 'Centers Type',
    8: 'Centers Simple Type',
    9: 'Centers Characteristics',
    10: 'Population with Low Studies (%)',
    11: 'Total Number of Students',
    12: 'Primary School in people older than 15 (%)',
    13: 'Secondary School in people older than 15 (%)',
    14: 'Middle Studies in people older than 15 (%)',
    15: 'Higher Studies in people older than 15 (%)',
    16: 'No education or Incomplete Primary School in people older than 15 (%)',
    17: 'Young Population without Post-Compulsory Education (%)',
    18: 'Abscence Rate in 4th Grade (%)',
    19: 'Graduation Rate in 4th Grade (%)',
    20: 'Territorial Socioeconomic Index (IST)',
    21: 'Avg. Gini Index (%)',
    22: 'Population Density (hab/ha)',
    23: 'Net Population Density (hab/residential ha)',
}

# Create empty dataframe with IDs as index
zones_educ_df = pd.DataFrame(index=neighborhood_ids, columns=column_names.values())

# Rename Index
zones_educ_df.index.name = 'Neighborhood ID'

display(zones_educ_df)
# Out:
#                 Neighborhood Name District Name Associated Number of Services  \
# Neighborhood ID
# 0                             NaN                      NaN                NaN
# 1                             NaN                      NaN                NaN
# 2                             NaN                      NaN                NaN
# 3                             NaN                      NaN                NaN
# 4                             NaN                      NaN                NaN
# ...                           ...                      ...                ...
# 69                            NaN                      NaN                NaN
# 70                            NaN                      NaN                NaN
# 71                            NaN                      NaN                NaN
# 72                            NaN                      NaN                NaN
# 73                            NaN                      NaN                NaN
#
#                 Distances Density over Places Ratio  \
# Neighborhood ID
# 0                     NaN                       NaN
# 1                     NaN                       NaN
# 2                     NaN                       NaN
# 3                     NaN                       NaN
# 4                     NaN                       NaN
# ...                   ...                       ...
# 69                    NaN                       NaN
# 70                    NaN                       NaN
# 71                    NaN                       NaN
# 72                    NaN                       NaN
# 73                    NaN                       NaN
#
#                 Avg. Students per Teacher Ratio School Status Centers Type  \
# Neighborhood ID
# 0                                           NaN           NaN          NaN
# 1                                           NaN           NaN          NaN
# 2                                           NaN           NaN          NaN
# 3                                           NaN           NaN          NaN
# 4                                           NaN           NaN          NaN
# ...                                         ...           ...          ...
# 69                                          NaN           NaN          NaN
# 70                                          NaN           NaN          NaN
# 71                                          NaN           NaN          NaN
# 72                                          NaN           NaN          NaN
# 73                                          NaN           NaN          NaN
#
#                 Centers Simple Type Centers Characteristics  ...  \
# Neighborhood ID                                              ...
# 0                               NaN                     NaN  ...
# 1                               NaN                     NaN  ...
# 2                               NaN                     NaN  ...
# 3                               NaN                     NaN  ...
# 4                               NaN                     NaN  ...
# ...                             ...                     ...  ...
# 69                              NaN                     NaN  ...
# 70                              NaN                     NaN  ...
# 71                              NaN                     NaN  ...
# 72                              NaN                     NaN  ...
# 73                              NaN                     NaN  ...
#
#                 Middle Studies in people older than 15 (%)  \
# Neighborhood ID
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 69                                                     NaN
# 70                                                     NaN
# 71                                                     NaN
# 72                                                     NaN
# 73                                                     NaN
#
#                 Higher Studies in people older than 15 (%)  \
# Neighborhood ID
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 69                                                     NaN
# 70                                                     NaN
# 71                                                     NaN
# 72                                                     NaN
# 73                                                     NaN
#
#                 No education or Incomplete Primary School in people older than 15 (%)  \
# Neighborhood ID
# 0                                                              NaN
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
# ...                                                            ...
# 69                                                             NaN
# 70                                                             NaN
# 71                                                             NaN
# 72                                                             NaN
# 73                                                             NaN
#
#                 Young Population without Post-Compulsory Education (%)  \
# Neighborhood ID
# 0                                                              NaN
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
# ...                                                            ...
# 69                                                             NaN
# 70                                                             NaN
# 71                                                             NaN
# 72                                                             NaN
# 73                                                             NaN
#
#                 Abscence Rate in 4th Grade (%)  \
# Neighborhood ID
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 69                                         NaN
# 70                                         NaN
# 71                                         NaN
# 72                                         NaN
# 73                                         NaN
#
#                 Graduation Rate in 4th Grade (%)  \
# Neighborhood ID
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 69                                           NaN
# 70                                           NaN
# 71                                           NaN
# 72                                           NaN
# 73                                           NaN
#
#                 Territorial Socioeconomic Index (IST) Avg. Gini Index (%)  \
# Neighborhood ID
# 0                                                 NaN                 NaN
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
# 3                                                 NaN                 NaN
# 4                                                 NaN                 NaN
# ...                                               ...                 ...
# 69                                                NaN                 NaN
# 70                                                NaN                 NaN
# 71                                                NaN                 NaN
# 72                                                NaN                 NaN
# 73                                                NaN                 NaN
#
#                 Population Density (hab/ha)  \
# Neighborhood ID
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 69                                      NaN
# 70                                      NaN
# 71                                      NaN
# 72                                      NaN
# 73                                      NaN
#
#                 Net Population Density (hab/residential ha)
# Neighborhood ID
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 69                                                      NaN
# 70                                                      NaN
# 71                                                      NaN
# 72                                                      NaN
# 73                                                      NaN
#
# [74 rows x 24 columns]

# %% [markdown]
# ### 1.2. Number of educational services

# %%
# Count number of rows for which Neighborhood ID holds a value
neighborhood_counts = cleaned_educ_df['Neighborhood ID'].value_counts().sort_index()
#print(neighborhood_counts)
zones_educ_df['Number of Services'] = neighborhood_counts
zones_educ_df.head(5)
# Out:
#                 Neighborhood Name District Name Associated  \
# Neighborhood ID
# 0                             NaN                      NaN
# 1                             NaN                      NaN
# 2                             NaN                      NaN
# 3                             NaN                      NaN
# 4                             NaN                      NaN
#
#                  Number of Services Distances Density over Places Ratio  \
# Neighborhood ID
# 0                                 2       NaN                       NaN
# 1                                45       NaN                       NaN
# 2                                13       NaN                       NaN
# 3                                23       NaN                       NaN
# 4                                35       NaN                       NaN
#
#                 Avg. Students per Teacher Ratio School Status Centers Type  \
# Neighborhood ID
# 0                                           NaN           NaN          NaN
# 1                                           NaN           NaN          NaN
# 2                                           NaN           NaN          NaN
# 3                                           NaN           NaN          NaN
# 4                                           NaN           NaN          NaN
#
#                 Centers Simple Type Centers Characteristics  ...  \
# Neighborhood ID                                              ...
# 0                               NaN                     NaN  ...
# 1                               NaN                     NaN  ...
# 2                               NaN                     NaN  ...
# 3                               NaN                     NaN  ...
# 4                               NaN                     NaN  ...
#
#                 Middle Studies in people older than 15 (%)  \
# Neighborhood ID
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
#
#                 Higher Studies in people older than 15 (%)  \
# Neighborhood ID
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
#
#                 No education or Incomplete Primary School in people older than 15 (%)  \
# Neighborhood ID
# 0                                                              NaN
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
#
#                 Young Population without Post-Compulsory Education (%)  \
# Neighborhood ID
# 0                                                              NaN
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
#
#                 Abscence Rate in 4th Grade (%)  \
# Neighborhood ID
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#                 Graduation Rate in 4th Grade (%)  \
# Neighborhood ID
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#                 Territorial Socioeconomic Index (IST) Avg. Gini Index (%)  \
# Neighborhood ID
# 0                                                 NaN                 NaN
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
# 3                                                 NaN                 NaN
# 4                                                 NaN                 NaN
#
#                 Population Density (hab/ha)  \
# Neighborhood ID
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#                 Net Population Density (hab/residential ha)
# Neighborhood ID
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ### 1.3. Neighborhood & District Name Mappings

# %% [markdown]
# 1.3.1 Neighborhoods

# %%
# Neighborhood ID & Name Mapping
# Mapping Generation (Unique IDs)
neighborhood_mapping = cleaned_educ_df[['Neighborhood ID', 'Neighborhood Name']].drop_duplicates()
#neighborhood_mapping = neighborhood_mapping.dropna()
#display(neighborhood_mapping[neighborhood_mapping['Neighborhood ID'] == 11]): idx 58 el Poble-sec, idx 1355 el Poble Sec
neighborhood_mapping = neighborhood_mapping.drop(1355)

# Set the index to 'Neighborhood ID'
neighborhood_mapping.set_index('Neighborhood ID', inplace=True)
# Sort IDs
neighborhood_mapping = neighborhood_mapping.sort_index()
#display(neighborhood_mapping)

# Merge Data
zones_educ_df['Neighborhood Name'] = neighborhood_mapping
zones_educ_df.head(5)
# Out:
#                                      Neighborhood Name  \
# Neighborhood ID
# 0                                                  NaN
# 1                                             el Raval
# 2                                       el Barri Gòtic
# 3                                       la Barceloneta
# 4                Sant Pere, Santa Caterina i la Ribera
#
#                 District Name Associated  Number of Services Distances  \
# Neighborhood ID
# 0                                    NaN                   2       NaN
# 1                                    NaN                  45       NaN
# 2                                    NaN                  13       NaN
# 3                                    NaN                  23       NaN
# 4                                    NaN                  35       NaN
#
#                 Density over Places Ratio Avg. Students per Teacher Ratio  \
# Neighborhood ID
# 0                                     NaN                             NaN
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
#
#                 School Status Centers Type Centers Simple Type  \
# Neighborhood ID
# 0                         NaN          NaN                 NaN
# 1                         NaN          NaN                 NaN
# 2                         NaN          NaN                 NaN
# 3                         NaN          NaN                 NaN
# 4                         NaN          NaN                 NaN
#
#                 Centers Characteristics  ...  \
# Neighborhood ID                          ...
# 0                                   NaN  ...
# 1                                   NaN  ...
# 2                                   NaN  ...
# 3                                   NaN  ...
# 4                                   NaN  ...
#
#                 Middle Studies in people older than 15 (%)  \
# Neighborhood ID
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
#
#                 Higher Studies in people older than 15 (%)  \
# Neighborhood ID
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
#
#                 No education or Incomplete Primary School in people older than 15 (%)  \
# Neighborhood ID
# 0                                                              NaN
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
#
#                 Young Population without Post-Compulsory Education (%)  \
# Neighborhood ID
# 0                                                              NaN
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
#
#                 Abscence Rate in 4th Grade (%)  \
# Neighborhood ID
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#                 Graduation Rate in 4th Grade (%)  \
# Neighborhood ID
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#                 Territorial Socioeconomic Index (IST) Avg. Gini Index (%)  \
# Neighborhood ID
# 0                                                 NaN                 NaN
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
# 3                                                 NaN                 NaN
# 4                                                 NaN                 NaN
#
#                 Population Density (hab/ha)  \
# Neighborhood ID
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#                 Net Population Density (hab/residential ha)
# Neighborhood ID
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
#
# [5 rows x 24 columns]

# %%
# Services with Neighborhood ID 0
#display(cleaned_educ_df[cleaned_educ_df['Neighborhood ID'] == 0])

# Drop ID 0
zones_educ_df = zones_educ_df.drop(zones_educ_df.index[0])
zones_educ_df.head(5)
# Out:
#                                      Neighborhood Name  \
# Neighborhood ID
# 1                                             el Raval
# 2                                       el Barri Gòtic
# 3                                       la Barceloneta
# 4                Sant Pere, Santa Caterina i la Ribera
# 5                                        el Fort Pienc
#
#                 District Name Associated  Number of Services Distances  \
# Neighborhood ID
# 1                                    NaN                  45       NaN
# 2                                    NaN                  13       NaN
# 3                                    NaN                  23       NaN
# 4                                    NaN                  35       NaN
# 5                                    NaN                  19       NaN
#
#                 Density over Places Ratio Avg. Students per Teacher Ratio  \
# Neighborhood ID
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
# 5                                     NaN                             NaN
#
#                 School Status Centers Type Centers Simple Type  \
# Neighborhood ID
# 1                         NaN          NaN                 NaN
# 2                         NaN          NaN                 NaN
# 3                         NaN          NaN                 NaN
# 4                         NaN          NaN                 NaN
# 5                         NaN          NaN                 NaN
#
#                 Centers Characteristics  ...  \
# Neighborhood ID                          ...
# 1                                   NaN  ...
# 2                                   NaN  ...
# 3                                   NaN  ...
# 4                                   NaN  ...
# 5                                   NaN  ...
#
#                 Middle Studies in people older than 15 (%)  \
# Neighborhood ID
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
#
#                 Higher Studies in people older than 15 (%)  \
# Neighborhood ID
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
#
#                 No education or Incomplete Primary School in people older than 15 (%)  \
# Neighborhood ID
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
# 5                                                              NaN
#
#                 Young Population without Post-Compulsory Education (%)  \
# Neighborhood ID
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
# 5                                                              NaN
#
#                 Abscence Rate in 4th Grade (%)  \
# Neighborhood ID
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
#
#                 Graduation Rate in 4th Grade (%)  \
# Neighborhood ID
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
#
#                 Territorial Socioeconomic Index (IST) Avg. Gini Index (%)  \
# Neighborhood ID
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
# 3                                                 NaN                 NaN
# 4                                                 NaN                 NaN
# 5                                                 NaN                 NaN
#
#                 Population Density (hab/ha)  \
# Neighborhood ID
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
#
#                 Net Population Density (hab/residential ha)
# Neighborhood ID
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# 5                                                       NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# 1.3.2 Districts

# %%
# Neighborhood ID & District Name Mapping
# Mapping Generation (Unique IDs)
district_mapping = cleaned_educ_df[['Neighborhood ID', 'District Name']].drop_duplicates()
#district_mapping = district_mapping[district_mapping['Neighborhood ID'] != 0]
district_mapping = district_mapping.dropna()
#print(district_mapping.isnull().any())

# Set the index to 'Neighborhood ID'
district_mapping.set_index('Neighborhood ID', inplace=True)

# Sort IDs
district_mapping = district_mapping.sort_index()
#display(district_mapping)

# Merge Data
zones_educ_df['District Name Associated'] = district_mapping
zones_educ_df.head(5)
# Out:
#                                      Neighborhood Name  \
# Neighborhood ID
# 1                                             el Raval
# 2                                       el Barri Gòtic
# 3                                       la Barceloneta
# 4                Sant Pere, Santa Caterina i la Ribera
# 5                                        el Fort Pienc
#
#                 District Name Associated  Number of Services Distances  \
# Neighborhood ID
# 1                           Ciutat Vella                  45       NaN
# 2                           Ciutat Vella                  13       NaN
# 3                           Ciutat Vella                  23       NaN
# 4                           Ciutat Vella                  35       NaN
# 5                               Eixample                  19       NaN
#
#                 Density over Places Ratio Avg. Students per Teacher Ratio  \
# Neighborhood ID
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
# 5                                     NaN                             NaN
#
#                 School Status Centers Type Centers Simple Type  \
# Neighborhood ID
# 1                         NaN          NaN                 NaN
# 2                         NaN          NaN                 NaN
# 3                         NaN          NaN                 NaN
# 4                         NaN          NaN                 NaN
# 5                         NaN          NaN                 NaN
#
#                 Centers Characteristics  ...  \
# Neighborhood ID                          ...
# 1                                   NaN  ...
# 2                                   NaN  ...
# 3                                   NaN  ...
# 4                                   NaN  ...
# 5                                   NaN  ...
#
#                 Middle Studies in people older than 15 (%)  \
# Neighborhood ID
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
#
#                 Higher Studies in people older than 15 (%)  \
# Neighborhood ID
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
#
#                 No education or Incomplete Primary School in people older than 15 (%)  \
# Neighborhood ID
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
# 5                                                              NaN
#
#                 Young Population without Post-Compulsory Education (%)  \
# Neighborhood ID
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
# 5                                                              NaN
#
#                 Abscence Rate in 4th Grade (%)  \
# Neighborhood ID
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
#
#                 Graduation Rate in 4th Grade (%)  \
# Neighborhood ID
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
#
#                 Territorial Socioeconomic Index (IST) Avg. Gini Index (%)  \
# Neighborhood ID
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
# 3                                                 NaN                 NaN
# 4                                                 NaN                 NaN
# 5                                                 NaN                 NaN
#
#                 Population Density (hab/ha)  \
# Neighborhood ID
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
#
#                 Net Population Density (hab/residential ha)
# Neighborhood ID
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# 5                                                       NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ### 1.4. IST for all Neighborhoods

# %%
# Dataset Files
socioec_idx_file = "/Users/mariatormo02/Desktop/TFG-Code/Data/Context Index Data/IST.csv"

encoded = detect_encoding(socioec_idx_file)
print(encoded)

# Read CSV
socioec_idx_df = pd.read_csv(socioec_idx_file, encoding='utf-8', sep='\t')
# Out:
# utf-8

# %%
#display(socioec_idx_df)
# Only last year included
socioec_idx_df = socioec_idx_df[socioec_idx_df['any'] == 2020]

# Drop useless cols and renaming
socioec_idx_df = socioec_idx_df.drop(columns={'any', 'estat', 'concepte'})
socioec_idx_df.rename(columns={'barris de Barcelona': 'Neighborhood Name', 'valor': 'Territorial Socioeconomic Index (IST)'}, inplace=True)

# Reset indices
socioec_idx_df.reset_index(drop=True, inplace=True)
socioec_idx_df.index = socioec_idx_df.index + 1
socioec_idx_df.index.name = 'Neighborhood ID'
socioec_idx_df = socioec_idx_df.drop(socioec_idx_df.index[73])
display(socioec_idx_df)
# Out:
#                                             Neighborhood Name  \
# Neighborhood ID
# 1                                                    el Raval
# 2                                              el Barri Gòtic
# 3                                              la Barceloneta
# 4                       Sant Pere, Santa Caterina i la Ribera
# 5                                               el Fort Pienc
# ...                                                       ...
# 69               Diagonal Mar i el Front Marítim del Poblenou
# 70                                      el Besòs i el Maresme
# 71                                    Provençals del Poblenou
# 72                                   Sant Martí de Provençals
# 73                                        la Verneda i la Pau
#
#                 Territorial Socioeconomic Index (IST)
# Neighborhood ID
# 1                                                78,2
# 2                                                75,6
# 3                                                95,8
# 4                                               100,8
# 5                                                 111
# ...                                               ...
# 69                                              116,6
# 70                                               72,4
# 71                                                107
# 72                                              102,9
# 73                                                 96
#
# [73 rows x 2 columns]

# %%
# Compare
#socioec_idx_df['Neighborhood Name'].unique()
#zones_educ_df['Neighborhood Name'].unique()

# Merge
zones_educ_df['Territorial Socioeconomic Index (IST)'] = socioec_idx_df['Territorial Socioeconomic Index (IST)']
zones_educ_df.head(5)
# Out:
#                                      Neighborhood Name  \
# Neighborhood ID
# 1                                             el Raval
# 2                                       el Barri Gòtic
# 3                                       la Barceloneta
# 4                Sant Pere, Santa Caterina i la Ribera
# 5                                        el Fort Pienc
#
#                 District Name Associated  Number of Services Distances  \
# Neighborhood ID
# 1                           Ciutat Vella                  45       NaN
# 2                           Ciutat Vella                  13       NaN
# 3                           Ciutat Vella                  23       NaN
# 4                           Ciutat Vella                  35       NaN
# 5                               Eixample                  19       NaN
#
#                 Density over Places Ratio Avg. Students per Teacher Ratio  \
# Neighborhood ID
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
# 5                                     NaN                             NaN
#
#                 School Status Centers Type Centers Simple Type  \
# Neighborhood ID
# 1                         NaN          NaN                 NaN
# 2                         NaN          NaN                 NaN
# 3                         NaN          NaN                 NaN
# 4                         NaN          NaN                 NaN
# 5                         NaN          NaN                 NaN
#
#                 Centers Characteristics  ...  \
# Neighborhood ID                          ...
# 1                                   NaN  ...
# 2                                   NaN  ...
# 3                                   NaN  ...
# 4                                   NaN  ...
# 5                                   NaN  ...
#
#                 Middle Studies in people older than 15 (%)  \
# Neighborhood ID
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
#
#                 Higher Studies in people older than 15 (%)  \
# Neighborhood ID
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
#
#                 No education or Incomplete Primary School in people older than 15 (%)  \
# Neighborhood ID
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
# 5                                                              NaN
#
#                 Young Population without Post-Compulsory Education (%)  \
# Neighborhood ID
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
# 5                                                              NaN
#
#                 Abscence Rate in 4th Grade (%)  \
# Neighborhood ID
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
#
#                 Graduation Rate in 4th Grade (%)  \
# Neighborhood ID
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
#
#                 Territorial Socioeconomic Index (IST) Avg. Gini Index (%)  \
# Neighborhood ID
# 1                                                78,2                 NaN
# 2                                                75,6                 NaN
# 3                                                95,8                 NaN
# 4                                               100,8                 NaN
# 5                                                 111                 NaN
#
#                 Population Density (hab/ha)  \
# Neighborhood ID
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
#
#                 Net Population Density (hab/residential ha)
# Neighborhood ID
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# 5                                                       NaN
#
# [5 rows x 24 columns]

# %%
# Replace COMA with POINT for decimals in the "Territorial Socioeconomic Index (IST)" column
zones_educ_df['Territorial Socioeconomic Index (IST)'] = zones_educ_df['Territorial Socioeconomic Index (IST)'].str.replace(',', '.')

# Convert the column to numeric data type
zones_educ_df['Territorial Socioeconomic Index (IST)'] = pd.to_numeric(zones_educ_df['Territorial Socioeconomic Index (IST)'])
zones_educ_df.head(5)
# Out:
#                                      Neighborhood Name  \
# Neighborhood ID
# 1                                             el Raval
# 2                                       el Barri Gòtic
# 3                                       la Barceloneta
# 4                Sant Pere, Santa Caterina i la Ribera
# 5                                        el Fort Pienc
#
#                 District Name Associated  Number of Services Distances  \
# Neighborhood ID
# 1                           Ciutat Vella                  45       NaN
# 2                           Ciutat Vella                  13       NaN
# 3                           Ciutat Vella                  23       NaN
# 4                           Ciutat Vella                  35       NaN
# 5                               Eixample                  19       NaN
#
#                 Density over Places Ratio Avg. Students per Teacher Ratio  \
# Neighborhood ID
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
# 5                                     NaN                             NaN
#
#                 School Status Centers Type Centers Simple Type  \
# Neighborhood ID
# 1                         NaN          NaN                 NaN
# 2                         NaN          NaN                 NaN
# 3                         NaN          NaN                 NaN
# 4                         NaN          NaN                 NaN
# 5                         NaN          NaN                 NaN
#
#                 Centers Characteristics  ...  \
# Neighborhood ID                          ...
# 1                                   NaN  ...
# 2                                   NaN  ...
# 3                                   NaN  ...
# 4                                   NaN  ...
# 5                                   NaN  ...
#
#                 Middle Studies in people older than 15 (%)  \
# Neighborhood ID
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
#
#                 Higher Studies in people older than 15 (%)  \
# Neighborhood ID
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
#
#                 No education or Incomplete Primary School in people older than 15 (%)  \
# Neighborhood ID
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
# 5                                                              NaN
#
#                 Young Population without Post-Compulsory Education (%)  \
# Neighborhood ID
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
# 5                                                              NaN
#
#                 Abscence Rate in 4th Grade (%)  \
# Neighborhood ID
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
#
#                 Graduation Rate in 4th Grade (%)  \
# Neighborhood ID
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
#
#                 Territorial Socioeconomic Index (IST) Avg. Gini Index (%)  \
# Neighborhood ID
# 1                                                78.2                 NaN
# 2                                                75.6                 NaN
# 3                                                95.8                 NaN
# 4                                               100.8                 NaN
# 5                                               111.0                 NaN
#
#                 Population Density (hab/ha)  \
# Neighborhood ID
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
#
#                 Net Population Density (hab/residential ha)
# Neighborhood ID
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# 5                                                       NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ### 1.5. Gini Index(%) for all Neighborhoods

# %%
# Dataset Files
gini_idx_file = "/Users/mariatormo02/Desktop/TFG-Code/Data/Context Index Data/2021_renda_index_gini.csv"

encoded = detect_encoding(gini_idx_file)
print(encoded)

# Read CSV
gini_idx_df = pd.read_csv(gini_idx_file, encoding='utf-8')
# Out:
# utf-8

# %%
display(gini_idx_df)
# Out:
#        Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0     2021               1  Ciutat Vella           1
# 1     2021               1  Ciutat Vella           1
# 2     2021               1  Ciutat Vella           1
# 3     2021               1  Ciutat Vella           1
# 4     2021               1  Ciutat Vella           1
# ...    ...             ...           ...         ...
# 1063  2021              10    Sant Martí          73
# 1064  2021              10    Sant Martí          65
# 1065  2021              10    Sant Martí          69
# 1066  2021              10    Sant Martí          69
# 1067  2021              10    Sant Martí          71
#
#                                          Nom_Barri  Seccio_Censal  Index_Gini
# 0                                         el Raval              1        37.5
# 1                                         el Raval              2        35.4
# 2                                         el Raval              3        36.2
# 3                                         el Raval              4        35.0
# 4                                         el Raval              5        36.8
# ...                                            ...            ...         ...
# 1063                           la Verneda i la Pau            143        27.1
# 1064                                       el Clot            234        25.3
# 1065  Diagonal Mar i el Front Marítim del Poblenou            235        32.9
# 1066  Diagonal Mar i el Front Marítim del Poblenou            236        28.1
# 1067                       Provençals del Poblenou            237        28.0
#
# [1068 rows x 7 columns]

# %%
#display(socioec_idx_df)
# Drop useless cols and renaming
gini_idx_df = gini_idx_df.drop(columns={'Any', 'Codi_Districte', 'Nom_Districte'})
gini_idx_df.rename(columns={'Codi_Barri': 'Neighborhood ID', 'Nom_Barri': 'Neighborhood Name', 'Index_Gini': 'Gini Index'}, inplace=True)

display(gini_idx_df)
# Out:
#       Neighborhood ID                             Neighborhood Name  \
# 0                   1                                      el Raval
# 1                   1                                      el Raval
# 2                   1                                      el Raval
# 3                   1                                      el Raval
# 4                   1                                      el Raval
# ...               ...                                           ...
# 1063               73                           la Verneda i la Pau
# 1064               65                                       el Clot
# 1065               69  Diagonal Mar i el Front Marítim del Poblenou
# 1066               69  Diagonal Mar i el Front Marítim del Poblenou
# 1067               71                       Provençals del Poblenou
#
#       Seccio_Censal  Gini Index
# 0                 1        37.5
# 1                 2        35.4
# 2                 3        36.2
# 3                 4        35.0
# 4                 5        36.8
# ...             ...         ...
# 1063            143        27.1
# 1064            234        25.3
# 1065            235        32.9
# 1066            236        28.1
# 1067            237        28.0
#
# [1068 rows x 4 columns]

# %%
# Compute Avg Gini Index per Neighborhood ID
avg_gini_df = gini_idx_df.groupby('Neighborhood ID')['Gini Index'].mean()

# Into sorted Dataframe by ID
avg_gini_df = avg_gini_df.reset_index()
avg_gini_df.index = avg_gini_df.index + 1
avg_gini_df.rename(columns={'Gini Index': 'Avg. Gini Index (%)'}, inplace=True)
avg_gini_df.drop(columns={'Neighborhood ID'}, inplace=True)
display(avg_gini_df)
# Out:
#     Avg. Gini Index (%)
# 1             34.495238
# 2             39.133333
# 3             33.636364
# 4             37.030769
# 5             32.475000
# ..                  ...
# 69            31.814286
# 70            29.715385
# 71            29.241667
# 72            27.361111
# 73            27.128571
#
# [73 rows x 1 columns]

# %%
# Merge into zones dataset (round to 3 decimal places)
avg_gini_df['Avg. Gini Index (%)'] = avg_gini_df['Avg. Gini Index (%)'].round(3)
zones_educ_df['Avg. Gini Index (%)'] = avg_gini_df['Avg. Gini Index (%)']
display(zones_educ_df)
# Out:
#                                             Neighborhood Name  \
# Neighborhood ID
# 1                                                    el Raval
# 2                                              el Barri Gòtic
# 3                                              la Barceloneta
# 4                       Sant Pere, Santa Caterina i la Ribera
# 5                                               el Fort Pienc
# ...                                                       ...
# 69               Diagonal Mar i el Front Marítim del Poblenou
# 70                                      el Besòs i el Maresme
# 71                                    Provençals del Poblenou
# 72                                   Sant Martí de Provençals
# 73                                        la Verneda i la Pau
#
#                 District Name Associated  Number of Services Distances  \
# Neighborhood ID
# 1                           Ciutat Vella                  45       NaN
# 2                           Ciutat Vella                  13       NaN
# 3                           Ciutat Vella                  23       NaN
# 4                           Ciutat Vella                  35       NaN
# 5                               Eixample                  19       NaN
# ...                                  ...                 ...       ...
# 69                            Sant Martí                   7       NaN
# 70                            Sant Martí                  13       NaN
# 71                            Sant Martí                  17       NaN
# 72                            Sant Martí                  19       NaN
# 73                            Sant Martí                  15       NaN
#
#                 Density over Places Ratio Avg. Students per Teacher Ratio  \
# Neighborhood ID
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
# 5                                     NaN                             NaN
# ...                                   ...                             ...
# 69                                    NaN                             NaN
# 70                                    NaN                             NaN
# 71                                    NaN                             NaN
# 72                                    NaN                             NaN
# 73                                    NaN                             NaN
#
#                 School Status Centers Type Centers Simple Type  \
# Neighborhood ID
# 1                         NaN          NaN                 NaN
# 2                         NaN          NaN                 NaN
# 3                         NaN          NaN                 NaN
# 4                         NaN          NaN                 NaN
# 5                         NaN          NaN                 NaN
# ...                       ...          ...                 ...
# 69                        NaN          NaN                 NaN
# 70                        NaN          NaN                 NaN
# 71                        NaN          NaN                 NaN
# 72                        NaN          NaN                 NaN
# 73                        NaN          NaN                 NaN
#
#                 Centers Characteristics  ...  \
# Neighborhood ID                          ...
# 1                                   NaN  ...
# 2                                   NaN  ...
# 3                                   NaN  ...
# 4                                   NaN  ...
# 5                                   NaN  ...
# ...                                 ...  ...
# 69                                  NaN  ...
# 70                                  NaN  ...
# 71                                  NaN  ...
# 72                                  NaN  ...
# 73                                  NaN  ...
#
#                 Middle Studies in people older than 15 (%)  \
# Neighborhood ID
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# ...                                                    ...
# 69                                                     NaN
# 70                                                     NaN
# 71                                                     NaN
# 72                                                     NaN
# 73                                                     NaN
#
#                 Higher Studies in people older than 15 (%)  \
# Neighborhood ID
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# ...                                                    ...
# 69                                                     NaN
# 70                                                     NaN
# 71                                                     NaN
# 72                                                     NaN
# 73                                                     NaN
#
#                 No education or Incomplete Primary School in people older than 15 (%)  \
# Neighborhood ID
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
# 5                                                              NaN
# ...                                                            ...
# 69                                                             NaN
# 70                                                             NaN
# 71                                                             NaN
# 72                                                             NaN
# 73                                                             NaN
#
#                 Young Population without Post-Compulsory Education (%)  \
# Neighborhood ID
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
# 5                                                              NaN
# ...                                                            ...
# 69                                                             NaN
# 70                                                             NaN
# 71                                                             NaN
# 72                                                             NaN
# 73                                                             NaN
#
#                 Abscence Rate in 4th Grade (%)  \
# Neighborhood ID
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# ...                                        ...
# 69                                         NaN
# 70                                         NaN
# 71                                         NaN
# 72                                         NaN
# 73                                         NaN
#
#                 Graduation Rate in 4th Grade (%)  \
# Neighborhood ID
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# ...                                          ...
# 69                                           NaN
# 70                                           NaN
# 71                                           NaN
# 72                                           NaN
# 73                                           NaN
#
#                 Territorial Socioeconomic Index (IST) Avg. Gini Index (%)  \
# Neighborhood ID
# 1                                                78.2              34.495
# 2                                                75.6              39.133
# 3                                                95.8              33.636
# 4                                               100.8              37.031
# 5                                               111.0              32.475
# ...                                               ...                 ...
# 69                                              116.6              31.814
# 70                                               72.4              29.715
# 71                                              107.0              29.242
# 72                                              102.9              27.361
# 73                                               96.0              27.129
#
#                 Population Density (hab/ha)  \
# Neighborhood ID
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# ...                                     ...
# 69                                      NaN
# 70                                      NaN
# 71                                      NaN
# 72                                      NaN
# 73                                      NaN
#
#                 Net Population Density (hab/residential ha)
# Neighborhood ID
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# 5                                                       NaN
# ...                                                     ...
# 69                                                      NaN
# 70                                                      NaN
# 71                                                      NaN
# 72                                                      NaN
# 73                                                      NaN
#
# [73 rows x 24 columns]

# %% [markdown]
# ### 1.6. Residents Density for each Neighborhood

# %%
# Dataset Files
density_file = "/Users/mariatormo02/Desktop/TFG-Code/Data/Context Index Data/2021_densitat.csv"

encoded = detect_encoding(density_file)
print(encoded)

# Read CSV
density_df = pd.read_csv(density_file, encoding='utf-8')
# Out:
# utf-8

# %%
display(density_df)
# Out:
#      Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0   2021               1  Ciutat Vella           1
# 1   2021               1  Ciutat Vella           2
# 2   2021               1  Ciutat Vella           3
# 3   2021               1  Ciutat Vella           4
# 4   2021               2      Eixample           5
# ..   ...             ...           ...         ...
# 68  2021              10    Sant Martí          69
# 69  2021              10    Sant Martí          70
# 70  2021              10    Sant Martí          71
# 71  2021              10    Sant Martí          72
# 72  2021              10    Sant Martí          73
#
#                                        Nom_Barri  Població  Superfície (ha)  \
# 0                                       el Raval     47228            110.0
# 1                                 el Barri Gòtic     21827             81.6
# 2                                 la Barceloneta     14643            117.9
# 3          Sant Pere, Santa Caterina i la Ribera     22131            111.0
# 4                                  el Fort Pienc     31262             92.9
# ..                                           ...       ...              ...
# 68  Diagonal Mar i el Front Marítim del Poblenou     13323            122.7
# 69                         el Besòs i el Maresme     25657            120.9
# 70                       Provençals del Poblenou     20949            108.6
# 71                      Sant Martí de Provençals     26032             73.4
# 72                           la Verneda i la Pau     28585            113.0
#
#     Superfície Residencial (ha)  Densitat (hab/ha)  Densitat neta (hab/ha)
# 0                          49.6                429                     952
# 1                          34.1                268                     639
# 2                          13.5                124                    1081
# 3                          32.4                199                     683
# 4                          33.6                336                     930
# ..                          ...                ...                     ...
# 68                         24.0                109                     556
# 69                         28.1                212                     913
# 70                         15.3                193                    1368
# 71                         23.4                355                    1111
# 72                         40.0                253                     714
#
# [73 rows x 10 columns]

# %%
#display(density_df)
# Drop useless cols and renaming
density_df = density_df.drop(columns={'Any', 'Codi_Districte', 'Nom_Districte', 'Nom_Barri', 'Població', 'Superfície (ha)', 'Superfície Residencial (ha)'})
density_df.rename(columns={'Codi_Barri': 'Neighborhood ID', 'Densitat (hab/ha)': 'Population Density (hab/ha)', 'Densitat neta (hab/ha)': 'Net Population Density (hab/residential ha)'}, inplace=True)

# Use Index as Neighborhood ID
density_df.drop(columns={'Neighborhood ID'}, inplace=True)
density_df.index = density_df.index + 1
display(density_df)
# Out:
#     Population Density (hab/ha)  Net Population Density (hab/residential ha)
# 1                           429                                          952
# 2                           268                                          639
# 3                           124                                         1081
# 4                           199                                          683
# 5                           336                                          930
# ..                          ...                                          ...
# 69                          109                                          556
# 70                          212                                          913
# 71                          193                                         1368
# 72                          355                                         1111
# 73                          253                                          714
#
# [73 rows x 2 columns]

# %%
# Merge data
zones_educ_df['Population Density (hab/ha)'] = density_df['Population Density (hab/ha)']
zones_educ_df['Net Population Density (hab/residential ha)'] = density_df['Net Population Density (hab/residential ha)']
zones_educ_df.head(7)
# Out:
#                                      Neighborhood Name  \
# Neighborhood ID
# 1                                             el Raval
# 2                                       el Barri Gòtic
# 3                                       la Barceloneta
# 4                Sant Pere, Santa Caterina i la Ribera
# 5                                        el Fort Pienc
# 6                                   la Sagrada Família
# 7                               la Dreta de l'Eixample
#
#                 District Name Associated  Number of Services Distances  \
# Neighborhood ID
# 1                           Ciutat Vella                  45       NaN
# 2                           Ciutat Vella                  13       NaN
# 3                           Ciutat Vella                  23       NaN
# 4                           Ciutat Vella                  35       NaN
# 5                               Eixample                  19       NaN
# 6                               Eixample                  24       NaN
# 7                               Eixample                  75       NaN
#
#                 Density over Places Ratio Avg. Students per Teacher Ratio  \
# Neighborhood ID
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
# 5                                     NaN                             NaN
# 6                                     NaN                             NaN
# 7                                     NaN                             NaN
#
#                 School Status Centers Type Centers Simple Type  \
# Neighborhood ID
# 1                         NaN          NaN                 NaN
# 2                         NaN          NaN                 NaN
# 3                         NaN          NaN                 NaN
# 4                         NaN          NaN                 NaN
# 5                         NaN          NaN                 NaN
# 6                         NaN          NaN                 NaN
# 7                         NaN          NaN                 NaN
#
#                 Centers Characteristics  ...  \
# Neighborhood ID                          ...
# 1                                   NaN  ...
# 2                                   NaN  ...
# 3                                   NaN  ...
# 4                                   NaN  ...
# 5                                   NaN  ...
# 6                                   NaN  ...
# 7                                   NaN  ...
#
#                 Middle Studies in people older than 15 (%)  \
# Neighborhood ID
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7                                                      NaN
#
#                 Higher Studies in people older than 15 (%)  \
# Neighborhood ID
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7                                                      NaN
#
#                 No education or Incomplete Primary School in people older than 15 (%)  \
# Neighborhood ID
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
# 5                                                              NaN
# 6                                                              NaN
# 7                                                              NaN
#
#                 Young Population without Post-Compulsory Education (%)  \
# Neighborhood ID
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
# 5                                                              NaN
# 6                                                              NaN
# 7                                                              NaN
#
#                 Abscence Rate in 4th Grade (%)  \
# Neighborhood ID
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
#
#                 Graduation Rate in 4th Grade (%)  \
# Neighborhood ID
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
#
#                 Territorial Socioeconomic Index (IST) Avg. Gini Index (%)  \
# Neighborhood ID
# 1                                                78.2              34.495
# 2                                                75.6              39.133
# 3                                                95.8              33.636
# 4                                               100.8              37.031
# 5                                               111.0              32.475
# 6                                               111.8              32.700
# 7                                               120.9              36.697
#
#                 Population Density (hab/ha)  \
# Neighborhood ID
# 1                                       429
# 2                                       268
# 3                                       124
# 4                                       199
# 5                                       336
# 6                                       493
# 7                                       211
#
#                 Net Population Density (hab/residential ha)
# Neighborhood ID
# 1                                                       952
# 2                                                       639
# 3                                                      1081
# 4                                                       683
# 5                                                       930
# 6                                                      1007
# 7                                                       392
#
# [7 rows x 24 columns]

# %% [markdown]
# ### 1.7 Services Status

# %%
# Dataset Files
status_file = "status_education.csv"

encoded = detect_encoding(status_file)
print(encoded)

# Read CSV
status_df = pd.read_csv(status_file, encoding='utf-8')
# Out:
# utf-8

# %%
status_df.drop(columns={'Unnamed: 0'}, inplace=True)
status_df.rename(columns={'Neighborhood Name': 'District Name'}, inplace=True)
display(status_df)
# Out:
#                                  Name        District Name   Status
# 0                   Escola Poeta Foix  Sarrià-Sant Gervasi   public
# 1                     Escola Arc Iris       Horta-Guinardó   public
# 2                     Escola Baixeras         Ciutat Vella   public
# 3        Escola Parc de la Ciutadella         Ciutat Vella   public
# 4      Escola Mossèn Jacint Verdaguer       Sants-Montjuïc   public
# ..                                ...                  ...      ...
# 549          Llar d'infants Guinyolet           la Sagrera  private
# 550  Llar d'infants La Pau - Gran Via       Sants-Montjuïc  private
# 551              Llar d'infants Àgora             Eixample  private
# 552         Escola Infantil Pas A Pas       Horta-Guinardó  private
# 553          Escola Bressol Sol Solet             Eixample  private
#
# [554 rows x 3 columns]

# %%
# Function to get the best match with a minimum score threshold and district matching
def get_best_match(row, choices, scorer, threshold=95):
    # Filter choices by matching district
    district_choices = [choice for choice in choices if choice[1] == row['District Name']]

    if not district_choices:
        return None

    best_match, best_score = process.extractOne(row['Name'], [choice[0] for choice in district_choices], scorer=scorer)

    if best_score >= threshold:
        return best_match
    else:
        return None

# %%
# Assign Neighborhoods using Cleaned Dataset

# Assuming 'District Name' column exists in both datasets
# Prepare the choices list with tuples of (Name, District)
choices = list(cleaned_educ_df[['Name', 'District Name']].itertuples(index=False, name=None))

# Apply the fuzzy matching function to the second dataset
status_df['Matched_Name'] = status_df.apply(get_best_match, axis=1, choices=choices, scorer=fuzz.partial_ratio)

# Filter out rows where no good match was found
status_df = status_df[status_df['Matched_Name'].notna()]

# Merge with the neighborhood information using the matched names
status_merged_df = status_df.merge(cleaned_educ_df[['Name', 'Neighborhood Name']],
                                   left_on='Matched_Name', right_on='Name', how='left')

# Drop the 'Matched_Name' column as it is no longer needed
status_merged_df.drop(columns=['Matched_Name'], inplace=True)

# Rename and drop columns
status_merged_df.rename(columns={'Name_x': 'Original Name', 'Name_y': 'Mapped Name', 'Neighborhood Name_y': 'Neighborhood Name'}, inplace=True)

# Display the merged DataFrame
display(status_merged_df)
status_df = status_merged_df
# Out:
#                            Original Name        District Name   Status  \
# 0                      Escola Poeta Foix  Sarrià-Sant Gervasi   public
# 1                        Escola Arc Iris       Horta-Guinardó   public
# 2                        Escola Baixeras         Ciutat Vella   public
# 3           Escola Parc de la Ciutadella         Ciutat Vella   public
# 4         Escola Mossèn Jacint Verdaguer       Sants-Montjuïc   public
# ..                                   ...                  ...      ...
# 389    Llar d'infants El petit rossinyol             Eixample  private
# 390                Llar d'infants Tagore  Sarrià-Sant Gervasi  private
# 391  Llar d'infants Casa Sagrada Família  Sarrià-Sant Gervasi  private
# 392     Llar d'infants La Pau - Gran Via       Sants-Montjuïc  private
# 393                 Llar d'infants Àgora             Eixample  private
#
#                              Mapped Name  \
# 0                      Escola Poeta Foix
# 1                        Escola Arc Iris
# 2                        Escola Baixeras
# 3           Escola Parc de la Ciutadella
# 4         Escola Mossèn Jacint Verdaguer
# ..                                   ...
# 389    Llar d'Infants El Petit Rossinyol
# 390                Llar d'Infants Tagore
# 391  Llar d'Infants Casa Sagrada Família
# 392                Llar d'Infants La Pau
# 393                 Llar d'Infants Àgora
#
#                          Neighborhood Name
# 0                     el Putxet i el Farró
# 1                     la Font d'en Fargues
# 2                           el Barri Gòtic
# 3    Sant Pere, Santa Caterina i la Ribera
# 4                             el Poble-sec
# ..                                     ...
# 389                            Sant Antoni
# 390                 Sant Gervasi - Galvany
# 391  Vallvidrera, el Tibidabo i les Planes
# 392                  la Font de la Guatlla
# 393         la Nova Esquerra de l'Eixample
#
# [394 rows x 5 columns]

# %%
# Group by Neighborhood, and count occurences of each status value

# Group by 'Neighborhood Name' and aggregate 'Status' column
neighborhood_status_df = status_df.groupby('Neighborhood Name')['Status'].value_counts().unstack(fill_value=0)

# Reset index to make 'Neighborhood Name' a column instead of an index
neighborhood_status_df.reset_index(inplace=True)

# Reorder columns
neighborhood_status_df = neighborhood_status_df[['Neighborhood Name', 'private', 'public', 'charter']]

display(neighborhood_status_df)
# Out:
# Status                             Neighborhood Name  private  public  charter
# 0                                      Baró de Viver        0       2        1
# 1                                          Canyelles        0       3        0
# 2                                   Ciutat Meridiana        0       4        1
# 3       Diagonal Mar i el Front Marítim del Poblenou        0       1        2
# 4                                              Horta        0       3        5
# ..                                               ...      ...     ...      ...
# 59                     la Vila Olímpica del Poblenou        0       2        0
# 60                                 la Vila de Gràcia        0       9        4
# 61                                         les Corts        0       4        3
# 62                                      les Roquetes        0       4        0
# 63                                   les Tres Torres        0       0        2
#
# [64 rows x 4 columns]

# %%
# Group by District, and count occurences of each status value

# Group by 'District Name' and aggregate 'Status' column
district_status_df = status_df.groupby('District Name')['Status'].value_counts().unstack(fill_value=0)

# Reset index to make 'Neighborhood Name' a column instead of an index
district_status_df.reset_index(inplace=True)

# Reorder columns
district_status_df = district_status_df[['District Name', 'private', 'public', 'charter']]

display(district_status_df)
# Out:
# Status        District Name  private  public  charter
# 0              Ciutat Vella        0      17        6
# 1                  Eixample        5      22       22
# 2                    Gràcia        0      22       11
# 3            Horta-Guinardó        1      28       13
# 4                 Les Corts        1      11        9
# 5                Nou Barris        0      29       13
# 6               Sant Andreu        0      23       12
# 7                Sant Martí        0      36       18
# 8            Sants-Montjuïc        5      30       12
# 9       Sarrià-Sant Gervasi        3      13       32

# %% [markdown]
# We will assign the status offer regarding the Neighbourhood. In case some neighborhoods are not referenced but, instead, the District is given, we will assign status according to the district name instead of the neighborhood.

# %%
cleaned_educ_df['Neighborhood Name'].unique()
# Out:
# array(['Sants', 'el Fort Pienc', "la Dreta de l'Eixample",
#        'la Verneda i la Pau', 'la Salut', 'Sant Antoni',
#        'la Vila de Gràcia', 'Sant Andreu', 'el Clot', 'la Marina de Port',
#        'Provençals del Poblenou', 'les Tres Torres', 'el Raval',
#        'el Guinardó', "la Nova Esquerra de l'Eixample", 'Porta',
#        'Sant Martí de Provençals', 'el Poblenou',
#        "l'Antiga Esquerra de l'Eixample",
#        'Vallvidrera, el Tibidabo i les Planes',
#        'Sant Pere, Santa Caterina i la Ribera', 'Sarrià', 'Navas',
#        'la Prosperitat', 'la Sagrada Família', 'la Sagrera',
#        'Sant Gervasi - la Bonanova', 'la Maternitat i Sant Ramon',
#        'Pedralbes', 'la Trinitat Nova', "la Vall d'Hebron",
#        'el Bon Pastor', 'la Vila Olímpica del Poblenou', 'Hostafrancs',
#        'Sant Gervasi - Galvany', 'el Poble-sec',
#        'Sant Genís dels Agudells', 'el Baix Guinardó', 'el Carmel',
#        'el Besòs i el Maresme', 'Sants - Badal', 'la Barceloneta',
#        'les Corts', 'el Congrés i els Indians', 'Montbau',
#        "la Font d'en Fargues", 'la Font de la Guatlla',
#        'Vallcarca i els Penitents', 'Verdun', 'el Putxet i el Farró',
#        'Horta', 'la Guineueta', 'el Parc i la Llacuna del Poblenou',
#        "el Camp de l'Arpa del Clot", 'Vilapicina i la Torre Llobeta',
#        'la Marina del Prat Vermell', 'el Barri Gòtic', 'la Bordeta',
#        'Can Peguera', 'el Turó de la Peira', 'Ciutat Meridiana',
#        'Baró de Viver', 'el Coll', 'les Roquetes', 'Can Baró',
#        "el Camp d'en Grassot i Gràcia Nova", 'Vallbona', 'la Clota',
#        'la Trinitat Vella',
#        'Diagonal Mar i el Front Marítim del Poblenou', 'Canyelles',
#        'Torre Baró', nan, 'la Teixonera', 'el Poble Sec'], dtype=object)

# %%
#cleaned_educ_df['District Name'].unique()

# %%
neighborhood_status_df['Neighborhood Name'].unique()
# Out:
# array(['Baró de Viver', 'Canyelles', 'Ciutat Meridiana',
#        'Diagonal Mar i el Front Marítim del Poblenou', 'Horta',
#        'Hostafrancs', 'Montbau', 'Navas', 'Pedralbes', 'Porta',
#        'Provençals del Poblenou', 'Sant Andreu', 'Sant Antoni',
#        'Sant Genís dels Agudells', 'Sant Gervasi - Galvany',
#        'Sant Gervasi - la Bonanova', 'Sant Martí de Provençals',
#        'Sant Pere, Santa Caterina i la Ribera', 'Sants', 'Sants - Badal',
#        'Sarrià', 'Vallbona', 'Vallcarca i els Penitents',
#        'Vallvidrera, el Tibidabo i les Planes', 'Verdun',
#        'Vilapicina i la Torre Llobeta', 'el Baix Guinardó',
#        'el Barri Gòtic', 'el Besòs i el Maresme', 'el Bon Pastor',
#        "el Camp d'en Grassot i Gràcia Nova", "el Camp de l'Arpa del Clot",
#        'el Carmel', 'el Clot', 'el Coll', 'el Congrés i els Indians',
#        'el Fort Pienc', 'el Guinardó', 'el Poble-sec', 'el Poblenou',
#        'el Putxet i el Farró', 'el Raval', 'el Turó de la Peira',
#        "l'Antiga Esquerra de l'Eixample", 'la Barceloneta', 'la Bordeta',
#        "la Dreta de l'Eixample", "la Font d'en Fargues",
#        'la Font de la Guatlla', 'la Guineueta', 'la Marina de Port',
#        'la Maternitat i Sant Ramon', "la Nova Esquerra de l'Eixample",
#        'la Prosperitat', 'la Sagrada Família', 'la Sagrera', 'la Salut',
#        "la Vall d'Hebron", 'la Verneda i la Pau',
#        'la Vila Olímpica del Poblenou', 'la Vila de Gràcia', 'les Corts',
#        'les Roquetes', 'les Tres Torres'], dtype=object)

# %%
# Missing Neighborhoods
print("Missing Neighborhoods:", list(set(cleaned_educ_df['Neighborhood Name'].unique()) - set(status_df['Neighborhood Name'].unique())))
# Out:
# Missing Neighborhoods: [nan, 'la Trinitat Vella', 'la Clota', 'la Marina del Prat Vermell', 'el Poble Sec', 'el Parc i la Llacuna del Poblenou', 'Can Baró', 'Can Peguera', 'Torre Baró', 'la Trinitat Nova', 'la Teixonera']

# %%
# DISTRICTS NAMES

# Merge in case Name coincides, assign list of status greater than 0
# Create empty list
status_list = []

# Iterate over 'zones_educ_df' rows
for idx, row in zones_educ_df.iterrows():
  district_name = row['District Name Associated']

  # Check if in status dataframe
  if district_name in district_status_df['District Name'].values:
    # Get row
    district_row = district_status_df.loc[district_status_df['District Name'] == district_name]
    # Get status > 0
    status = [col for col in district_row.columns[1:] if district_row[col].values[0] > 0]

    # Append to list of statuses
    status_string = ', '.join(status)
    status_list.append(status_string)
  else:
    status_list.append('')

# Assign list
zones_educ_df['School Status'] = status_list
zones_educ_df.head(5)
#display(zones_educ_df)
# Out:
#                                      Neighborhood Name  \
# Neighborhood ID
# 1                                             el Raval
# 2                                       el Barri Gòtic
# 3                                       la Barceloneta
# 4                Sant Pere, Santa Caterina i la Ribera
# 5                                        el Fort Pienc
#
#                 District Name Associated  Number of Services Distances  \
# Neighborhood ID
# 1                           Ciutat Vella                  45       NaN
# 2                           Ciutat Vella                  13       NaN
# 3                           Ciutat Vella                  23       NaN
# 4                           Ciutat Vella                  35       NaN
# 5                               Eixample                  19       NaN
#
#                 Density over Places Ratio Avg. Students per Teacher Ratio  \
# Neighborhood ID
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
# 5                                     NaN                             NaN
#
#                             School Status Centers Type Centers Simple Type  \
# Neighborhood ID
# 1                         public, charter          NaN                 NaN
# 2                         public, charter          NaN                 NaN
# 3                         public, charter          NaN                 NaN
# 4                         public, charter          NaN                 NaN
# 5                private, public, charter          NaN                 NaN
#
#                 Centers Characteristics  ...  \
# Neighborhood ID                          ...
# 1                                   NaN  ...
# 2                                   NaN  ...
# 3                                   NaN  ...
# 4                                   NaN  ...
# 5                                   NaN  ...
#
#                 Middle Studies in people older than 15 (%)  \
# Neighborhood ID
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
#
#                 Higher Studies in people older than 15 (%)  \
# Neighborhood ID
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
#
#                 No education or Incomplete Primary School in people older than 15 (%)  \
# Neighborhood ID
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
# 5                                                              NaN
#
#                 Young Population without Post-Compulsory Education (%)  \
# Neighborhood ID
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
# 5                                                              NaN
#
#                 Abscence Rate in 4th Grade (%)  \
# Neighborhood ID
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
#
#                 Graduation Rate in 4th Grade (%)  \
# Neighborhood ID
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
#
#                 Territorial Socioeconomic Index (IST) Avg. Gini Index (%)  \
# Neighborhood ID
# 1                                                78.2              34.495
# 2                                                75.6              39.133
# 3                                                95.8              33.636
# 4                                               100.8              37.031
# 5                                               111.0              32.475
#
#                 Population Density (hab/ha)  \
# Neighborhood ID
# 1                                       429
# 2                                       268
# 3                                       124
# 4                                       199
# 5                                       336
#
#                 Net Population Density (hab/residential ha)
# Neighborhood ID
# 1                                                       952
# 2                                                       639
# 3                                                      1081
# 4                                                       683
# 5                                                       930
#
# [5 rows x 24 columns]

# %%
# NEIGHBORHOODS NAMES

# Merge in case Name coincides, assign list of status greater than 0
# Create empty list
status_list = []

# Iterate over 'zones_educ_df' rows
for idx, row in zones_educ_df.iterrows():
    neighborhood_name = row['Neighborhood Name']
    
    # Check if in status dataframe
    if neighborhood_name in neighborhood_status_df['Neighborhood Name'].values:
        # Get row
        neighborhood_row = neighborhood_status_df.loc[neighborhood_status_df['Neighborhood Name'] == neighborhood_name]
        # Get status > 0
        status = [col for col in neighborhood_row.columns[1:] if neighborhood_row[col].values[0] > 0]

        # Append to list of statuses
        status_string = ', '.join(status)
        status_list.append(status_string)
    else:
        status_list.append(row['School Status'])

# Assign list
zones_educ_df['School Status'] = status_list
zones_educ_df.head(5)
#display(zones_educ_df)
# Out:
#                                      Neighborhood Name  \
# Neighborhood ID
# 1                                             el Raval
# 2                                       el Barri Gòtic
# 3                                       la Barceloneta
# 4                Sant Pere, Santa Caterina i la Ribera
# 5                                        el Fort Pienc
#
#                 District Name Associated  Number of Services Distances  \
# Neighborhood ID
# 1                           Ciutat Vella                  45       NaN
# 2                           Ciutat Vella                  13       NaN
# 3                           Ciutat Vella                  23       NaN
# 4                           Ciutat Vella                  35       NaN
# 5                               Eixample                  19       NaN
#
#                 Density over Places Ratio Avg. Students per Teacher Ratio  \
# Neighborhood ID
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
# 5                                     NaN                             NaN
#
#                             School Status Centers Type Centers Simple Type  \
# Neighborhood ID
# 1                         public, charter          NaN                 NaN
# 2                         public, charter          NaN                 NaN
# 3                                  public          NaN                 NaN
# 4                         public, charter          NaN                 NaN
# 5                private, public, charter          NaN                 NaN
#
#                 Centers Characteristics  ...  \
# Neighborhood ID                          ...
# 1                                   NaN  ...
# 2                                   NaN  ...
# 3                                   NaN  ...
# 4                                   NaN  ...
# 5                                   NaN  ...
#
#                 Middle Studies in people older than 15 (%)  \
# Neighborhood ID
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
#
#                 Higher Studies in people older than 15 (%)  \
# Neighborhood ID
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
#
#                 No education or Incomplete Primary School in people older than 15 (%)  \
# Neighborhood ID
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
# 5                                                              NaN
#
#                 Young Population without Post-Compulsory Education (%)  \
# Neighborhood ID
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
# 5                                                              NaN
#
#                 Abscence Rate in 4th Grade (%)  \
# Neighborhood ID
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
#
#                 Graduation Rate in 4th Grade (%)  \
# Neighborhood ID
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
#
#                 Territorial Socioeconomic Index (IST) Avg. Gini Index (%)  \
# Neighborhood ID
# 1                                                78.2              34.495
# 2                                                75.6              39.133
# 3                                                95.8              33.636
# 4                                               100.8              37.031
# 5                                               111.0              32.475
#
#                 Population Density (hab/ha)  \
# Neighborhood ID
# 1                                       429
# 2                                       268
# 3                                       124
# 4                                       199
# 5                                       336
#
#                 Net Population Density (hab/residential ha)
# Neighborhood ID
# 1                                                       952
# 2                                                       639
# 3                                                      1081
# 4                                                       683
# 5                                                       930
#
# [5 rows x 24 columns]

# %%
zones_educ_df['School Status'].unique()
# Out:
# array(['public, charter', 'public', 'private, public, charter',
#        'private, public', 'charter', 'private, charter'], dtype=object)

# %% [markdown]
# ### 1.8 Service Typology (Service Type & Simple Service Type)

# %%
display(cleaned_educ_df)
# Out:
#                                                    Name  Neighborhood ID  \
# 0     Facultat d'Informació i Mitjans Audiovisuals - UB               18
# 1                                    Institut Fort Pius                5
# 2                          Escola Pia de Nostra Senyora                7
# 3                               Institut Salvador Seguí               73
# 4                               Escola de Música Kostka               30
# ...                                                 ...              ...
# 1352           Biblioteca Trinitat Vella - José Barbero               57
# 1353                Biblioteca Poblenou - Manuel Arranz               68
# 1354                      Biblioteca Ramon d'Alòs-Moner               70
# 1355               Biblioteca Poble Sec - Francesc Boix               11
# 1356              Biblioteca Collserola - Josep Miracle               22
#
#                           Neighborhood Name  District ID        District Name  \
# 0                                     Sants            3       Sants-Montjuïc
# 1                             el Fort Pienc            2             Eixample
# 2                    la Dreta de l'Eixample            2             Eixample
# 3                       la Verneda i la Pau           10           Sant Martí
# 4                                  la Salut            6               Gràcia
# ...                                     ...          ...                  ...
# 1352                      la Trinitat Vella            9          Sant Andreu
# 1353                            el Poblenou           10           Sant Martí
# 1354                  el Besòs i el Maresme           10           Sant Martí
# 1355                           el Poble Sec            3       Sants-Montjuïc
# 1356  Vallvidrera, el Tibidabo i les Planes            5  Sarrià-Sant Gervasi
#
#       ZipCode           Service Type   Simple Service Type   Latitude  \
# 0        8014             University            University  41.381286
# 1        8013       Secondary School           High School  41.394359
# 2        8007  Secondary School & FP           High School  41.391216
# 3        8020                     FP                    FP  41.423094
# 4        8024           Music School          Music School  41.414357
# ...       ...                    ...                   ...        ...
# 1352        0   Library & Study Room  Library & Study Room  41.449283
# 1353        0   Library & Study Room  Library & Study Room  41.401373
# 1354        0   Library & Study Room  Library & Study Room  41.416309
# 1355        0   Library & Study Room  Library & Study Room  41.373922
# 1356        0   Library & Study Room  Library & Study Room  41.415359
#
#       Longitude
# 0      2.138788
# 1      2.179807
# 2      2.167916
# 3      2.196790
# 4      2.157240
# ...         ...
# 1352   2.190749
# 1353   2.204526
# 1354   2.211483
# 1355   2.164025
# 1356   2.102529
#
# [1357 rows x 10 columns]

# %%
# SERVICE TYPE
# Group by 'Neighborhood ID', include unique values for 'Service Type'
neighborhood_type_df = cleaned_educ_df.groupby('Neighborhood ID')['Service Type'].apply(lambda x: ', '.join(x.unique()))
# Reset idx values
neighborhood_type_df = neighborhood_type_df.reset_index()
neighborhood_type_df = neighborhood_type_df[neighborhood_type_df['Neighborhood ID'] != 0]

display(neighborhood_type_df)
# Out:
#     Neighborhood ID                                       Service Type
# 1                 1  Kindergarten & Primary School, University, Kin...
# 2                 2  FP, Kindergarten & Primary School, University,...
# 3                 3  Secondary School, University, Kindergarten & P...
# 4                 4  Kindergarten & Primary School, Secondary Schoo...
# 5                 5  Secondary School, Kindergarten & Primary Schoo...
# ..              ...                                                ...
# 69               69  Kindergarten, Primary & Secondary School, FP, ...
# 70               70  Kindergarten & Primary School, Secondary Schoo...
# 71               71  Kindergarten & Primary School, University, Inf...
# 72               72  Kindergarten & Primary School, Kindergarten, P...
# 73               73  FP, Kindergarten & Primary School, Secondary S...
#
# [73 rows x 2 columns]

# %%
# SIMPLE SERVICE TYPE
# Group by 'Neighborhood ID', include unique values for 'Service Type'
neighborhood_simple_type_df = cleaned_educ_df.groupby('Neighborhood ID')['Simple Service Type'].apply(lambda x: ', '.join(x.unique()))
# Reset idx values
neighborhood_simple_type_df = neighborhood_simple_type_df.reset_index()
neighborhood_simple_type_df = neighborhood_simple_type_df[neighborhood_simple_type_df['Neighborhood ID'] != 0]

display(neighborhood_simple_type_df)
# Out:
#     Neighborhood ID                                Simple Service Type
# 1                 1  Kindergarten & Primary School, University, Gen...
# 2                 2  FP, Kindergarten & Primary School, University,...
# 3                 3  High School, University, Kindergarten & Primar...
# 4                 4  Kindergarten & Primary School, High School, Mu...
# 5                 5  High School, Kindergarten & Primary School, Ge...
# ..              ...                                                ...
# 69               69  General School (with kindergarten), FP, Kinder...
# 70               70  Kindergarten & Primary School, High School, Un...
# 71               71  Kindergarten & Primary School, University, Inf...
# 72               72  Kindergarten & Primary School, General School ...
# 73               73  FP, Kindergarten & Primary School, High School...
#
# [73 rows x 2 columns]

# %%
zones_educ_df['Centers Type'] = neighborhood_type_df['Service Type']
zones_educ_df['Centers Simple Type'] = neighborhood_simple_type_df['Simple Service Type']
zones_educ_df.head(7)
# Out:
#                                      Neighborhood Name  \
# Neighborhood ID
# 1                                             el Raval
# 2                                       el Barri Gòtic
# 3                                       la Barceloneta
# 4                Sant Pere, Santa Caterina i la Ribera
# 5                                        el Fort Pienc
# 6                                   la Sagrada Família
# 7                               la Dreta de l'Eixample
#
#                 District Name Associated  Number of Services Distances  \
# Neighborhood ID
# 1                           Ciutat Vella                  45       NaN
# 2                           Ciutat Vella                  13       NaN
# 3                           Ciutat Vella                  23       NaN
# 4                           Ciutat Vella                  35       NaN
# 5                               Eixample                  19       NaN
# 6                               Eixample                  24       NaN
# 7                               Eixample                  75       NaN
#
#                 Density over Places Ratio Avg. Students per Teacher Ratio  \
# Neighborhood ID
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
# 5                                     NaN                             NaN
# 6                                     NaN                             NaN
# 7                                     NaN                             NaN
#
#                             School Status  \
# Neighborhood ID
# 1                         public, charter
# 2                         public, charter
# 3                                  public
# 4                         public, charter
# 5                private, public, charter
# 6                private, public, charter
# 7                         public, charter
#
#                                                       Centers Type  \
# Neighborhood ID
# 1                Kindergarten & Primary School, University, Kin...
# 2                FP, Kindergarten & Primary School, University,...
# 3                Secondary School, University, Kindergarten & P...
# 4                Kindergarten & Primary School, Secondary Schoo...
# 5                Secondary School, Kindergarten & Primary Schoo...
# 6                Kindergarten & Primary School, Music School, F...
# 7                Secondary School & FP, Kindergarten, Primary &...
#
#                                                Centers Simple Type  \
# Neighborhood ID
# 1                Kindergarten & Primary School, University, Gen...
# 2                FP, Kindergarten & Primary School, University,...
# 3                High School, University, Kindergarten & Primar...
# 4                Kindergarten & Primary School, High School, Mu...
# 5                High School, Kindergarten & Primary School, Ge...
# 6                Kindergarten & Primary School, Music School, F...
# 7                High School, General School (with kindergarten...
#
#                 Centers Characteristics  ...  \
# Neighborhood ID                          ...
# 1                                   NaN  ...
# 2                                   NaN  ...
# 3                                   NaN  ...
# 4                                   NaN  ...
# 5                                   NaN  ...
# 6                                   NaN  ...
# 7                                   NaN  ...
#
#                 Middle Studies in people older than 15 (%)  \
# Neighborhood ID
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7                                                      NaN
#
#                 Higher Studies in people older than 15 (%)  \
# Neighborhood ID
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7                                                      NaN
#
#                 No education or Incomplete Primary School in people older than 15 (%)  \
# Neighborhood ID
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
# 5                                                              NaN
# 6                                                              NaN
# 7                                                              NaN
#
#                 Young Population without Post-Compulsory Education (%)  \
# Neighborhood ID
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
# 5                                                              NaN
# 6                                                              NaN
# 7                                                              NaN
#
#                 Abscence Rate in 4th Grade (%)  \
# Neighborhood ID
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
#
#                 Graduation Rate in 4th Grade (%)  \
# Neighborhood ID
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
#
#                 Territorial Socioeconomic Index (IST) Avg. Gini Index (%)  \
# Neighborhood ID
# 1                                                78.2              34.495
# 2                                                75.6              39.133
# 3                                                95.8              33.636
# 4                                               100.8              37.031
# 5                                               111.0              32.475
# 6                                               111.8              32.700
# 7                                               120.9              36.697
#
#                 Population Density (hab/ha)  \
# Neighborhood ID
# 1                                       429
# 2                                       268
# 3                                       124
# 4                                       199
# 5                                       336
# 6                                       493
# 7                                       211
#
#                 Net Population Density (hab/residential ha)
# Neighborhood ID
# 1                                                       952
# 2                                                       639
# 3                                                      1081
# 4                                                       683
# 5                                                       930
# 6                                                      1007
# 7                                                       392
#
# [7 rows x 24 columns]

# %% [markdown]
# ### 1.9 Places Offer

# %%
# Dataset Files
places_offer_file = "/Users/mariatormo02/Desktop/TFG-Code/Data/Education Index Data/Oferta_inicial_de_places_escolars_dels_estudis_obligatoris_20240402.csv"

encoded = detect_encoding(places_offer_file)
print(encoded)

# Read CSV
places_offer_df = pd.read_csv(places_offer_file, encoding='utf-8')
# Out:
# utf-8

# %%
places_offer_df.columns
# Out:
# Index(['Curs', 'Codi centre', 'Denominació completa', 'Codi naturalesa',
#        'Nom naturalesa', 'Codi titularitat', 'Nom titularitat',
#        'Codi delegació', 'Nom delegació', 'Codi comarca', 'Nom comarca',
#        'Codi municipi_6', 'Nom municipi', 'Codi districte municipal', 'Nom DM',
#        'Coordenades_GEO_X', 'Coordenades_GEO_Y', 'Codi ensenyament',
#        'Nom ensenyament', 'Nivell', 'Nombre grups', 'Mixt', 'Nombre places',
#        'Places ofertades a la preinscripció', 'Georeferència'],
#       dtype='object')

# %%
places_offer_df = places_offer_df.drop(columns={'Codi naturalesa', 'Nom naturalesa', 'Codi titularitat', 'Codi delegació', 'Codi comarca',
                                                'Codi municipi_6', 'Codi ensenyament', 'Nivell', 'Nombre grups', 'Mixt', 'Georeferència'})

places_offer_df.rename(columns={'Codi centre': 'ID', 'Denominació completa': 'Name', 'Nom titularitat': 'Ownership', 'Nom delegació': 'Delegation Name',
                                'Nom comarca': 'Region Name', 'Nom municipi': 'Town Name', 'Codi districte municipal': 'District ID',
                                'Nom DM': 'District Name', 'Coordenades_GEO_X': 'Longitude', 'Coordenades_GEO_Y': 'Latitude',
                                'Nombre places': 'Number of Places', 'Places ofertades a la preinscripció': 'Places Offered'}, inplace=True)
places_offer_df.head(7)
# Out:
#         Curs        ID                                           Name  \
# 0  2024/2025  43008419                              Institut Camarles
# 1  2024/2025  25001126                   Escola Vallmajor - ZER Elaia
# 2  2024/2025  25001001         Escola Sant Bartomeu - ZER Espernallac
# 3  2024/2025  17006769                             Institut de Llançà
# 4  2024/2025  25004036                                 Escola L'Estel
# 5  2024/2025  43005005                       Escola Sant Bernat Calvó
# 6  2024/2025  43001395  Escola Teresa Subirats i Mestre - ZER Montsià
#
#                 Ownership   Delegation Name  Region Name  \
# 0  Departament d'Educació  Terres de l'Ebre    Baix Ebre
# 1  Departament d'Educació            Lleida    Garrigues
# 2  Departament d'Educació            Lleida      Noguera
# 3  Departament d'Educació            Girona  Alt Empordà
# 4  Departament d'Educació            Lleida      Segarra
# 5  Departament d'Educació         Tarragona   Tarragonès
# 6  Departament d'Educació  Terres de l'Ebre      Montsià
#
#                 Town Name  District ID District Name  Longitude   Latitude  \
# 0                Camarles            0           NaN   0.658462  40.765611
# 1                  Bovera            0           NaN   0.638488  41.325428
# 2       Bellmunt d'Urgell            0           NaN   0.953486  41.773514
# 3                  Llançà            0           NaN   3.153030  42.359094
# 4  Sant Guim de Freixenet            0           NaN   1.420193  41.657002
# 5               Vila-seca            0           NaN   1.147857  41.111652
# 6        Mas de Barberans            0           NaN   0.374205  40.736972
#
#                    Nom ensenyament  Number of Places  Places Offered
# 0  Educació secundària obligatòria                90              90
# 1                Educació primària                 2               0
# 2                Educació primària                 0               0
# 3  Educació secundària obligatòria                90               0
# 4                Educació primària                25               9
# 5     Educació infantil: Parvulari                19              19
# 6                Educació primària                 5               1

# %%
places_offer_df = places_offer_df[places_offer_df['Town Name'] == 'Barcelona']
places_offer_df.head()
# Out:
#            Curs       ID                       Name  \
# 1400  2024/2025  8077095    Institut Escola Mirades
# 1787  2024/2025  8054848  Institut Bosc de Montjuïc
# 1808  2024/2025  8043747               Escola Baloo
# 1809  2024/2025  8036469                     Urgell
# 1868  2024/2025  8007494            Sagrada Família
#
#                          Ownership                   Delegation Name  \
# 1400        Departament d'Educació  Consorci d'Educació de Barcelona
# 1787           Corporacions Locals  Consorci d'Educació de Barcelona
# 1808        Departament d'Educació  Consorci d'Educació de Barcelona
# 1809  Altres Confesions Religioses  Consorci d'Educació de Barcelona
# 1868                    Fundacions  Consorci d'Educació de Barcelona
#
#      Region Name  Town Name  District ID     District Name  Longitude  \
# 1400  Barcelonès  Barcelona            7  Horta - Guinardó   2.152905
# 1787  Barcelonès  Barcelona            3  Sants - Montjuïc   2.161387
# 1808  Barcelonès  Barcelona            7  Horta - Guinardó   2.140470
# 1809  Barcelonès  Barcelona            2          Eixample   2.153131
# 1868  Barcelonès  Barcelona            9       Sant Andreu   2.186580
#
#        Latitude                  Nom ensenyament  Number of Places  \
# 1400  41.426163     Educació infantil: Parvulari                40
# 1787  41.368973  Educació secundària obligatòria                60
# 1808  41.433634                Educació primària                25
# 1809  41.386032     Educació infantil: Parvulari                22
# 1868  41.438809                Educació primària                75
#
#       Places Offered
# 1400               0
# 1787              60
# 1808               0
# 1809              22
# 1868               0

# %%
cleaned_educ_df.head()
# Out:
#                                                 Name  Neighborhood ID  \
# 0  Facultat d'Informació i Mitjans Audiovisuals - UB               18
# 1                                 Institut Fort Pius                5
# 2                       Escola Pia de Nostra Senyora                7
# 3                            Institut Salvador Seguí               73
# 4                            Escola de Música Kostka               30
#
#         Neighborhood Name  District ID   District Name  ZipCode  \
# 0                   Sants            3  Sants-Montjuïc     8014
# 1           el Fort Pienc            2        Eixample     8013
# 2  la Dreta de l'Eixample            2        Eixample     8007
# 3     la Verneda i la Pau           10      Sant Martí     8020
# 4                la Salut            6          Gràcia     8024
#
#             Service Type Simple Service Type   Latitude  Longitude
# 0             University          University  41.381286   2.138788
# 1       Secondary School         High School  41.394359   2.179807
# 2  Secondary School & FP         High School  41.391216   2.167916
# 3                     FP                  FP  41.423094   2.196790
# 4           Music School        Music School  41.414357   2.157240

# %% [markdown]
# #### Compare Centres in places dataset and cleaned dataset

# %%
print(cleaned_educ_df.shape)
print(places_offer_df.shape)
# Out:
# (1357, 10)
# (14849, 14)

# %%
# Select School Names with nearest year (appear for diverse years)
reference_year = 2024
# Get first year as int
places_offer_df['Year'] = places_offer_df['Curs'].str.split("/").str[0].astype(int)
rows = []
names_places = set(places_offer_df['Name'])

for name in names_places:
    sub_df = places_offer_df[places_offer_df['Name'] == name]
    sub_df['YearDiff'] = abs(sub_df['Year'] - reference_year)
    nearest_row = sub_df.loc[sub_df['YearDiff'].idxmin()]
    rows.append(nearest_row)


# Step 4: Create a new DataFrame from the filtered rows
filtered_places_offer_df = pd.DataFrame(rows).drop(columns=['Year', 'YearDiff']).reset_index(drop=True)

# Print the filtered DataFrame to verify
places_offer_df = filtered_places_offer_df
places_offer_df = places_offer_df.drop(columns={'Curs', 'ID', 'Delegation Name', 'Region Name', 'Town Name', 'Nom ensenyament'})
places_offer_df.head()
# Out:
#                  Name                       Ownership  District ID  \
# 0  Escola Rubén Darío          Departament d'Educació            1
# 1              Claret  Ordes i Congregacions Catòlics            6
# 2  Institut La Sedeta          Departament d'Educació            6
# 3   Montseny-Poblenou                    Cooperatives           10
# 4        Joan Pelegrí                      Fundacions            3
#
#       District Name  Longitude   Latitude  Number of Places  Places Offered
# 0      Ciutat vella   2.165736  41.376907                21               0
# 1            Gràcia   2.167221  41.406086                90               0
# 2            Gràcia   2.168345  41.405210                90              89
# 3        Sant Martí   2.210654  41.410702                50              50
# 4  Sants - Montjuïc   2.144470  41.375795               180               7

# %%
print(cleaned_educ_df.shape)
print(places_offer_df.shape)
# Out:
# (1357, 10)
# (430, 8)

# %%
def get_best_match(row, choices, scorer, cutoff=80):
    name = row['Name']
    match, score = process.extractOne(name, choices, scorer=scorer)
    return match if score >= cutoff else None

# %%
# Assign Neighborhoods using Cleaned Dataset

# Apply the fuzzy matching function to the second dataset
choices = cleaned_educ_df['Name'].tolist()
places_offer_df['Matched_Name'] = places_offer_df.apply(get_best_match, axis=1, choices=choices, scorer=fuzz.partial_ratio)

# Merge with the neighborhood information using the matched names
places_merged_df = places_offer_df.merge(cleaned_educ_df[['Name', 'Neighborhood Name']],
                             left_on='Matched_Name', right_on='Name', how='left')

# Drop the 'Matched_Name' column as it is no longer needed
places_merged_df.drop(columns=['Matched_Name'], inplace=True)

#  Rename and drop
places_merged_df.rename(columns={'Name_x': 'Original Name', 'Name_y': 'Mapped Name', 'Neighborhood Name_y': 'Neighborhood Name'}, inplace=True)

# Display the merged DataFrame
display(places_merged_df)
# Out:
#                   Original Name                       Ownership  District ID  \
# 0            Escola Rubén Darío          Departament d'Educació            1
# 1                        Claret  Ordes i Congregacions Catòlics            6
# 2            Institut La Sedeta          Departament d'Educació            6
# 3             Montseny-Poblenou                    Cooperatives           10
# 4                  Joan Pelegrí                      Fundacions            3
# ..                          ...                             ...          ...
# 425             Escola Arc Iris             Corporacions Locals            7
# 426  Institut Menéndez y Pelayo          Departament d'Educació            5
# 427      Escola Sagrada Família          Departament d'Educació            6
# 428     Institut Escola Londres          Departament d'Educació            2
# 429            Escola Barcelona          Departament d'Educació            4
#
#              District Name  Longitude   Latitude  Number of Places  \
# 0             Ciutat vella   2.165736  41.376907                21
# 1                   Gràcia   2.167221  41.406086                90
# 2                   Gràcia   2.168345  41.405210                90
# 3               Sant Martí   2.210654  41.410702                50
# 4         Sants - Montjuïc   2.144470  41.375795               180
# ..                     ...        ...        ...               ...
# 425       Horta - Guinardó   2.171432  41.425240                20
# 426  Sarrià - Sant Gervasi   2.144640  41.399960               120
# 427                 Gràcia   2.171171  41.404879                60
# 428               Eixample   2.147038  41.391028                50
# 429              Les Corts   2.132017  41.381966                50
#
#      Places Offered                        Mapped Name  \
# 0                 0                 Escola Rubén Darío
# 1                 0             Centre Educatiu Claret
# 2                89                 Institut La Sedeta
# 3                50  Centre Educatiu Montseny-Poblenou
# 4                 7       Centre Educatiu Joan Pelegrí
# ..              ...                                ...
# 425              20                    Escola Arc Iris
# 426               0         Institut Menéndez y Pelayo
# 427               3   Escola Sagrada Família *Sardenya
# 428              26            Institut Escola Londres
# 429               0                   Escola Barcelona
#
#                                 Neighborhood Name
# 0                                        el Raval
# 1              el Camp d'en Grassot i Gràcia Nova
# 2              el Camp d'en Grassot i Gràcia Nova
# 3    Diagonal Mar i el Front Marítim del Poblenou
# 4                                     Hostafrancs
# ..                                            ...
# 425                          la Font d'en Fargues
# 426                        Sant Gervasi - Galvany
# 427            el Camp d'en Grassot i Gràcia Nova
# 428               l'Antiga Esquerra de l'Eixample
# 429                                     les Corts
#
# [430 rows x 10 columns]

# %%
zones_educ_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73 entries, 1 to 73
# Data columns (total 24 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   Neighborhood Name                                                      73 non-null     object
#  1   District Name Associated                                               73 non-null     object
#  2   Number of Services                                                     73 non-null     int64
#  3   Distances                                                              0 non-null      object
#  4   Density over Places Ratio                                              0 non-null      object
#  5   Avg. Students per Teacher Ratio                                        0 non-null      object
#  6   School Status                                                          73 non-null     object
#  7   Centers Type                                                           73 non-null     object
#  8   Centers Simple Type                                                    73 non-null     object
#  9   Centers Characteristics                                                0 non-null      object
#  10  Population with Low Studies (%)                                        0 non-null      object
#  11  Total Number of Students                                               0 non-null      object
#  12  Primary School in people older than 15 (%)                             0 non-null      object
#  13  Secondary School in people older than 15 (%)                           0 non-null      object
#  14  Middle Studies in people older than 15 (%)                             0 non-null      object
#  15  Higher Studies in people older than 15 (%)                             0 non-null      object
#  16  No education or Incomplete Primary School in people older than 15 (%)  0 non-null      object
#  17  Young Population without Post-Compulsory Education (%)                 0 non-null      object
#  18  Abscence Rate in 4th Grade (%)                                         0 non-null      object
#  19  Graduation Rate in 4th Grade (%)                                       0 non-null      object
#  20  Territorial Socioeconomic Index (IST)                                  73 non-null     float64
#  21  Avg. Gini Index (%)                                                    73 non-null     float64
#  22  Population Density (hab/ha)                                            73 non-null     int64
#  23  Net Population Density (hab/residential ha)                            73 non-null     int64
# dtypes: float64(2), int64(3), object(19)
# memory usage: 14.3+ KB

# %%
# GROUP BY NEIGHBORHOOD

# Count Schools from dataframe for each neighborhood (add places)
neighborhood_places = places_merged_df.groupby('Neighborhood Name')['Number of Places'].sum().reset_index()

# Rename the 'Number of Places' column in neighborhood_places to avoid conflict
neighborhood_places = neighborhood_places.rename(columns={'Number of Places': 'Total Number of Places'})

# Update the 'Density over Places Ratio' column in zones_educ_df
zones_educ_df = zones_educ_df.merge(neighborhood_places, on='Neighborhood Name', how='left')

# If you need the new column to be named 'Number of Places', you can rename it back
zones_educ_df = zones_educ_df.rename(columns={'Total Number of Places': 'Number of Places'})
zones_educ_df['Density over Places Ratio'] = zones_educ_df['Population Density (hab/ha)']/zones_educ_df['Number of Places']
zones_educ_df['Density over Places Ratio'] = zones_educ_df['Density over Places Ratio'].round(3)
zones_educ_df.index = zones_educ_df.index + 1
display(zones_educ_df)
# Out:
#                                Neighborhood Name District Name Associated  \
# 1                                       el Raval             Ciutat Vella
# 2                                 el Barri Gòtic             Ciutat Vella
# 3                                 la Barceloneta             Ciutat Vella
# 4          Sant Pere, Santa Caterina i la Ribera             Ciutat Vella
# 5                                  el Fort Pienc                 Eixample
# ..                                           ...                      ...
# 69  Diagonal Mar i el Front Marítim del Poblenou               Sant Martí
# 70                         el Besòs i el Maresme               Sant Martí
# 71                       Provençals del Poblenou               Sant Martí
# 72                      Sant Martí de Provençals               Sant Martí
# 73                           la Verneda i la Pau               Sant Martí
#
#     Number of Services Distances  Density over Places Ratio  \
# 1                   45       NaN                      1.005
# 2                   13       NaN                      1.686
# 3                   23       NaN                      0.697
# 4                   35       NaN                      0.711
# 5                   19       NaN                      1.116
# ..                 ...       ...                        ...
# 69                   7       NaN                      1.090
# 70                  13       NaN                      0.601
# 71                  17       NaN                      1.237
# 72                  19       NaN                      0.579
# 73                  15       NaN                      1.454
#
#    Avg. Students per Teacher Ratio             School Status  \
# 1                              NaN           public, charter
# 2                              NaN           public, charter
# 3                              NaN                    public
# 4                              NaN           public, charter
# 5                              NaN  private, public, charter
# ..                             ...                       ...
# 69                             NaN           public, charter
# 70                             NaN           public, charter
# 71                             NaN           public, charter
# 72                             NaN           public, charter
# 73                             NaN           public, charter
#
#                                          Centers Type  \
# 1   Kindergarten & Primary School, University, Kin...
# 2   FP, Kindergarten & Primary School, University,...
# 3   Secondary School, University, Kindergarten & P...
# 4   Kindergarten & Primary School, Secondary Schoo...
# 5   Secondary School, Kindergarten & Primary Schoo...
# ..                                                ...
# 69  Kindergarten, Primary & Secondary School, FP, ...
# 70  Kindergarten & Primary School, Secondary Schoo...
# 71  Kindergarten & Primary School, University, Inf...
# 72  Kindergarten & Primary School, Kindergarten, P...
# 73  FP, Kindergarten & Primary School, Secondary S...
#
#                                   Centers Simple Type Centers Characteristics  \
# 1   Kindergarten & Primary School, University, Gen...                     NaN
# 2   FP, Kindergarten & Primary School, University,...                     NaN
# 3   High School, University, Kindergarten & Primar...                     NaN
# 4   Kindergarten & Primary School, High School, Mu...                     NaN
# 5   High School, Kindergarten & Primary School, Ge...                     NaN
# ..                                                ...                     ...
# 69  General School (with kindergarten), FP, Kinder...                     NaN
# 70  Kindergarten & Primary School, High School, Un...                     NaN
# 71  Kindergarten & Primary School, University, Inf...                     NaN
# 72  Kindergarten & Primary School, General School ...                     NaN
# 73  FP, Kindergarten & Primary School, High School...                     NaN
#
#     ... Higher Studies in people older than 15 (%)  \
# 1   ...                                        NaN
# 2   ...                                        NaN
# 3   ...                                        NaN
# 4   ...                                        NaN
# 5   ...                                        NaN
# ..  ...                                        ...
# 69  ...                                        NaN
# 70  ...                                        NaN
# 71  ...                                        NaN
# 72  ...                                        NaN
# 73  ...                                        NaN
#
#    No education or Incomplete Primary School in people older than 15 (%)  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# ..                                                ...
# 69                                                NaN
# 70                                                NaN
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
#
#    Young Population without Post-Compulsory Education (%)  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# ..                                                ...
# 69                                                NaN
# 70                                                NaN
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
#
#    Abscence Rate in 4th Grade (%) Graduation Rate in 4th Grade (%)  \
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             NaN                              NaN
# ..                            ...                              ...
# 69                            NaN                              NaN
# 70                            NaN                              NaN
# 71                            NaN                              NaN
# 72                            NaN                              NaN
# 73                            NaN                              NaN
#
#    Territorial Socioeconomic Index (IST) Avg. Gini Index (%)  \
# 1                                   78.2              34.495
# 2                                   75.6              39.133
# 3                                   95.8              33.636
# 4                                  100.8              37.031
# 5                                  111.0              32.475
# ..                                   ...                 ...
# 69                                 116.6              31.814
# 70                                  72.4              29.715
# 71                                 107.0              29.242
# 72                                 102.9              27.361
# 73                                  96.0              27.129
#
#    Population Density (hab/ha) Net Population Density (hab/residential ha)  \
# 1                          429                                         952
# 2                          268                                         639
# 3                          124                                        1081
# 4                          199                                         683
# 5                          336                                         930
# ..                         ...                                         ...
# 69                         109                                         556
# 70                         212                                         913
# 71                         193                                        1368
# 72                         355                                        1111
# 73                         253                                         714
#
#    Number of Places
# 1             427.0
# 2             159.0
# 3             178.0
# 4             280.0
# 5             301.0
# ..              ...
# 69            100.0
# 70            353.0
# 71            156.0
# 72            613.0
# 73            174.0
#
# [73 rows x 25 columns]

# %% [markdown]
# ### 1.10 Center Characteristics

# %% [markdown]
# 1.10.1 Religious

# %%
places_offer_df['Ownership'].unique()
# Out:
# array(["Departament d'Educació", 'Ordes i Congregacions Catòlics',
#        'Cooperatives', 'Fundacions', 'Societats Mercantils',
#        'Corporacions Locals', 'Persones Físiques', 'Associacions',
#        'Altres Confesions Religioses', 'Església Catòlica'], dtype=object)

# %%
religious_df = pd.DataFrame(places_offer_df)
religious_df = religious_df.drop(columns={'Latitude', 'Longitude', 'Number of Places', 'Places Offered'})
religious_df = religious_df[religious_df['Ownership'] != "Departament d'Educació"]
religious_df = religious_df[religious_df['Ownership'] != "Corporacions Locals"]
religious_df = religious_df[religious_df['Ownership'] != "Persones Físiques"]
religious_df = religious_df[religious_df['Ownership'] != "Cooperatives"]
religious_df = religious_df[religious_df['Ownership'] != "Associacions"]
religious_df = religious_df[religious_df['Ownership'] != "Altres Confesions Religioses"]

# Exclude Particular Schools from Fundacions Category:
religious_df = religious_df[religious_df['Name'] != 'Mary Ward']
religious_df = religious_df[religious_df['Name'] != 'Decroly']
religious_df = religious_df[religious_df['Name'] != 'Sadako']
religious_df = religious_df[religious_df['Name'] != 'Santísima Trinidad']
religious_df = religious_df[religious_df['Name'] != 'Galí Bellesguard']
religious_df = religious_df[religious_df['Name'] != 'Sopeña Barcelona']
religious_df = religious_df[religious_df['Name'] != 'Frederic Mistral-Tècnic Eulàlia']
religious_df = religious_df[religious_df['Name'] != 'Santa Anna-Eixample']
religious_df = religious_df[religious_df['Name'] != 'Bon Pastor']
religious_df = religious_df[religious_df['Name'] != 'Thau']
religious_df = religious_df[religious_df['Name'] != 'Sant Gregori']
religious_df = religious_df[religious_df['Name'] != 'Santíssima Trinitat']
religious_df = religious_df[religious_df['Name'] != 'El Petit Santa Maria']
religious_df = religious_df[religious_df['Name'] != 'Sagrada Família']
religious_df = religious_df[religious_df['Name'] != 'Voramar']
religious_df = religious_df[religious_df['Name'] != 'Sant Felip Neri']
religious_df = religious_df[religious_df['Name'] != 'Sant Medir']
religious_df = religious_df[religious_df['Name'] != 'Santa Teresa de Lisieux']
religious_df = religious_df[religious_df['Name'] != 'Mare de Déu del Roser Les Planes']
religious_df = religious_df[religious_df['Name'] != 'Peter Pan']
religious_df = religious_df[religious_df['Name'] != 'Joan Pelegrí']
religious_df = religious_df[religious_df['Name'] != "L'Horitzó"]
religious_df = religious_df[religious_df['Name'] != 'Nausica']
religious_df = religious_df[religious_df['Name'] != 'Centre Educatiu Projecte']

# Exclude particular schools of Socetats Mercantils Ownership:
religious_df = religious_df[religious_df['Name'] != 'Virolai']
religious_df = religious_df[religious_df['Name'] != 'Grimm']
religious_df = religious_df[religious_df['Name'] != 'Garbiñe']
religious_df = religious_df[religious_df['Name'] != 'Grey']
religious_df = religious_df[religious_df['Name'] != 'San Rafael']
religious_df = religious_df[religious_df['Name'] != 'Mireia']
religious_df = religious_df[religious_df['Name'] != 'Súnion']
religious_df = religious_df[religious_df['Name'] != 'Joan Roca Guipúzcoa']
religious_df = religious_df[religious_df['Name'] != 'Sant Ferran']
religious_df = religious_df[religious_df['Name'] != 'Reina Elisenda']
religious_df = religious_df[religious_df['Name'] != 'Molina']
religious_df = religious_df[religious_df['Name'] != 'Lloret']
religious_df = religious_df[religious_df['Name'] != 'Laia']
religious_df = religious_df[religious_df['Name'] != 'Aloma']
religious_df = religious_df[religious_df['Name'] != 'Ramon Llull']
religious_df = religious_df[religious_df['Name'] != 'Alfageme']
religious_df = religious_df[religious_df['Name'] != 'Mare de Déu de Núria']
religious_df = religious_df[religious_df['Name'] != 'Sant Francesc Xavier']
religious_df = religious_df[religious_df['Name'] != 'Lleó XIII']
religious_df = religious_df[religious_df['Name'] != 'Palcam']
religious_df = religious_df[religious_df['Name'] != 'Closa']
religious_df = religious_df[religious_df['Name'] != 'Roca']
religious_df = religious_df[religious_df['Name'] != 'Monlau']
religious_df = religious_df[religious_df['Name'] != 'IPSI']
religious_df = religious_df[religious_df['Name'] != "L'Esclop-Passeig"]
religious_df = religious_df[religious_df['Name'] != 'John Talabot']
religious_df = religious_df[religious_df['Name'] != 'Camí']
religious_df = religious_df[religious_df['Name'] != 'Sant Marc de Sarrià']
religious_df = religious_df[religious_df['Name'] != 'Castro de la Peña']
religious_df = religious_df[religious_df['Name'] != 'Joan Roca 1953']
religious_df = religious_df[religious_df['Name'] != 'Miró']
religious_df = religious_df[religious_df['Name'] != 'Sant Lluís']
religious_df = religious_df[religious_df['Name'] != 'Sant Pau']

# %%
religious_df.head()
# Out:
#                                Name                       Ownership  \
# 1                            Claret  Ordes i Congregacions Catòlics
# 5              Sagrat Cor-Diputació                      Fundacions
# 12      FEP Santa Teresa de Lisieux                      Fundacions
# 16  Padre Damián Sagrados Corazones  Ordes i Congregacions Catòlics
# 18                        Valldaura                      Fundacions
#
#     District ID          District Name  \
# 1             6                 Gràcia
# 5             2               Eixample
# 12            4              Les Corts
# 16            5  Sarrià - Sant Gervasi
# 18            8             Nou Barris
#
#                                        Matched_Name
# 1                            Centre Educatiu Claret
# 5              Centre Educatiu Sagrat Cor-Diputació
# 12      Centre Educatiu FEP Santa Teresa de Lisieux
# 16  Centre Educatiu Padre Damián Sagrados Corazones
# 18                        Centre Educatiu Valldaura

# %%
religious_df.reset_index()
religious_df.head()
# Out:
#                                Name                       Ownership  \
# 1                            Claret  Ordes i Congregacions Catòlics
# 5              Sagrat Cor-Diputació                      Fundacions
# 12      FEP Santa Teresa de Lisieux                      Fundacions
# 16  Padre Damián Sagrados Corazones  Ordes i Congregacions Catòlics
# 18                        Valldaura                      Fundacions
#
#     District ID          District Name  \
# 1             6                 Gràcia
# 5             2               Eixample
# 12            4              Les Corts
# 16            5  Sarrià - Sant Gervasi
# 18            8             Nou Barris
#
#                                        Matched_Name
# 1                            Centre Educatiu Claret
# 5              Centre Educatiu Sagrat Cor-Diputació
# 12      Centre Educatiu FEP Santa Teresa de Lisieux
# 16  Centre Educatiu Padre Damián Sagrados Corazones
# 18                        Centre Educatiu Valldaura

# %% [markdown]
# #### Add neighborhood ID corresponding to each school in dataset

# %%
schools_neighborhood_df = cleaned_educ_df.drop(columns={'Neighborhood ID', 'ZipCode', 'Service Type', 'Simple Service Type', 'Latitude', 'Longitude'})
schools_neighborhood_df.rename(columns={'District ID': 'District ID 2', 'District Name': 'District Name 2'}, inplace=True)
schools_neighborhood_df.head()
# Out:
#                                                 Name       Neighborhood Name  \
# 0  Facultat d'Informació i Mitjans Audiovisuals - UB                   Sants
# 1                                 Institut Fort Pius           el Fort Pienc
# 2                       Escola Pia de Nostra Senyora  la Dreta de l'Eixample
# 3                            Institut Salvador Seguí     la Verneda i la Pau
# 4                            Escola de Música Kostka                la Salut
#
#    District ID 2 District Name 2
# 0              3  Sants-Montjuïc
# 1              2        Eixample
# 2              2        Eixample
# 3             10      Sant Martí
# 4              6          Gràcia

# %%
# Apply the fuzzy matching function to the second dataset
choices = schools_neighborhood_df['Name'].tolist()
religious_df['Matched_Name'] = religious_df.apply(get_best_match, axis=1, choices=choices, scorer=fuzz.partial_ratio)

# Merge with the neighborhood information using the matched names
merged_df = religious_df.merge(schools_neighborhood_df[['Name', 'Neighborhood Name']],
                             left_on='Matched_Name', right_on='Name', how='left')

# Drop the 'Matched_Name' column as it is no longer needed
merged_df.drop(columns=['Matched_Name'], inplace=True)

#  Rename and drop
#merged_df.drop(columns={'Neighborhood Name_x'}, inplace=True)
merged_df.rename(columns={'Name_x': 'Original Name', 'Name_y': 'Mapped Name', 'Neighborhood Name_y': 'Neighborhood Name'}, inplace=True)

# Display the merged DataFrame
display(merged_df)
religious_df = merged_df
# Out:
#                       Original Name                       Ownership  \
# 0                            Claret  Ordes i Congregacions Catòlics
# 1              Sagrat Cor-Diputació                      Fundacions
# 2       FEP Santa Teresa de Lisieux                      Fundacions
# 3   Padre Damián Sagrados Corazones  Ordes i Congregacions Catòlics
# 4                         Valldaura                      Fundacions
# ..                              ...                             ...
# 92                           Canigó            Societats Mercantils
# 93            Santa Teresa de Jesús            Societats Mercantils
# 94            Sagrada Família-Horta  Ordes i Congregacions Catòlics
# 95             Mare del Diví Pastor  Ordes i Congregacions Catòlics
# 96       Maristes Sants - les Corts                      Fundacions
#
#     District ID          District Name  \
# 0             6                 Gràcia
# 1             2               Eixample
# 2             4              Les Corts
# 3             5  Sarrià - Sant Gervasi
# 4             8             Nou Barris
# ..          ...                    ...
# 92            5  Sarrià - Sant Gervasi
# 93            7       Horta - Guinardó
# 94            7       Horta - Guinardó
# 95            2               Eixample
# 96            4              Les Corts
#
#                                          Mapped Name  \
# 0                             Centre Educatiu Claret
# 1               Centre Educatiu Sagrat Cor-Diputació
# 2        Centre Educatiu FEP Santa Teresa de Lisieux
# 3    Centre Educatiu Padre Damián Sagrados Corazones
# 4                          Centre Educatiu Valldaura
# ..                                               ...
# 92                            Centre Educatiu Canigó
# 93  Centre Educatiu Santa Teresa de Jesús *Llobregós
# 94             Centre Educatiu Sagrada Família-Horta
# 95              Centre Educatiu Mare del Diví Pastor
# 96        Centre Educatiu Maristes Sants - Les Corts
#
#                      Neighborhood Name
# 0   el Camp d'en Grassot i Gràcia Nova
# 1               la Dreta de l'Eixample
# 2                            les Corts
# 3                               Sarrià
# 4                       la Prosperitat
# ..                                 ...
# 92          Sant Gervasi - la Bonanova
# 93                           el Carmel
# 94                la Font d'en Fargues
# 95              la Dreta de l'Eixample
# 96                           les Corts
#
# [97 rows x 6 columns]

# %%
# GROUP BY NEIGHBORHOOD

# Count Schools from dataframe (religious) for each neighborhood
neighborhood_counts = religious_df.groupby('Neighborhood Name').size()
#print(neighborhood_counts)

# Find neighborhoods with at least one school
neighborhoods_with_schools = neighborhood_counts[neighborhood_counts > 0].index

# Update the 'Centers Characteristics' column in zones_educ_df
zones_educ_df['Centers Characteristics'] = "non-religious"
zones_educ_df.loc[zones_educ_df['Neighborhood Name'].isin(neighborhoods_with_schools), 'Centers Characteristics'] = 'religious and non-religious'

display(zones_educ_df)
# Out:
#                                Neighborhood Name District Name Associated  \
# 1                                       el Raval             Ciutat Vella
# 2                                 el Barri Gòtic             Ciutat Vella
# 3                                 la Barceloneta             Ciutat Vella
# 4          Sant Pere, Santa Caterina i la Ribera             Ciutat Vella
# 5                                  el Fort Pienc                 Eixample
# ..                                           ...                      ...
# 69  Diagonal Mar i el Front Marítim del Poblenou               Sant Martí
# 70                         el Besòs i el Maresme               Sant Martí
# 71                       Provençals del Poblenou               Sant Martí
# 72                      Sant Martí de Provençals               Sant Martí
# 73                           la Verneda i la Pau               Sant Martí
#
#     Number of Services Distances  Density over Places Ratio  \
# 1                   45       NaN                      1.005
# 2                   13       NaN                      1.686
# 3                   23       NaN                      0.697
# 4                   35       NaN                      0.711
# 5                   19       NaN                      1.116
# ..                 ...       ...                        ...
# 69                   7       NaN                      1.090
# 70                  13       NaN                      0.601
# 71                  17       NaN                      1.237
# 72                  19       NaN                      0.579
# 73                  15       NaN                      1.454
#
#    Avg. Students per Teacher Ratio             School Status  \
# 1                              NaN           public, charter
# 2                              NaN           public, charter
# 3                              NaN                    public
# 4                              NaN           public, charter
# 5                              NaN  private, public, charter
# ..                             ...                       ...
# 69                             NaN           public, charter
# 70                             NaN           public, charter
# 71                             NaN           public, charter
# 72                             NaN           public, charter
# 73                             NaN           public, charter
#
#                                          Centers Type  \
# 1   Kindergarten & Primary School, University, Kin...
# 2   FP, Kindergarten & Primary School, University,...
# 3   Secondary School, University, Kindergarten & P...
# 4   Kindergarten & Primary School, Secondary Schoo...
# 5   Secondary School, Kindergarten & Primary Schoo...
# ..                                                ...
# 69  Kindergarten, Primary & Secondary School, FP, ...
# 70  Kindergarten & Primary School, Secondary Schoo...
# 71  Kindergarten & Primary School, University, Inf...
# 72  Kindergarten & Primary School, Kindergarten, P...
# 73  FP, Kindergarten & Primary School, Secondary S...
#
#                                   Centers Simple Type  \
# 1   Kindergarten & Primary School, University, Gen...
# 2   FP, Kindergarten & Primary School, University,...
# 3   High School, University, Kindergarten & Primar...
# 4   Kindergarten & Primary School, High School, Mu...
# 5   High School, Kindergarten & Primary School, Ge...
# ..                                                ...
# 69  General School (with kindergarten), FP, Kinder...
# 70  Kindergarten & Primary School, High School, Un...
# 71  Kindergarten & Primary School, University, Inf...
# 72  Kindergarten & Primary School, General School ...
# 73  FP, Kindergarten & Primary School, High School...
#
#         Centers Characteristics  ...  \
# 1   religious and non-religious  ...
# 2                 non-religious  ...
# 3                 non-religious  ...
# 4   religious and non-religious  ...
# 5                 non-religious  ...
# ..                          ...  ...
# 69                non-religious  ...
# 70  religious and non-religious  ...
# 71                non-religious  ...
# 72  religious and non-religious  ...
# 73  religious and non-religious  ...
#
#    Higher Studies in people older than 15 (%)  \
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# ..                                        ...
# 69                                        NaN
# 70                                        NaN
# 71                                        NaN
# 72                                        NaN
# 73                                        NaN
#
#    No education or Incomplete Primary School in people older than 15 (%)  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# ..                                                ...
# 69                                                NaN
# 70                                                NaN
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
#
#    Young Population without Post-Compulsory Education (%)  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# ..                                                ...
# 69                                                NaN
# 70                                                NaN
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
#
#    Abscence Rate in 4th Grade (%) Graduation Rate in 4th Grade (%)  \
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             NaN                              NaN
# ..                            ...                              ...
# 69                            NaN                              NaN
# 70                            NaN                              NaN
# 71                            NaN                              NaN
# 72                            NaN                              NaN
# 73                            NaN                              NaN
#
#    Territorial Socioeconomic Index (IST) Avg. Gini Index (%)  \
# 1                                   78.2              34.495
# 2                                   75.6              39.133
# 3                                   95.8              33.636
# 4                                  100.8              37.031
# 5                                  111.0              32.475
# ..                                   ...                 ...
# 69                                 116.6              31.814
# 70                                  72.4              29.715
# 71                                 107.0              29.242
# 72                                 102.9              27.361
# 73                                  96.0              27.129
#
#    Population Density (hab/ha) Net Population Density (hab/residential ha)  \
# 1                          429                                         952
# 2                          268                                         639
# 3                          124                                        1081
# 4                          199                                         683
# 5                          336                                         930
# ..                         ...                                         ...
# 69                         109                                         556
# 70                         212                                         913
# 71                         193                                        1368
# 72                         355                                        1111
# 73                         253                                         714
#
#    Number of Places
# 1             427.0
# 2             159.0
# 3             178.0
# 4             280.0
# 5             301.0
# ..              ...
# 69            100.0
# 70            353.0
# 71            156.0
# 72            613.0
# 73            174.0
#
# [73 rows x 25 columns]

# %% [markdown]
# 1.10.2 International (specify language?)

# %% [markdown]
# ### 1.11. Students per Teacher Ratio

# %%
# Dataset Files
students_file = "/Users/mariatormo02/Desktop/TFG-Code/Data/Education Index Data/Alumnes_matriculats_per_ensenyament_i_unitats_dels_centres_docents_20240402.csv"
teachers_file = "/Users/mariatormo02/Desktop/TFG-Code/Data/Education Index Data/Personal_docent_en_centres_p_blics_titularitat_del_Departament_d_Educaci__20240402.csv"

#encoded = detect_encoding(students_file)
#print(encoded)

# Read CSV
students_df = pd.read_csv(students_file, encoding='utf-8', nrows=44463)
teachers_df = pd.read_csv(teachers_file, encoding='utf-8')

# %% [markdown]
# STUDENTS

# %%
students_df.head()
# Out:
#         Curs   Any  Codi centre   Denominació completa  Codi naturalesa  \
# 0  2022/2023  2022     43960064  PTT Segur de Calafell                1
# 1  2022/2023  2022     43960066          PTT Constantí                1
# 2  2022/2023  2022     43012629             Aula Magna                2
# 3  2022/2023  2022     43012629             Aula Magna                2
# 4  2022/2023  2022     43012629             Aula Magna                2
#
#   Nom naturalesa  Codi titularitat       Nom titularitat  Codi delegació  \
# 0         Públic                99           No informat             208
# 1         Públic                99           No informat             143
# 2         Privat                26  Societats Mercantils             143
# 3         Privat                26  Societats Mercantils             143
# 4         Privat                26  Societats Mercantils             143
#
#          Nom delegació  ...  \
# 0  Barcelona Comarques  ...
# 1            Tarragona  ...
# 2            Tarragona  ...
# 3            Tarragona  ...
# 4            Tarragona  ...
#
#                                      Nom ensenyament Nivell  \
# 0                       AUXILIAR DE VIVERS I JARDINS      1
# 1  AUXILIAR DE COMERCIALITZACIÓ DE PRODUCTES I LO...      1
# 2                           CFPS - EDUCACIÓ INFANTIL      2
# 3                           CFPS - INTEGRACIÓ SOCIAL      1
# 4                           CFPS - INTEGRACIÓ SOCIAL      2
#
#    Matrícula concertada      Modalitat Període matrícula  Matrícules. Total  \
# 0                    NO     PRESENCIAL             ANUAL                 11
# 1                    NO     PRESENCIAL             ANUAL                 15
# 2                    NO     PRESENCIAL             ANUAL                 20
# 3                    NO  NO PRESENCIAL             ANUAL                 10
# 4                    NO  NO PRESENCIAL             ANUAL                 12
#
#   Matrícules. Dones  Matrícules. Homes  Unitats  Georeferència
# 0                 2                  9      0.0            NaN
# 1                 3                 12      0.0            NaN
# 2                17                  3      0.0            NaN
# 3                 9                  1      0.0            NaN
# 4                10                  2      0.0            NaN
#
# [5 rows x 36 columns]

# %%
# Select Most Recent Year
students_df = students_df[students_df['Any'] == 2022]
students_df = students_df[students_df['Nom comarca'] == 'Barcelonès']

# %%
#students_df = students_df[students_df['Nom municipi'] == 'Barcelona']
# Drop Unnecessary columns
cols_to_drop_stud = ['Curs', 'Any', 'Codi centre', 'Codi naturalesa', 'Nom naturalesa', 'Codi titularitat', 'Nom titularitat', 'Codi delegació', 'Nom delegació', 'Codi comarca', 'Nom comarca',
                     'Codi municipi_5', 'Codi municipi_6', 'Nom municipi', 'Nom districte municipal', 'Coordenades UTM X', 'Coordenades UTM Y',
                     'Coordenades GEO X', 'Coordenades GEO Y', 'Codi estudis', 'Nom estudis', 'Temàtica', 'Grau', 'Codi ensenyament', 'Nom ensenyament',
                     'Nivell', 'Matrícula concertada', 'Modalitat', 'Període matrícula', 'Georeferència', 'Unitats', 'Matrícules. Dones', 'Matrícules. Homes']

students_df.drop(columns=cols_to_drop_stud, inplace=True)
students_df.rename(columns={'Denominació completa': 'Name', 'Codi districte municipal': 'District ID', 'Matrícules. Total': 'Number of Students'}, inplace=True)
students_df.reset_index()
students_df.head(8)
# Out:
#                                     Name  District ID  Number of Students
# 4690  Institut de Logística de Barcelona            1                  32
# 4691  Institut de Logística de Barcelona            1                  26
# 4692  Institut de Logística de Barcelona            1                  32
# 4693  Institut de Logística de Barcelona            1                  55
# 4694  Institut de Logística de Barcelona            1                  63
# 4695  Institut de Logística de Barcelona            1                  28
# 4696  Institut de Logística de Barcelona            1                  32
# 4697  Institut de Logística de Barcelona            1                  30

# %%
# Add up students per center Name (different services type: primary, secondary, etc.)
center_students_df = students_df.groupby(['Name', 'District ID'], as_index=False)['Number of Students'].sum().reset_index()
students_df = center_students_df
students_df.head()
# Out:
#    index                  Name  District ID  Number of Students
# 0      0                   19@            5                 128
# 1      1    AA Eurofitness Edu            2                 241
# 2      2          AAFE Olimpia           10                  79
# 3      3   AF Centre d'estudis            1                 189
# 4      4  AFA Ciutat Meridiana            8                 360

# %%
# Function to get the best match with a minimum score threshold and district matching
def get_best_match(row, choices, scorer, threshold=95):
    # Filter choices by matching district
    district_choices = [choice for choice in choices if choice[1] == row['District ID']]

    if not district_choices:
        return None

    best_match, best_score = process.extractOne(row['Name'], [choice[0] for choice in district_choices], scorer=scorer)

    if best_score >= threshold:
        return best_match
    else:
        return None

# Assign Neighborhoods using Cleaned Dataset

# Assuming 'District Name' column exists in both datasets
# Prepare the choices list with tuples of (Name, District)
choices = list(cleaned_educ_df[['Name', 'District ID']].itertuples(index=False, name=None))

# Apply the fuzzy matching function to the second dataset
students_df['Matched_Name'] = students_df.apply(get_best_match, axis=1, choices=choices, scorer=fuzz.partial_ratio)

# Filter out rows where no good match was found
students_df = students_df[students_df['Matched_Name'].notna()]

# Merge with the neighborhood information using the matched names
students_merged_df = students_df.merge(cleaned_educ_df[['Name', 'Neighborhood Name']],
                                   left_on='Matched_Name', right_on='Name', how='left')

# Drop the 'Matched_Name' column as it is no longer needed
students_merged_df.drop(columns=['Matched_Name'], inplace=True)

# Rename and drop columns
students_merged_df.rename(columns={'Name_x': 'Original Name', 'Name_y': 'Mapped Name', 'Neighborhood Name_y': 'Neighborhood Name'}, inplace=True)

# Display the merged DataFrame
display(students_merged_df)
students_df = students_merged_df
# Out:
#      index          Original Name  District ID  Number of Students  \
# 0        0                    19@            5                 128
# 1       10     Abat Oliba-Spínola            7                 820
# 2       11                   Acis            6                  18
# 3       13  Adela de Trenquelleón           10                 680
# 4       16               Alfageme            3                 190
# ..     ...                    ...          ...                 ...
# 521   1121                Voramar           10                 638
# 522   1122        Waldorf Steiner            7                   4
# 523   1125                 Xumets            3                  32
# 524   1126                 Zurich            4                 302
# 525   1127                  Àgora            2                  58
#
#                                Mapped Name               Neighborhood Name
# 0                   Centre de Formació 19@      Sant Gervasi - la Bonanova
# 1       Centre Educatiu Abat Oliba-Spínola                el Baix Guinardó
# 2                     Escola d'Adults Acis                        la Salut
# 3    Centre Educatiu Adela de Trenquelleón        Sant Martí de Provençals
# 4                 Centre Educatiu Alfageme               la Marina de Port
# ..                                     ...                             ...
# 521                Centre Educatiu Voramar                     el Poblenou
# 522              Parvulari Waldorf Steiner            la Font d'en Fargues
# 523                  Llar d'Infants Xumets               la Marina de Port
# 524                 Centre Educatiu Zurich                       Pedralbes
# 525                   Llar d'Infants Àgora  la Nova Esquerra de l'Eixample
#
# [526 rows x 6 columns]

# %%
# SUM STUDENTS BY NEIGHBORHOOD
neighborhood_students = students_df.groupby('Neighborhood Name')['Number of Students'].sum().reset_index()


# Update the 'Number of Students' column in zones_educ_df
zones_educ_df = zones_educ_df.merge(neighborhood_students, on='Neighborhood Name', how='left')

display(zones_educ_df)
# Out:
#                                Neighborhood Name District Name Associated  \
# 0                                       el Raval             Ciutat Vella
# 1                                 el Barri Gòtic             Ciutat Vella
# 2                                 la Barceloneta             Ciutat Vella
# 3          Sant Pere, Santa Caterina i la Ribera             Ciutat Vella
# 4                                  el Fort Pienc                 Eixample
# ..                                           ...                      ...
# 68  Diagonal Mar i el Front Marítim del Poblenou               Sant Martí
# 69                         el Besòs i el Maresme               Sant Martí
# 70                       Provençals del Poblenou               Sant Martí
# 71                      Sant Martí de Provençals               Sant Martí
# 72                           la Verneda i la Pau               Sant Martí
#
#     Number of Services Distances  Density over Places Ratio  \
# 0                   45       NaN                      1.005
# 1                   13       NaN                      1.686
# 2                   23       NaN                      0.697
# 3                   35       NaN                      0.711
# 4                   19       NaN                      1.116
# ..                 ...       ...                        ...
# 68                   7       NaN                      1.090
# 69                  13       NaN                      0.601
# 70                  17       NaN                      1.237
# 71                  19       NaN                      0.579
# 72                  15       NaN                      1.454
#
#    Avg. Students per Teacher Ratio             School Status  \
# 0                              NaN           public, charter
# 1                              NaN           public, charter
# 2                              NaN                    public
# 3                              NaN           public, charter
# 4                              NaN  private, public, charter
# ..                             ...                       ...
# 68                             NaN           public, charter
# 69                             NaN           public, charter
# 70                             NaN           public, charter
# 71                             NaN           public, charter
# 72                             NaN           public, charter
#
#                                          Centers Type  \
# 0   Kindergarten & Primary School, University, Kin...
# 1   FP, Kindergarten & Primary School, University,...
# 2   Secondary School, University, Kindergarten & P...
# 3   Kindergarten & Primary School, Secondary Schoo...
# 4   Secondary School, Kindergarten & Primary Schoo...
# ..                                                ...
# 68  Kindergarten, Primary & Secondary School, FP, ...
# 69  Kindergarten & Primary School, Secondary Schoo...
# 70  Kindergarten & Primary School, University, Inf...
# 71  Kindergarten & Primary School, Kindergarten, P...
# 72  FP, Kindergarten & Primary School, Secondary S...
#
#                                   Centers Simple Type  \
# 0   Kindergarten & Primary School, University, Gen...
# 1   FP, Kindergarten & Primary School, University,...
# 2   High School, University, Kindergarten & Primar...
# 3   Kindergarten & Primary School, High School, Mu...
# 4   High School, Kindergarten & Primary School, Ge...
# ..                                                ...
# 68  General School (with kindergarten), FP, Kinder...
# 69  Kindergarten & Primary School, High School, Un...
# 70  Kindergarten & Primary School, University, Inf...
# 71  Kindergarten & Primary School, General School ...
# 72  FP, Kindergarten & Primary School, High School...
#
#         Centers Characteristics  ...  \
# 0   religious and non-religious  ...
# 1                 non-religious  ...
# 2                 non-religious  ...
# 3   religious and non-religious  ...
# 4                 non-religious  ...
# ..                          ...  ...
# 68                non-religious  ...
# 69  religious and non-religious  ...
# 70                non-religious  ...
# 71  religious and non-religious  ...
# 72  religious and non-religious  ...
#
#    No education or Incomplete Primary School in people older than 15 (%)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 68                                                NaN
# 69                                                NaN
# 70                                                NaN
# 71                                                NaN
# 72                                                NaN
#
#    Young Population without Post-Compulsory Education (%)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 68                                                NaN
# 69                                                NaN
# 70                                                NaN
# 71                                                NaN
# 72                                                NaN
#
#    Abscence Rate in 4th Grade (%) Graduation Rate in 4th Grade (%)  \
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# ..                            ...                              ...
# 68                            NaN                              NaN
# 69                            NaN                              NaN
# 70                            NaN                              NaN
# 71                            NaN                              NaN
# 72                            NaN                              NaN
#
#    Territorial Socioeconomic Index (IST) Avg. Gini Index (%)  \
# 0                                   78.2              34.495
# 1                                   75.6              39.133
# 2                                   95.8              33.636
# 3                                  100.8              37.031
# 4                                  111.0              32.475
# ..                                   ...                 ...
# 68                                 116.6              31.814
# 69                                  72.4              29.715
# 70                                 107.0              29.242
# 71                                 102.9              27.361
# 72                                  96.0              27.129
#
#    Population Density (hab/ha) Net Population Density (hab/residential ha)  \
# 0                          429                                         952
# 1                          268                                         639
# 2                          124                                        1081
# 3                          199                                         683
# 4                          336                                         930
# ..                         ...                                         ...
# 68                         109                                         556
# 69                         212                                         913
# 70                         193                                        1368
# 71                         355                                        1111
# 72                         253                                         714
#
#    Number of Places Number of Students
# 0             427.0             9128.0
# 1             159.0             1066.0
# 2             178.0             1554.0
# 3             280.0             4360.0
# 4             301.0             2817.0
# ..              ...                ...
# 68            100.0             2628.0
# 69            353.0             5363.0
# 70            156.0             1972.0
# 71            613.0             4287.0
# 72            174.0             3162.0
#
# [73 rows x 26 columns]

# %% [markdown]
# TEACHERS

# %%
#teachers_df['Nom municipi'].unique()

# %%
#display(teachers_df)
teachers_df = teachers_df[teachers_df['Curs'] == '2023/2024']
teachers_df = teachers_df[teachers_df['Nom municipi'] == 'BARCELONA']

# Get rid of useless columns and rename
teachers_df.drop(columns=['Curs', 'Codi centre', 'Codi municipi_5', 'Codi municipi_6', 'Nom municipi', 'Dones', 'Homes'], inplace=True)
teachers_df.rename(columns={'Denominació completa': 'Name', 'Total': 'Number of Teachers'}, inplace=True)
teachers_df.head()
# Out:
#                                                    Name  Number of Teachers
# 1026  INSTITUT DE TÈCNIQUES AUDIOVISUALS I DE L'ESPE...                  26
# 1027                          INSTITUT TIC DE BARCELONA                  48
# 1028                                       ESCOLA SEGRE                  18
# 1029                    INSTITUT ESCOLA SANT FELIP NERI                  28
# 1034                 INSTITUT DE LOGÍSTICA DE BARCELONA                  47

# %%
# Add up students per center Name (different services type: primary, secondary, etc.)
center_teachers_df = teachers_df.groupby('Name')['Number of Teachers'].sum().reset_index()
teachers_df = center_teachers_df
teachers_df.head()
# Out:
#                        Name  Number of Teachers
# 0      AFA CIUTAT MERIDIANA                   7
# 1         CEE CONCHA ESPINA                  20
# 2      CEE FOLCH I CAMARASA                  11
# 3             CEE JOSEP PLA                  15
# 4  CEE SANT JOAN DE LA CREU                  34

# %%
def get_best_match(row, choices, scorer, cutoff=80):
    name = row['Name']
    match, score = process.extractOne(name, choices, scorer=scorer)
    return match if score >= cutoff else None

# Assign Neighborhoods using Cleaned Dataset

# Apply the fuzzy matching function to the second dataset
choices = cleaned_educ_df['Name'].tolist()
teachers_df['Matched_Name'] = teachers_df.apply(get_best_match, axis=1, choices=choices, scorer=fuzz.partial_ratio)

# Merge with the neighborhood information using the matched names
teachers_merged_df = teachers_df.merge(cleaned_educ_df[['Name', 'Neighborhood Name']],
                             left_on='Matched_Name', right_on='Name', how='left')

# Drop the 'Matched_Name' column as it is no longer needed
teachers_merged_df.drop(columns=['Matched_Name'], inplace=True)

#  Rename and drop
#merged_df.drop(columns={'Neighborhood Name_x'}, inplace=True)
teachers_merged_df.rename(columns={'Name_x': 'Original Name', 'Name_y': 'Mapped Name', 'Neighborhood Name_y': 'Neighborhood Name'}, inplace=True)

# Display the merged DataFrame
display(teachers_merged_df)
teachers_df = teachers_merged_df
# Out:
#                 Original Name  Number of Teachers  \
# 0        AFA CIUTAT MERIDIANA                   7
# 1           CEE CONCHA ESPINA                  20
# 2        CEE FOLCH I CAMARASA                  11
# 3               CEE JOSEP PLA                  15
# 4    CEE SANT JOAN DE LA CREU                  34
# ..                        ...                 ...
# 269    INSTITUT VAPOR DEL FIL                  23
# 270        INSTITUT VERDAGUER                  37
# 271   INSTITUT VILA DE GRÀCIA                  38
# 272        INSTITUT VILADOMAT                  47
# 273    INSTITUT XXV OLIMPÍADA                  58
#
#                                            Mapped Name  \
# 0    Aula de Formació de Persones Adultes Ciutat Me...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 269                             Institut Vapor del Fil
# 270                                 Institut Verdaguer
# 271                            Institut Vila de Gràcia
# 272                                 Institut Viladomat
# 273                             Institut XXV Olimpíada
#
#                          Neighborhood Name
# 0                         Ciutat Meridiana
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 269                            Sant Andreu
# 270  Sant Pere, Santa Caterina i la Ribera
# 271                      la Vila de Gràcia
# 272         la Nova Esquerra de l'Eixample
# 273                  la Font de la Guatlla
#
# [274 rows x 4 columns]

# %%
# SUM STUDENTS BY NEIGHBORHOOD
neighborhood_teachers = teachers_df.groupby('Neighborhood Name')['Number of Teachers'].sum().reset_index()
display(neighborhood_teachers)

# Update the 'Density over Places Ratio' column in zones_educ_df
zones_educ_df = zones_educ_df.merge(neighborhood_teachers, on='Neighborhood Name', how='left')
zones_educ_df['Avg. Students per Teacher Ratio'] = zones_educ_df['Number of Students']/zones_educ_df['Number of Teachers']
zones_educ_df['Avg. Students per Teacher Ratio'] = zones_educ_df['Avg. Students per Teacher Ratio'].round(3)
zones_educ_df.index = zones_educ_df.index + 1
display(zones_educ_df)
# Out:
#                 Neighborhood Name  Number of Teachers
# 0                   Baró de Viver                  17
# 1                       Canyelles                  24
# 2                Ciutat Meridiana                 105
# 3                           Horta                  30
# 4                     Hostafrancs                  21
# ..                            ...                 ...
# 61            la Verneda i la Pau                 254
# 62  la Vila Olímpica del Poblenou                 125
# 63              la Vila de Gràcia                 100
# 64                      les Corts                 162
# 65                   les Roquetes                  66
#
# [66 rows x 2 columns]
#                                Neighborhood Name District Name Associated  \
# 1                                       el Raval             Ciutat Vella
# 2                                 el Barri Gòtic             Ciutat Vella
# 3                                 la Barceloneta             Ciutat Vella
# 4          Sant Pere, Santa Caterina i la Ribera             Ciutat Vella
# 5                                  el Fort Pienc                 Eixample
# ..                                           ...                      ...
# 69  Diagonal Mar i el Front Marítim del Poblenou               Sant Martí
# 70                         el Besòs i el Maresme               Sant Martí
# 71                       Provençals del Poblenou               Sant Martí
# 72                      Sant Martí de Provençals               Sant Martí
# 73                           la Verneda i la Pau               Sant Martí
#
#     Number of Services Distances  Density over Places Ratio  \
# 1                   45       NaN                      1.005
# 2                   13       NaN                      1.686
# 3                   23       NaN                      0.697
# 4                   35       NaN                      0.711
# 5                   19       NaN                      1.116
# ..                 ...       ...                        ...
# 69                   7       NaN                      1.090
# 70                  13       NaN                      0.601
# 71                  17       NaN                      1.237
# 72                  19       NaN                      0.579
# 73                  15       NaN                      1.454
#
#     Avg. Students per Teacher Ratio             School Status  \
# 1                            25.858           public, charter
# 2                            21.320           public, charter
# 3                            10.571                    public
# 4                            22.947           public, charter
# 5                            21.341  private, public, charter
# ..                              ...                       ...
# 69                              NaN           public, charter
# 70                           28.527           public, charter
# 71                           21.911           public, charter
# 72                           25.518           public, charter
# 73                           12.449           public, charter
#
#                                          Centers Type  \
# 1   Kindergarten & Primary School, University, Kin...
# 2   FP, Kindergarten & Primary School, University,...
# 3   Secondary School, University, Kindergarten & P...
# 4   Kindergarten & Primary School, Secondary Schoo...
# 5   Secondary School, Kindergarten & Primary Schoo...
# ..                                                ...
# 69  Kindergarten, Primary & Secondary School, FP, ...
# 70  Kindergarten & Primary School, Secondary Schoo...
# 71  Kindergarten & Primary School, University, Inf...
# 72  Kindergarten & Primary School, Kindergarten, P...
# 73  FP, Kindergarten & Primary School, Secondary S...
#
#                                   Centers Simple Type  \
# 1   Kindergarten & Primary School, University, Gen...
# 2   FP, Kindergarten & Primary School, University,...
# 3   High School, University, Kindergarten & Primar...
# 4   Kindergarten & Primary School, High School, Mu...
# 5   High School, Kindergarten & Primary School, Ge...
# ..                                                ...
# 69  General School (with kindergarten), FP, Kinder...
# 70  Kindergarten & Primary School, High School, Un...
# 71  Kindergarten & Primary School, University, Inf...
# 72  Kindergarten & Primary School, General School ...
# 73  FP, Kindergarten & Primary School, High School...
#
#         Centers Characteristics  ...  \
# 1   religious and non-religious  ...
# 2                 non-religious  ...
# 3                 non-religious  ...
# 4   religious and non-religious  ...
# 5                 non-religious  ...
# ..                          ...  ...
# 69                non-religious  ...
# 70  religious and non-religious  ...
# 71                non-religious  ...
# 72  religious and non-religious  ...
# 73  religious and non-religious  ...
#
#    Young Population without Post-Compulsory Education (%)  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# ..                                                ...
# 69                                                NaN
# 70                                                NaN
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
#
#    Abscence Rate in 4th Grade (%) Graduation Rate in 4th Grade (%)  \
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             NaN                              NaN
# ..                            ...                              ...
# 69                            NaN                              NaN
# 70                            NaN                              NaN
# 71                            NaN                              NaN
# 72                            NaN                              NaN
# 73                            NaN                              NaN
#
#    Territorial Socioeconomic Index (IST) Avg. Gini Index (%)  \
# 1                                   78.2              34.495
# 2                                   75.6              39.133
# 3                                   95.8              33.636
# 4                                  100.8              37.031
# 5                                  111.0              32.475
# ..                                   ...                 ...
# 69                                 116.6              31.814
# 70                                  72.4              29.715
# 71                                 107.0              29.242
# 72                                 102.9              27.361
# 73                                  96.0              27.129
#
#    Population Density (hab/ha) Net Population Density (hab/residential ha)  \
# 1                          429                                         952
# 2                          268                                         639
# 3                          124                                        1081
# 4                          199                                         683
# 5                          336                                         930
# ..                         ...                                         ...
# 69                         109                                         556
# 70                         212                                         913
# 71                         193                                        1368
# 72                         355                                        1111
# 73                         253                                         714
#
#    Number of Places Number of Students Number of Teachers
# 1             427.0             9128.0              353.0
# 2             159.0             1066.0               50.0
# 3             178.0             1554.0              147.0
# 4             280.0             4360.0              190.0
# 5             301.0             2817.0              132.0
# ..              ...                ...                ...
# 69            100.0             2628.0                NaN
# 70            353.0             5363.0              188.0
# 71            156.0             1972.0               90.0
# 72            613.0             4287.0              168.0
# 73            174.0             3162.0              254.0
#
# [73 rows x 27 columns]

# %% [markdown]
# ### 1.12. Percentage of Population with Low Studies

# %%
# Dataset File
IST_educ_values_file = "/Users/mariatormo02/Desktop/TFG-Code/Data/Education Index Data/IST_valors_estudis.csv"

encoded = detect_encoding(IST_educ_values_file)
print(encoded)

# Read CSV
IST_educ_values_df = pd.read_csv(IST_educ_values_file, encoding='utf-8', sep=';')
# Out:
# utf-8

# %%
#display(IST_educ_values_df)
low_studies_df = IST_educ_values_df.copy()
low_studies_df.drop(columns={'any', 'població ocupada', 'treballadors de baixa qualificació', 
                             'població jove sense estudis postobligatoris', 'estrangers de països de renda baixa o mitjana',
                            'renda mitjana per persona'}, inplace=True)
low_studies_df.rename(columns={'barris de Barcelona': 'Neighborhood Name',
                              'població amb estudis baixos': '% Population with Low Studies'}, inplace=True)
low_studies_df.index = low_studies_df.index + 1
display(low_studies_df)
# Out:
#                         Neighborhood Name  % Population with Low Studies
# 1                                el Raval                           15.8
# 2                          el Barri Gòtic                           18.0
# 3                          la Barceloneta                           14.2
# 4   Sant Pere, Santa Caterina i la Ribera                            9.9
# 5                           el Fort Pienc                            8.9
# ..                                    ...                            ...
# 70                  el Besòs i el Maresme                           21.4
# 71                Provençals del Poblenou                           12.7
# 72               Sant Martí de Provençals                           16.6
# 73                    la Verneda i la Pau                           18.9
# 74                                  total                           12.0
#
# [74 rows x 2 columns]

# %%
# Check non-null values
low_studies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 1 to 74
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Neighborhood Name              74 non-null     object
#  1   % Population with Low Studies  74 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.3+ KB

# %%
# Assign Value
zones_educ_df['Population with Low Studies (%)'] = low_studies_df['% Population with Low Studies']
zones_educ_df.head(5)
# Out:
#                        Neighborhood Name District Name Associated  \
# 1                               el Raval             Ciutat Vella
# 2                         el Barri Gòtic             Ciutat Vella
# 3                         la Barceloneta             Ciutat Vella
# 4  Sant Pere, Santa Caterina i la Ribera             Ciutat Vella
# 5                          el Fort Pienc                 Eixample
#
#    Number of Services Distances  Density over Places Ratio  \
# 1                  45       NaN                      1.005
# 2                  13       NaN                      1.686
# 3                  23       NaN                      0.697
# 4                  35       NaN                      0.711
# 5                  19       NaN                      1.116
#
#    Avg. Students per Teacher Ratio             School Status  \
# 1                           25.858           public, charter
# 2                           21.320           public, charter
# 3                           10.571                    public
# 4                           22.947           public, charter
# 5                           21.341  private, public, charter
#
#                                         Centers Type  \
# 1  Kindergarten & Primary School, University, Kin...
# 2  FP, Kindergarten & Primary School, University,...
# 3  Secondary School, University, Kindergarten & P...
# 4  Kindergarten & Primary School, Secondary Schoo...
# 5  Secondary School, Kindergarten & Primary Schoo...
#
#                                  Centers Simple Type  \
# 1  Kindergarten & Primary School, University, Gen...
# 2  FP, Kindergarten & Primary School, University,...
# 3  High School, University, Kindergarten & Primar...
# 4  Kindergarten & Primary School, High School, Mu...
# 5  High School, Kindergarten & Primary School, Ge...
#
#        Centers Characteristics  ...  \
# 1  religious and non-religious  ...
# 2                non-religious  ...
# 3                non-religious  ...
# 4  religious and non-religious  ...
# 5                non-religious  ...
#
#    Young Population without Post-Compulsory Education (%)  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   Abscence Rate in 4th Grade (%) Graduation Rate in 4th Grade (%)  \
# 1                            NaN                              NaN
# 2                            NaN                              NaN
# 3                            NaN                              NaN
# 4                            NaN                              NaN
# 5                            NaN                              NaN
#
#   Territorial Socioeconomic Index (IST) Avg. Gini Index (%)  \
# 1                                  78.2              34.495
# 2                                  75.6              39.133
# 3                                  95.8              33.636
# 4                                 100.8              37.031
# 5                                 111.0              32.475
#
#   Population Density (hab/ha) Net Population Density (hab/residential ha)  \
# 1                         429                                         952
# 2                         268                                         639
# 3                         124                                        1081
# 4                         199                                         683
# 5                         336                                         930
#
#   Number of Places Number of Students Number of Teachers
# 1            427.0             9128.0              353.0
# 2            159.0             1066.0               50.0
# 3            178.0             1554.0              147.0
# 4            280.0             4360.0              190.0
# 5            301.0             2817.0              132.0
#
# [5 rows x 27 columns]

# %% [markdown]
# ### 1.13. Percentage of Young Population without Post-Compulsory Education

# %%
young_no_post_df = IST_educ_values_df.copy()
#display(young_no_post_df)
young_no_post_df.drop(columns={'any', 'població ocupada', 'treballadors de baixa qualificació', 'població amb estudis baixos',
                               'estrangers de països de renda baixa o mitjana','renda mitjana per persona'}, inplace=True)
young_no_post_df.rename(columns={'barris de Barcelona': 'Neighborhood Name',
                              'població jove sense estudis postobligatoris': '% Young Population without Post-Compulsory Education'}, inplace=True)
young_no_post_df.index = young_no_post_df.index + 1
display(young_no_post_df)
# Out:
#                         Neighborhood Name  \
# 1                                el Raval
# 2                          el Barri Gòtic
# 3                          la Barceloneta
# 4   Sant Pere, Santa Caterina i la Ribera
# 5                           el Fort Pienc
# ..                                    ...
# 70                  el Besòs i el Maresme
# 71                Provençals del Poblenou
# 72               Sant Martí de Provençals
# 73                    la Verneda i la Pau
# 74                                  total
#
#     % Young Population without Post-Compulsory Education
# 1                                                30.4
# 2                                                34.6
# 3                                                17.2
# 4                                                13.6
# 5                                                11.2
# ..                                                ...
# 70                                               41.6
# 71                                               18.4
# 72                                               18.8
# 73                                               25.1
# 74                                               16.8
#
# [74 rows x 2 columns]

# %%
# Check non-null values
young_no_post_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 1 to 74
# Data columns (total 2 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Neighborhood Name                                     74 non-null     object
#  1   % Young Population without Post-Compulsory Education  74 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.3+ KB

# %%
# Assign Value
zones_educ_df['Young Population without Post-Compulsory Education (%)'] = young_no_post_df['% Young Population without Post-Compulsory Education']
zones_educ_df.head(5)
# Out:
#                        Neighborhood Name District Name Associated  \
# 1                               el Raval             Ciutat Vella
# 2                         el Barri Gòtic             Ciutat Vella
# 3                         la Barceloneta             Ciutat Vella
# 4  Sant Pere, Santa Caterina i la Ribera             Ciutat Vella
# 5                          el Fort Pienc                 Eixample
#
#    Number of Services Distances  Density over Places Ratio  \
# 1                  45       NaN                      1.005
# 2                  13       NaN                      1.686
# 3                  23       NaN                      0.697
# 4                  35       NaN                      0.711
# 5                  19       NaN                      1.116
#
#    Avg. Students per Teacher Ratio             School Status  \
# 1                           25.858           public, charter
# 2                           21.320           public, charter
# 3                           10.571                    public
# 4                           22.947           public, charter
# 5                           21.341  private, public, charter
#
#                                         Centers Type  \
# 1  Kindergarten & Primary School, University, Kin...
# 2  FP, Kindergarten & Primary School, University,...
# 3  Secondary School, University, Kindergarten & P...
# 4  Kindergarten & Primary School, Secondary Schoo...
# 5  Secondary School, Kindergarten & Primary Schoo...
#
#                                  Centers Simple Type  \
# 1  Kindergarten & Primary School, University, Gen...
# 2  FP, Kindergarten & Primary School, University,...
# 3  High School, University, Kindergarten & Primar...
# 4  Kindergarten & Primary School, High School, Mu...
# 5  High School, Kindergarten & Primary School, Ge...
#
#        Centers Characteristics  ...  \
# 1  religious and non-religious  ...
# 2                non-religious  ...
# 3                non-religious  ...
# 4  religious and non-religious  ...
# 5                non-religious  ...
#
#    Young Population without Post-Compulsory Education (%)  \
# 1                                               30.4
# 2                                               34.6
# 3                                               17.2
# 4                                               13.6
# 5                                               11.2
#
#   Abscence Rate in 4th Grade (%) Graduation Rate in 4th Grade (%)  \
# 1                            NaN                              NaN
# 2                            NaN                              NaN
# 3                            NaN                              NaN
# 4                            NaN                              NaN
# 5                            NaN                              NaN
#
#   Territorial Socioeconomic Index (IST) Avg. Gini Index (%)  \
# 1                                  78.2              34.495
# 2                                  75.6              39.133
# 3                                  95.8              33.636
# 4                                 100.8              37.031
# 5                                 111.0              32.475
#
#   Population Density (hab/ha) Net Population Density (hab/residential ha)  \
# 1                         429                                         952
# 2                         268                                         639
# 3                         124                                        1081
# 4                         199                                         683
# 5                         336                                         930
#
#    Number of Places Number of Students Number of Teachers
# 1             427.0             9128.0              353.0
# 2             159.0             1066.0               50.0
# 3             178.0             1554.0              147.0
# 4             280.0             4360.0              190.0
# 5             301.0             2817.0              132.0
#
# [5 rows x 27 columns]

# %% [markdown]
# ### 1.14. Total Amount of Students

# %%
# Dataset File
level_studies_15a_file = "/Users/mariatormo02/Desktop/TFG-Code/Data/Education Index Data/D_NivellEstudis15a.csv"

encoded = detect_encoding(level_studies_15a_file)
print(encoded)

# Read CSV
level_studies_15a_df = pd.read_csv(level_studies_15a_file, encoding='utf-16', sep='\t')
# Out:
# UTF-16

# %%
total_stud_df = level_studies_15a_df[level_studies_15a_df['Nestudis'] == 'Total']
#total_stud_df.head()
total_stud_df.drop(columns={'TITOL SLOT 1', 'Any Dades', 'Nestudis', 'Pct N', 'Pct N Bcn'}, inplace=True)
total_stud_df.rename(columns={'Codibarri': 'Neighborhood ID', 'Descbarri': 'Neighborhood Name',
                             'N': 'Number of Students', 'N Bcn': 'Number of Students BCN'}, inplace=True)
total_stud_df = total_stud_df.reset_index()
total_stud_df.index = total_stud_df.index + 1
display(total_stud_df)
# Out:
#     index  Neighborhood ID                             Neighborhood Name  \
# 1     365                1                                      El Raval
# 2     366                2                                El Barri Gòtic
# 3     367                3                                La Barceloneta
# 4     368                4         Sant Pere, Santa Caterina i la Ribera
# 5     369                5                                 El Fort Pienc
# ..    ...              ...                                           ...
# 69    433               69  Diagonal Mar i el Front Marítim del Poblenou
# 70    434               70                         El Besós i el Maresme
# 71    435               71                       Provençals del Poblenou
# 72    436               72                      Sant Martí de Provençals
# 73    437               73                           La Verneda i la Pau
#
#     Number of Students  Number of Students BCN
# 1                39258                 1438585
# 2                21775                 1438585
# 3                13148                 1438585
# 4                19845                 1438585
# 5                30067                 1438585
# ..                 ...                     ...
# 69               11075                 1438585
# 70               23048                 1438585
# 71               18070                 1438585
# 72               22790                 1438585
# 73               25363                 1438585
#
# [73 rows x 5 columns]

# %%
# Check NULL Values
total_stud_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 1 to 73
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   index                   73 non-null     int64
#  1   Neighborhood ID         73 non-null     int64
#  2   Neighborhood Name       73 non-null     object
#  3   Number of Students      73 non-null     int64
#  4   Number of Students BCN  73 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 3.0+ KB

# %%
# Assign Values
zones_educ_df['Total Number of Students'] = total_stud_df['Number of Students']
zones_educ_df.head(5)
# Out:
#                        Neighborhood Name District Name Associated  \
# 1                               el Raval             Ciutat Vella
# 2                         el Barri Gòtic             Ciutat Vella
# 3                         la Barceloneta             Ciutat Vella
# 4  Sant Pere, Santa Caterina i la Ribera             Ciutat Vella
# 5                          el Fort Pienc                 Eixample
#
#    Number of Services Distances  Density over Places Ratio  \
# 1                  45       NaN                      1.005
# 2                  13       NaN                      1.686
# 3                  23       NaN                      0.697
# 4                  35       NaN                      0.711
# 5                  19       NaN                      1.116
#
#    Avg. Students per Teacher Ratio             School Status  \
# 1                           25.858           public, charter
# 2                           21.320           public, charter
# 3                           10.571                    public
# 4                           22.947           public, charter
# 5                           21.341  private, public, charter
#
#                                         Centers Type  \
# 1  Kindergarten & Primary School, University, Kin...
# 2  FP, Kindergarten & Primary School, University,...
# 3  Secondary School, University, Kindergarten & P...
# 4  Kindergarten & Primary School, Secondary Schoo...
# 5  Secondary School, Kindergarten & Primary Schoo...
#
#                                  Centers Simple Type  \
# 1  Kindergarten & Primary School, University, Gen...
# 2  FP, Kindergarten & Primary School, University,...
# 3  High School, University, Kindergarten & Primar...
# 4  Kindergarten & Primary School, High School, Mu...
# 5  High School, Kindergarten & Primary School, Ge...
#
#        Centers Characteristics  ...  \
# 1  religious and non-religious  ...
# 2                non-religious  ...
# 3                non-religious  ...
# 4  religious and non-religious  ...
# 5                non-religious  ...
#
#    Young Population without Post-Compulsory Education (%)  \
# 1                                               30.4
# 2                                               34.6
# 3                                               17.2
# 4                                               13.6
# 5                                               11.2
#
#    Abscence Rate in 4th Grade (%) Graduation Rate in 4th Grade (%)  \
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             NaN                              NaN
#
#   Territorial Socioeconomic Index (IST) Avg. Gini Index (%)  \
# 1                                  78.2              34.495
# 2                                  75.6              39.133
# 3                                  95.8              33.636
# 4                                 100.8              37.031
# 5                                 111.0              32.475
#
#   Population Density (hab/ha) Net Population Density (hab/residential ha)  \
# 1                         429                                         952
# 2                         268                                         639
# 3                         124                                        1081
# 4                         199                                         683
# 5                         336                                         930
#
#    Number of Places Number of Students Number of Teachers
# 1             427.0             9128.0              353.0
# 2             159.0             1066.0               50.0
# 3             178.0             1554.0              147.0
# 4             280.0             4360.0              190.0
# 5             301.0             2817.0              132.0
#
# [5 rows x 27 columns]

# %% [markdown]
# ### 1.15. Studies Level in people older than 15

# %%
#display(level_studies_15a_df)
level_studies_15a_df = level_studies_15a_df[level_studies_15a_df['Nestudis'] != 'Total']
level_studies_15a_df.drop(columns={'TITOL SLOT 1', 'Any Dades', 'N', 'N Bcn'}, inplace=True)
level_studies_15a_df.rename(columns={'Codibarri': 'Neighborhood ID', 'Descbarri': 'Neighborhood Name',
                                    'Nestudis': 'Education Level', 'Pct N': 'Percentage Level',
                                    'Pct N Bcn': 'Percentage Level BCN'}, inplace=True)
level_studies_15a_df.index = level_studies_15a_df.index + 1
display(level_studies_15a_df)
# Out:
#      Neighborhood ID                             Neighborhood Name  \
# 1                  1                                      El Raval
# 2                  2                                El Barri Gòtic
# 3                  3                                La Barceloneta
# 4                  4         Sant Pere, Santa Caterina i la Ribera
# 5                  5                                 El Fort Pienc
# ..               ...                                           ...
# 361               69  Diagonal Mar i el Front Marítim del Poblenou
# 362               70                         El Besós i el Maresme
# 363               71                       Provençals del Poblenou
# 364               72                      Sant Martí de Provençals
# 365               73                           La Verneda i la Pau
#
#                          Education Level Percentage Level Percentage Level BCN
# 1                         Estudis mitjos           20,4 %               25,4 %
# 2                         Estudis mitjos           21,5 %               25,4 %
# 3                         Estudis mitjos           23,0 %               25,4 %
# 4                         Estudis mitjos           22,6 %               25,4 %
# 5                         Estudis mitjos           26,3 %               25,4 %
# ..                                   ...              ...                  ...
# 361  Sense estudis o primària incompleta            1,3 %                1,5 %
# 362  Sense estudis o primària incompleta            2,6 %                1,5 %
# 363  Sense estudis o primària incompleta            1,7 %                1,5 %
# 364  Sense estudis o primària incompleta            2,1 %                1,5 %
# 365  Sense estudis o primària incompleta            2,9 %                1,5 %
#
# [365 rows x 5 columns]

# %%
primary_studies = level_studies_15a_df[level_studies_15a_df['Education Level'] == 'Primària completa']
secondary_studies = level_studies_15a_df[level_studies_15a_df['Education Level'] == 'Estudis secundaris']
middle_studies = level_studies_15a_df[level_studies_15a_df['Education Level'] == 'Estudis mitjos']
superior_studies = level_studies_15a_df[level_studies_15a_df['Education Level'] == 'Estudis superiors']
no_studies = level_studies_15a_df[level_studies_15a_df['Education Level'] == 'Sense estudis o primària incompleta']

# %% [markdown]
# Primary Studies

# %%
primary_studies = primary_studies.reset_index()
primary_studies.index = primary_studies.index + 1
primary_studies['Percentage Level'] = primary_studies['Percentage Level'].str.replace('%', '').str.replace(',', '.').astype(float)
primary_studies['Percentage Level BCN'] = primary_studies['Percentage Level BCN'].str.replace('%', '').str.replace(',', '.').astype(float)
display(primary_studies)
# Out:
#     index  Neighborhood ID                             Neighborhood Name  \
# 1     220                1                                      El Raval
# 2     221                2                                El Barri Gòtic
# 3     222                3                                La Barceloneta
# 4     223                4         Sant Pere, Santa Caterina i la Ribera
# 5     224                5                                 El Fort Pienc
# ..    ...              ...                                           ...
# 69    288               69  Diagonal Mar i el Front Marítim del Poblenou
# 70    289               70                         El Besós i el Maresme
# 71    290               71                       Provençals del Poblenou
# 72    291               72                      Sant Martí de Provençals
# 73    292               73                           La Verneda i la Pau
#
#       Education Level  Percentage Level  Percentage Level BCN
# 1   Primària completa              23.4                  14.7
# 2   Primària completa              20.7                  14.7
# 3   Primària completa              17.8                  14.7
# 4   Primària completa              13.4                  14.7
# 5   Primària completa              10.6                  14.7
# ..                ...               ...                   ...
# 69  Primària completa              11.1                  14.7
# 70  Primària completa              27.8                  14.7
# 71  Primària completa              16.4                  14.7
# 72  Primària completa              19.7                  14.7
# 73  Primària completa              23.6                  14.7
#
# [73 rows x 6 columns]

# %% [markdown]
# Secondary Studies

# %%
secondary_studies = secondary_studies.reset_index()
secondary_studies.index = secondary_studies.index + 1
secondary_studies['Percentage Level'] = secondary_studies['Percentage Level'].str.replace('%', '').str.replace(',', '.').astype(float)
secondary_studies['Percentage Level BCN'] = secondary_studies['Percentage Level BCN'].str.replace('%', '').str.replace(',', '.').astype(float)
display(secondary_studies)
# Out:
#     index  Neighborhood ID                             Neighborhood Name  \
# 1      74                1                                      El Raval
# 2      75                2                                El Barri Gòtic
# 3      76                3                                La Barceloneta
# 4      77                4         Sant Pere, Santa Caterina i la Ribera
# 5      78                5                                 El Fort Pienc
# ..    ...              ...                                           ...
# 69    142               69  Diagonal Mar i el Front Marítim del Poblenou
# 70    143               70                         El Besós i el Maresme
# 71    144               71                       Provençals del Poblenou
# 72    145               72                      Sant Martí de Provençals
# 73    146               73                           La Verneda i la Pau
#
#        Education Level  Percentage Level  Percentage Level BCN
# 1   Estudis secundaris              26.1                  21.9
# 2   Estudis secundaris              25.8                  21.9
# 3   Estudis secundaris              24.2                  21.9
# 4   Estudis secundaris              17.8                  21.9
# 5   Estudis secundaris              18.8                  21.9
# ..                 ...               ...                   ...
# 69  Estudis secundaris              18.5                  21.9
# 70  Estudis secundaris              32.7                  21.9
# 71  Estudis secundaris              25.8                  21.9
# 72  Estudis secundaris              27.9                  21.9
# 73  Estudis secundaris              30.8                  21.9
#
# [73 rows x 6 columns]

# %% [markdown]
# Middle Studies

# %%
middle_studies = middle_studies.reset_index()
middle_studies.index = middle_studies.index + 1
middle_studies['Percentage Level'] = middle_studies['Percentage Level'].str.replace('%', '').str.replace(',', '.').astype(float)
middle_studies['Percentage Level BCN'] = middle_studies['Percentage Level BCN'].str.replace('%', '').str.replace(',', '.').astype(float)
display(middle_studies)
# Out:
#     index  Neighborhood ID                             Neighborhood Name  \
# 1       1                1                                      El Raval
# 2       2                2                                El Barri Gòtic
# 3       3                3                                La Barceloneta
# 4       4                4         Sant Pere, Santa Caterina i la Ribera
# 5       5                5                                 El Fort Pienc
# ..    ...              ...                                           ...
# 69     69               69  Diagonal Mar i el Front Marítim del Poblenou
# 70     70               70                         El Besós i el Maresme
# 71     71               71                       Provençals del Poblenou
# 72     72               72                      Sant Martí de Provençals
# 73     73               73                           La Verneda i la Pau
#
#    Education Level  Percentage Level  Percentage Level BCN
# 1   Estudis mitjos              20.4                  25.4
# 2   Estudis mitjos              21.5                  25.4
# 3   Estudis mitjos              23.0                  25.4
# 4   Estudis mitjos              22.6                  25.4
# 5   Estudis mitjos              26.3                  25.4
# ..             ...               ...                   ...
# 69  Estudis mitjos              23.6                  25.4
# 70  Estudis mitjos              21.1                  25.4
# 71  Estudis mitjos              25.3                  25.4
# 72  Estudis mitjos              26.1                  25.4
# 73  Estudis mitjos              24.4                  25.4
#
# [73 rows x 6 columns]

# %% [markdown]
# Superior Studies

# %%
superior_studies = superior_studies.reset_index()
superior_studies.index = superior_studies.index + 1
superior_studies['Percentage Level'] = superior_studies['Percentage Level'].str.replace('%', '').str.replace(',', '.').astype(float)
superior_studies['Percentage Level BCN'] = superior_studies['Percentage Level BCN'].str.replace('%', '').str.replace(',', '.').astype(float)
display(superior_studies)
# Out:
#     index  Neighborhood ID                             Neighborhood Name  \
# 1     147                1                                      El Raval
# 2     148                2                                El Barri Gòtic
# 3     149                3                                La Barceloneta
# 4     150                4         Sant Pere, Santa Caterina i la Ribera
# 5     151                5                                 El Fort Pienc
# ..    ...              ...                                           ...
# 69    215               69  Diagonal Mar i el Front Marítim del Poblenou
# 70    216               70                         El Besós i el Maresme
# 71    217               71                       Provençals del Poblenou
# 72    218               72                      Sant Martí de Provençals
# 73    219               73                           La Verneda i la Pau
#
#       Education Level  Percentage Level  Percentage Level BCN
# 1   Estudis superiors              27.5                  34.9
# 2   Estudis superiors              30.5                  34.9
# 3   Estudis superiors              32.2                  34.9
# 4   Estudis superiors              44.1                  34.9
# 5   Estudis superiors              42.1                  34.9
# ..                ...               ...                   ...
# 69  Estudis superiors              43.2                  34.9
# 70  Estudis superiors              14.1                  34.9
# 71  Estudis superiors              29.0                  34.9
# 72  Estudis superiors              22.5                  34.9
# 73  Estudis superiors              16.5                  34.9
#
# [73 rows x 6 columns]

# %% [markdown]
# No education or incomplete Primary Studies

# %%
no_studies = no_studies.reset_index()
no_studies.index = no_studies.index + 1
no_studies['Percentage Level'] = no_studies['Percentage Level'].str.replace('%', '').str.replace(',', '.').astype(float)
no_studies['Percentage Level BCN'] = no_studies['Percentage Level BCN'].str.replace('%', '').str.replace(',', '.').astype(float)
display(no_studies)
# Out:
#     index  Neighborhood ID                             Neighborhood Name  \
# 1     293                1                                      El Raval
# 2     294                2                                El Barri Gòtic
# 3     295                3                                La Barceloneta
# 4     296                4         Sant Pere, Santa Caterina i la Ribera
# 5     297                5                                 El Fort Pienc
# ..    ...              ...                                           ...
# 69    361               69  Diagonal Mar i el Front Marítim del Poblenou
# 70    362               70                         El Besós i el Maresme
# 71    363               71                       Provençals del Poblenou
# 72    364               72                      Sant Martí de Provençals
# 73    365               73                           La Verneda i la Pau
#
#                         Education Level  Percentage Level  \
# 1   Sense estudis o primària incompleta               1.1
# 2   Sense estudis o primària incompleta               0.8
# 3   Sense estudis o primària incompleta               1.9
# 4   Sense estudis o primària incompleta               1.0
# 5   Sense estudis o primària incompleta               0.9
# ..                                  ...               ...
# 69  Sense estudis o primària incompleta               1.3
# 70  Sense estudis o primària incompleta               2.6
# 71  Sense estudis o primària incompleta               1.7
# 72  Sense estudis o primària incompleta               2.1
# 73  Sense estudis o primària incompleta               2.9
#
#     Percentage Level BCN
# 1                    1.5
# 2                    1.5
# 3                    1.5
# 4                    1.5
# 5                    1.5
# ..                   ...
# 69                   1.5
# 70                   1.5
# 71                   1.5
# 72                   1.5
# 73                   1.5
#
# [73 rows x 6 columns]

# %%
# Assign Values
zones_educ_df['Primary School in people older than 15 (%)'] = primary_studies['Percentage Level']
zones_educ_df['Secondary School in people older than 15 (%)'] = secondary_studies['Percentage Level']
zones_educ_df['Middle Studies in people older than 15 (%)'] = middle_studies['Percentage Level']
zones_educ_df['Higher Studies in people older than 15 (%)'] = superior_studies['Percentage Level']
zones_educ_df['No education or Incomplete Primary School in people older than 15 (%)'] = no_studies['Percentage Level']
zones_educ_df.head(5)
# Out:
#                        Neighborhood Name District Name Associated  \
# 1                               el Raval             Ciutat Vella
# 2                         el Barri Gòtic             Ciutat Vella
# 3                         la Barceloneta             Ciutat Vella
# 4  Sant Pere, Santa Caterina i la Ribera             Ciutat Vella
# 5                          el Fort Pienc                 Eixample
#
#    Number of Services Distances  Density over Places Ratio  \
# 1                  45       NaN                      1.005
# 2                  13       NaN                      1.686
# 3                  23       NaN                      0.697
# 4                  35       NaN                      0.711
# 5                  19       NaN                      1.116
#
#    Avg. Students per Teacher Ratio             School Status  \
# 1                           25.858           public, charter
# 2                           21.320           public, charter
# 3                           10.571                    public
# 4                           22.947           public, charter
# 5                           21.341  private, public, charter
#
#                                         Centers Type  \
# 1  Kindergarten & Primary School, University, Kin...
# 2  FP, Kindergarten & Primary School, University,...
# 3  Secondary School, University, Kindergarten & P...
# 4  Kindergarten & Primary School, Secondary Schoo...
# 5  Secondary School, Kindergarten & Primary Schoo...
#
#                                  Centers Simple Type  \
# 1  Kindergarten & Primary School, University, Gen...
# 2  FP, Kindergarten & Primary School, University,...
# 3  High School, University, Kindergarten & Primar...
# 4  Kindergarten & Primary School, High School, Mu...
# 5  High School, Kindergarten & Primary School, Ge...
#
#        Centers Characteristics  ...  \
# 1  religious and non-religious  ...
# 2                non-religious  ...
# 3                non-religious  ...
# 4  religious and non-religious  ...
# 5                non-religious  ...
#
#    Young Population without Post-Compulsory Education (%)  \
# 1                                               30.4
# 2                                               34.6
# 3                                               17.2
# 4                                               13.6
# 5                                               11.2
#
#    Abscence Rate in 4th Grade (%)  Graduation Rate in 4th Grade (%)  \
# 1                             NaN                               NaN
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                             NaN                               NaN
# 5                             NaN                               NaN
#
#    Territorial Socioeconomic Index (IST)  Avg. Gini Index (%)  \
# 1                                   78.2               34.495
# 2                                   75.6               39.133
# 3                                   95.8               33.636
# 4                                  100.8               37.031
# 5                                  111.0               32.475
#
#    Population Density (hab/ha)  Net Population Density (hab/residential ha)  \
# 1                          429                                          952
# 2                          268                                          639
# 3                          124                                         1081
# 4                          199                                          683
# 5                          336                                          930
#
#    Number of Places Number of Students Number of Teachers
# 1             427.0             9128.0              353.0
# 2             159.0             1066.0               50.0
# 3             178.0             1554.0              147.0
# 4             280.0             4360.0              190.0
# 5             301.0             2817.0              132.0
#
# [5 rows x 27 columns]

# %% [markdown]
# ### 1.16. Absenteeism and Graduation 4th Grade Rate

# %%
# Dataset File
absent_grad_4_file = "/Users/mariatormo02/Desktop/TFG-Code/Data/Education Index Data/Absentisme_Graduació_4tESO.csv"

encoded = detect_encoding(absent_grad_4_file)
print(encoded)

# Read CSV
absent_grad_4_df = pd.read_csv(absent_grad_4_file, encoding='utf-16', sep='\t')
# Out:
# UTF-16

# %%
#display(absent_grad_4_df)
absent_grad_4_df.drop(columns={'TITOL SLOT 2', 'Any Dades', 'Absent n DIST', 'Absent n BCN',
                                'Absentisme/Taxa de Graduació BCN', 'Absentisme/Taxa de Graduació DIST'}, inplace=True)
absent_grad_4_df.rename(columns={'Codidistricte': 'District ID', 'Descdistricte': 'District Name',
                                  'Absent % DIST': 'Absence Rate', 'Absent % BCN': 'Absence Rate BCN',
                                  'Tgraduacio DIST': 'Graduation Rate', 'Tgraduacio BCN': 'Graduation Rate BCN'}, inplace=True)
absent_grad_4_df.index = absent_grad_4_df.index + 1
display(absent_grad_4_df)
# Out:
#     District ID        District Name Absence Rate Absence Rate BCN  \
# 1             1         Ciutat Vella          0,7              0,5
# 2             2             Eixample          0,2              0,5
# 3             3       Sants-Montjuïc            1              0,5
# 4             4            Les Corts          0,2              0,5
# 5             5  Sarrià-Sant Gervasi          0,1              0,5
# 6             6               Gràcia          0,2              0,5
# 7             7       Horta-Guinardó          0,3              0,5
# 8             8           Nou Barris          1,3              0,5
# 9             9          Sant Andreu          0,2              0,5
# 10           10           Sant Martí          0,8              0,5
#
#    Graduation Rate Graduation Rate BCN
# 1             87,3                88,6
# 2             92,9                88,6
# 3               85                88,6
# 4             92,3                88,6
# 5             88,6                88,6
# 6             93,2                88,6
# 7             92,4                88,6
# 8             73,1                88,6
# 9             90,9                88,6
# 10            89,3                88,6

# %%
absent_grad_4_df['Absence Rate'] = absent_grad_4_df['Absence Rate'].str.replace(',', '.').astype(float)
absent_grad_4_df['Absence Rate BCN'] = absent_grad_4_df['Absence Rate BCN'].str.replace(',', '.').astype(float)
absent_grad_4_df['Graduation Rate'] = absent_grad_4_df['Graduation Rate'].str.replace(',', '.').astype(float)
absent_grad_4_df['Graduation Rate BCN'] = absent_grad_4_df['Graduation Rate BCN'].str.replace(',', '.').astype(float)
absent_grad_4_df.head(5)
# Out:
#    District ID        District Name  Absence Rate  Absence Rate BCN  \
# 1            1         Ciutat Vella           0.7               0.5
# 2            2             Eixample           0.2               0.5
# 3            3       Sants-Montjuïc           1.0               0.5
# 4            4            Les Corts           0.2               0.5
# 5            5  Sarrià-Sant Gervasi           0.1               0.5
#
#    Graduation Rate  Graduation Rate BCN
# 1             87.3                 88.6
# 2             92.9                 88.6
# 3             85.0                 88.6
# 4             92.3                 88.6
# 5             88.6                 88.6

# %% [markdown]
# Neighborhood District mappings

# %%
district_file = "/Users/mariatormo02/Desktop/TFG-Code/Data/Context Index Data/BarcelonaCiutat_Barris.csv"
encoded = detect_encoding(district_file)
print(encoded)

# Read CSV
district_df = pd.read_csv(district_file, encoding='utf-8')
# Out:
# utf-8

# %%
district_df.drop(columns={'District ID', 'geometria_etrs89', 'geometria_wgs84'}, inplace=True)
display(district_df)
# Out:
#    District Name  Neighborhood ID  \
# 0   Ciutat Vella                1
# 1   Ciutat Vella                2
# 2   Ciutat Vella                3
# 3   Ciutat Vella                4
# 4       Eixample                5
# ..           ...              ...
# 68    Sant Martí               69
# 69    Sant Martí               70
# 70    Sant Martí               71
# 71    Sant Martí               72
# 72    Sant Martí               73
#
#                                Neighborhood Name
# 0                                       el Raval
# 1                                 el Barri Gòtic
# 2                                 la Barceloneta
# 3          Sant Pere, Santa Caterina i la Ribera
# 4                                  el Fort Pienc
# ..                                           ...
# 68  Diagonal Mar i el Front Marítim del Poblenou
# 69                         el Besòs i el Maresme
# 70                       Provençals del Poblenou
# 71                      Sant Martí de Provençals
# 72                           la Verneda i la Pau
#
# [73 rows x 3 columns]

# %%
absent_grad_4_df = pd.merge(absent_grad_4_df, district_df, on='District Name', how='inner')
absent_grad_4_df.index = absent_grad_4_df.index + 1
display(absent_grad_4_df)
# Out:
#     District ID District Name  Absence Rate  Absence Rate BCN  \
# 1             1  Ciutat Vella           0.7               0.5
# 2             1  Ciutat Vella           0.7               0.5
# 3             1  Ciutat Vella           0.7               0.5
# 4             1  Ciutat Vella           0.7               0.5
# 5             2      Eixample           0.2               0.5
# ..          ...           ...           ...               ...
# 69           10    Sant Martí           0.8               0.5
# 70           10    Sant Martí           0.8               0.5
# 71           10    Sant Martí           0.8               0.5
# 72           10    Sant Martí           0.8               0.5
# 73           10    Sant Martí           0.8               0.5
#
#     Graduation Rate  Graduation Rate BCN  Neighborhood ID  \
# 1              87.3                 88.6                1
# 2              87.3                 88.6                2
# 3              87.3                 88.6                3
# 4              87.3                 88.6                4
# 5              92.9                 88.6                5
# ..              ...                  ...              ...
# 69             89.3                 88.6               69
# 70             89.3                 88.6               70
# 71             89.3                 88.6               71
# 72             89.3                 88.6               72
# 73             89.3                 88.6               73
#
#                                Neighborhood Name
# 1                                       el Raval
# 2                                 el Barri Gòtic
# 3                                 la Barceloneta
# 4          Sant Pere, Santa Caterina i la Ribera
# 5                                  el Fort Pienc
# ..                                           ...
# 69  Diagonal Mar i el Front Marítim del Poblenou
# 70                         el Besòs i el Maresme
# 71                       Provençals del Poblenou
# 72                      Sant Martí de Provençals
# 73                           la Verneda i la Pau
#
# [73 rows x 8 columns]

# %%
# Assign Value
zones_educ_df['Abscence Rate in 4th Grade (%)'] = absent_grad_4_df['Absence Rate']
zones_educ_df['Graduation Rate in 4th Grade (%)'] = absent_grad_4_df['Graduation Rate']
zones_educ_df.head(7)
# Out:
#                        Neighborhood Name District Name Associated  \
# 1                               el Raval             Ciutat Vella
# 2                         el Barri Gòtic             Ciutat Vella
# 3                         la Barceloneta             Ciutat Vella
# 4  Sant Pere, Santa Caterina i la Ribera             Ciutat Vella
# 5                          el Fort Pienc                 Eixample
# 6                     la Sagrada Família                 Eixample
# 7                 la Dreta de l'Eixample                 Eixample
#
#    Number of Services Distances  Density over Places Ratio  \
# 1                  45       NaN                      1.005
# 2                  13       NaN                      1.686
# 3                  23       NaN                      0.697
# 4                  35       NaN                      0.711
# 5                  19       NaN                      1.116
# 6                  24       NaN                      3.547
# 7                  75       NaN                      0.250
#
#    Avg. Students per Teacher Ratio             School Status  \
# 1                           25.858           public, charter
# 2                           21.320           public, charter
# 3                           10.571                    public
# 4                           22.947           public, charter
# 5                           21.341  private, public, charter
# 6                           45.774  private, public, charter
# 7                           69.438           public, charter
#
#                                         Centers Type  \
# 1  Kindergarten & Primary School, University, Kin...
# 2  FP, Kindergarten & Primary School, University,...
# 3  Secondary School, University, Kindergarten & P...
# 4  Kindergarten & Primary School, Secondary Schoo...
# 5  Secondary School, Kindergarten & Primary Schoo...
# 6  Kindergarten & Primary School, Music School, F...
# 7  Secondary School & FP, Kindergarten, Primary &...
#
#                                  Centers Simple Type  \
# 1  Kindergarten & Primary School, University, Gen...
# 2  FP, Kindergarten & Primary School, University,...
# 3  High School, University, Kindergarten & Primar...
# 4  Kindergarten & Primary School, High School, Mu...
# 5  High School, Kindergarten & Primary School, Ge...
# 6  Kindergarten & Primary School, Music School, F...
# 7  High School, General School (with kindergarten...
#
#        Centers Characteristics  ...  \
# 1  religious and non-religious  ...
# 2                non-religious  ...
# 3                non-religious  ...
# 4  religious and non-religious  ...
# 5                non-religious  ...
# 6  religious and non-religious  ...
# 7  religious and non-religious  ...
#
#    Young Population without Post-Compulsory Education (%)  \
# 1                                               30.4
# 2                                               34.6
# 3                                               17.2
# 4                                               13.6
# 5                                               11.2
# 6                                               10.3
# 7                                                7.6
#
#    Abscence Rate in 4th Grade (%)  Graduation Rate in 4th Grade (%)  \
# 1                             0.7                              87.3
# 2                             0.7                              87.3
# 3                             0.7                              87.3
# 4                             0.7                              87.3
# 5                             0.2                              92.9
# 6                             0.2                              92.9
# 7                             0.2                              92.9
#
#    Territorial Socioeconomic Index (IST)  Avg. Gini Index (%)  \
# 1                                   78.2               34.495
# 2                                   75.6               39.133
# 3                                   95.8               33.636
# 4                                  100.8               37.031
# 5                                  111.0               32.475
# 6                                  111.8               32.700
# 7                                  120.9               36.697
#
#    Population Density (hab/ha)  Net Population Density (hab/residential ha)  \
# 1                          429                                          952
# 2                          268                                          639
# 3                          124                                         1081
# 4                          199                                          683
# 5                          336                                          930
# 6                          493                                         1007
# 7                          211                                          392
#
#    Number of Places  Number of Students  Number of Teachers
# 1             427.0              9128.0               353.0
# 2             159.0              1066.0                50.0
# 3             178.0              1554.0               147.0
# 4             280.0              4360.0               190.0
# 5             301.0              2817.0               132.0
# 6             139.0              2838.0                62.0
# 7             844.0             11735.0               169.0
#
# [7 rows x 27 columns]

# %% [markdown]
# ### Save into CSV File

# %%
zones_educ_df.to_csv('educ_index_data.csv')

# %%
# Add Polygon
neighborhoods_file = "/Users/mariatormo02/Desktop/TFG-Code/Data/Context Index Data/BarcelonaCiutat_Barris.csv"
encoded = detect_encoding(neighborhoods_file)
print(encoded)

# Read CSV
neighborhoods_df = pd.read_csv(neighborhoods_file, encoding='utf-8')
# Out:
# utf-8

# %%
#display(neighborhoods_df)
neighborhoods_df.drop(columns={'District ID', 'District Name', 'Neighborhood Name', 'Neighborhood ID'}, inplace=True)
neighborhoods_df.rename(columns={'geometria_etrs89': 'Geo ETRS89', 'geometria_wgs84': 'Geo WGS84'}, inplace=True)
neighborhoods_df.index = neighborhoods_df.index + 1
display(neighborhoods_df)
# Out:
#                                            Geo ETRS89  \
# 1   POLYGON ((430164.372950341 4581940.39758424, 4...
# 2   POLYGON ((431192.082442968 4581854.86907373, 4...
# 3   POLYGON ((432800.888667699 4582084.69046333, 4...
# 4   POLYGON ((431735.899600634 4582445.23444175, 4...
# 5   POLYGON ((431743.977580732 4582629.06573617, 4...
# ..                                                ...
# 69  POLYGON ((434228.873282652 4584678.5490042, 43...
# 70  POLYGON ((434093.743891643 4585871.79499967, 4...
# 71  POLYGON ((432760.615644181 4584099.69680979, 4...
# 72  POLYGON ((432902.229521415 4584707.96513488, 4...
# 73  POLYGON ((433772.136039586 4586478.75148086, 4...
#
#                                             Geo WGS84
# 1   POLYGON ((2.16473952857229 41.3859611263672, 2...
# 2   POLYGON ((2.17703981017875 41.3852793578426, 2...
# 3   POLYGON ((2.1962542114702 41.3874852975771, 2....
# 4   POLYGON ((2.18347683856251 41.390642940051, 2....
# 5   POLYGON ((2.18355273505655 41.3922993404645, 2...
# ..                                                ...
# 69  POLYGON ((2.21305050684114 41.4109655883131, 2...
# 70  POLYGON ((2.21130382869618 41.4217017644346, 2...
# 71  POLYGON ((2.19554880988141 41.4056305449051, 2...
# 72  POLYGON ((2.19717547409715 41.4111208750969, 2...
# 73  POLYGON ((2.20738904098433 41.4271419991399, 2...
#
# [73 rows x 2 columns]

# %%
# Append Columns
zones_educ_geo_df = pd.concat([zones_educ_df, neighborhoods_df], axis=1)
display(zones_educ_geo_df)
# Out:
#                                Neighborhood Name District Name Associated  \
# 1                                       el Raval             Ciutat Vella
# 2                                 el Barri Gòtic             Ciutat Vella
# 3                                 la Barceloneta             Ciutat Vella
# 4          Sant Pere, Santa Caterina i la Ribera             Ciutat Vella
# 5                                  el Fort Pienc                 Eixample
# ..                                           ...                      ...
# 69  Diagonal Mar i el Front Marítim del Poblenou               Sant Martí
# 70                         el Besòs i el Maresme               Sant Martí
# 71                       Provençals del Poblenou               Sant Martí
# 72                      Sant Martí de Provençals               Sant Martí
# 73                           la Verneda i la Pau               Sant Martí
#
#     Number of Services Distances  Density over Places Ratio  \
# 1                   45       NaN                      1.005
# 2                   13       NaN                      1.686
# 3                   23       NaN                      0.697
# 4                   35       NaN                      0.711
# 5                   19       NaN                      1.116
# ..                 ...       ...                        ...
# 69                   7       NaN                      1.090
# 70                  13       NaN                      0.601
# 71                  17       NaN                      1.237
# 72                  19       NaN                      0.579
# 73                  15       NaN                      1.454
#
#     Avg. Students per Teacher Ratio             School Status  \
# 1                            25.858           public, charter
# 2                            21.320           public, charter
# 3                            10.571                    public
# 4                            22.947           public, charter
# 5                            21.341  private, public, charter
# ..                              ...                       ...
# 69                              NaN           public, charter
# 70                           28.527           public, charter
# 71                           21.911           public, charter
# 72                           25.518           public, charter
# 73                           12.449           public, charter
#
#                                          Centers Type  \
# 1   Kindergarten & Primary School, University, Kin...
# 2   FP, Kindergarten & Primary School, University,...
# 3   Secondary School, University, Kindergarten & P...
# 4   Kindergarten & Primary School, Secondary Schoo...
# 5   Secondary School, Kindergarten & Primary Schoo...
# ..                                                ...
# 69  Kindergarten, Primary & Secondary School, FP, ...
# 70  Kindergarten & Primary School, Secondary Schoo...
# 71  Kindergarten & Primary School, University, Inf...
# 72  Kindergarten & Primary School, Kindergarten, P...
# 73  FP, Kindergarten & Primary School, Secondary S...
#
#                                   Centers Simple Type  \
# 1   Kindergarten & Primary School, University, Gen...
# 2   FP, Kindergarten & Primary School, University,...
# 3   High School, University, Kindergarten & Primar...
# 4   Kindergarten & Primary School, High School, Mu...
# 5   High School, Kindergarten & Primary School, Ge...
# ..                                                ...
# 69  General School (with kindergarten), FP, Kinder...
# 70  Kindergarten & Primary School, High School, Un...
# 71  Kindergarten & Primary School, University, Inf...
# 72  Kindergarten & Primary School, General School ...
# 73  FP, Kindergarten & Primary School, High School...
#
#         Centers Characteristics  ...  Graduation Rate in 4th Grade (%)  \
# 1   religious and non-religious  ...                              87.3
# 2                 non-religious  ...                              87.3
# 3                 non-religious  ...                              87.3
# 4   religious and non-religious  ...                              87.3
# 5                 non-religious  ...                              92.9
# ..                          ...  ...                               ...
# 69                non-religious  ...                              89.3
# 70  religious and non-religious  ...                              89.3
# 71                non-religious  ...                              89.3
# 72  religious and non-religious  ...                              89.3
# 73  religious and non-religious  ...                              89.3
#
#     Territorial Socioeconomic Index (IST)  Avg. Gini Index (%)  \
# 1                                    78.2               34.495
# 2                                    75.6               39.133
# 3                                    95.8               33.636
# 4                                   100.8               37.031
# 5                                   111.0               32.475
# ..                                    ...                  ...
# 69                                  116.6               31.814
# 70                                   72.4               29.715
# 71                                  107.0               29.242
# 72                                  102.9               27.361
# 73                                   96.0               27.129
#
#     Population Density (hab/ha)  Net Population Density (hab/residential ha)  \
# 1                           429                                          952
# 2                           268                                          639
# 3                           124                                         1081
# 4                           199                                          683
# 5                           336                                          930
# ..                          ...                                          ...
# 69                          109                                          556
# 70                          212                                          913
# 71                          193                                         1368
# 72                          355                                         1111
# 73                          253                                          714
#
#     Number of Places  Number of Students  Number of Teachers  \
# 1              427.0              9128.0               353.0
# 2              159.0              1066.0                50.0
# 3              178.0              1554.0               147.0
# 4              280.0              4360.0               190.0
# 5              301.0              2817.0               132.0
# ..               ...                 ...                 ...
# 69             100.0              2628.0                 NaN
# 70             353.0              5363.0               188.0
# 71             156.0              1972.0                90.0
# 72             613.0              4287.0               168.0
# 73             174.0              3162.0               254.0
#
#                                            Geo ETRS89  \
# 1   POLYGON ((430164.372950341 4581940.39758424, 4...
# 2   POLYGON ((431192.082442968 4581854.86907373, 4...
# 3   POLYGON ((432800.888667699 4582084.69046333, 4...
# 4   POLYGON ((431735.899600634 4582445.23444175, 4...
# 5   POLYGON ((431743.977580732 4582629.06573617, 4...
# ..                                                ...
# 69  POLYGON ((434228.873282652 4584678.5490042, 43...
# 70  POLYGON ((434093.743891643 4585871.79499967, 4...
# 71  POLYGON ((432760.615644181 4584099.69680979, 4...
# 72  POLYGON ((432902.229521415 4584707.96513488, 4...
# 73  POLYGON ((433772.136039586 4586478.75148086, 4...
#
#                                             Geo WGS84
# 1   POLYGON ((2.16473952857229 41.3859611263672, 2...
# 2   POLYGON ((2.17703981017875 41.3852793578426, 2...
# 3   POLYGON ((2.1962542114702 41.3874852975771, 2....
# 4   POLYGON ((2.18347683856251 41.390642940051, 2....
# 5   POLYGON ((2.18355273505655 41.3922993404645, 2...
# ..                                                ...
# 69  POLYGON ((2.21305050684114 41.4109655883131, 2...
# 70  POLYGON ((2.21130382869618 41.4217017644346, 2...
# 71  POLYGON ((2.19554880988141 41.4056305449051, 2...
# 72  POLYGON ((2.19717547409715 41.4111208750969, 2...
# 73  POLYGON ((2.20738904098433 41.4271419991399, 2...
#
# [73 rows x 29 columns]

# %% [markdown]
# ### Save into CSV File (with geo polygon)

# %%
zones_educ_geo_df.to_csv('educ_index_data_geo.csv')
