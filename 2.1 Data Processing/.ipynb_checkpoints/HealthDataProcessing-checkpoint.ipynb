# %% [markdown]
# # Health Services

# %% [markdown]
# ## 2. Health Services Data

# %%
import pandas as pd

# %% [markdown]
# ### 1.1. Load Datasets
#
# Health Services:
#
# - Hospitals & CAPs: *Hospitales y servicios de atención primaria de la ciudad de Barcelona - Open Data BCN*
#
# - Pharmacies: *Farmacias de la ciudad de Barcelona - Open Data BCN*, *Catálogo de farmacias de Cataluña*
#
# - Day Centers: *Centros de día para las personas mayores de la ciudad de Barcelona - Open Data BCN*
#
# - Ederly Residences: *Residencias para las personas mayores de la ciudad de Barcelona - Open Data BCN*
#
# - Indicators: *Barcelona. La ciudad al día. → relación indicadores de ámbito de la salud - Open Data BCN*, *Indicadores de salud de la Central de Resultados: atención primaria*
#
# - Other Equipments: *Listado de equipamientos de sanidad de la ciudad de Barcelona - Open Data BCN*, *Establecimientos sanitarios autorizados en Cataluña*, *Clínicas Dentales autorizadas en Cataluña*

# %%
# Remove Warnings
import warnings
warnings.filterwarnings("ignore")

# %%
import chardet

def detect_encoding(file_path):
    with open(file_path, 'rb') as f:
        result = chardet.detect(f.read())
    return result['encoding']

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# Usage
#encoded = detect_encoding(path_files + hospitals_caps_file)
#print(encoded)

# %%
# Dataset Files

hospitals_caps_file = "opendatabcn_sanitat_hospitals-i-centres-atencio-primaria.csv"
pharmacies_bcn_file = "opendatabcn_sanitat_farmacies.csv"
#pharmacies_cat_file = "Cat_leg_de_farm_cies_de_Catalunya_20240403.csv"
day_centers_file = "opendatabcn_serveis-socials_centres-dia-gent-gran.csv"
residences_file = "opendatabcn_serveis-socials_residencies-gent-gran.csv"
health_equip_bcn_file = "opendatabcn_llista-equipaments_sanitat-csv.csv"
#health_equip_cat_file = "Establiments_sanitaris_autoritzats_a_Catalunya_20240403.csv"
#dental_cat_file = "Cl_niques_dentals_autoritzades_a_Catalunya_20240403.csv"
indicators_bcn_file = "2024_laciutataldia.csv"
# falta: indicators_CAP_file = ""

path_files = "/Users/mariatormo02/Desktop/TFG-Code/Data/Health Facilities/"


# Read CSVs
hospitals_caps_df = pd.read_csv(path_files + hospitals_caps_file, encoding='utf-16')
pharmacies_bcn_df = pd.read_csv(path_files + pharmacies_bcn_file, encoding='utf-16')
#pharmacies_cat_df = pd.read_csv(path_files + pharmacies_cat_file, encoding='utf-8')
day_centers_df = pd.read_csv(path_files + day_centers_file, encoding='utf-16')
residences_df = pd.read_csv(path_files + residences_file, encoding='utf-16')
health_equip_bcn_df = pd.read_csv(path_files + health_equip_bcn_file, encoding='utf-16')
#health_equip_cat_df = pd.read_csv(path_files + health_equip_cat_file, encoding='utf-8')
#dental_cat_df = pd.read_csv(path_files + dental_cat_file, encoding='utf-8')
indicators_bcn_df = pd.read_csv(path_files + indicators_bcn_file, encoding='utf-8')
# falta: indicators_CAP_df = pd.read_csv(path_files + indicators_CAP_file, encoding='utf-8')

# %% [markdown]
# ### 1.2. Dataset Analysis

# %%
# Functions Definition
def null_function (df):
    # Extract columns without nulls
    non_null_cols = df.columns[df.notnull().all()]

    # Extract columns with nulls
    null_cols = df.columns[df.isnull().any()]

    # Get count and percentage of null values for columns with nulls
    null_count = df[null_cols].isnull().sum()
    null_percentage = (null_count / len(df)) * 100

    # Combine information into a DataFrame
    info_df = pd.DataFrame({
        'Column': null_count.index,
        'Null Count': null_count.values,
        'Null Percentage': null_percentage.values
    })
    return non_null_cols, info_df

def has_duplicates(df, col_name):
    if df[col_name].duplicated().any():
        print("There's duplicate values in column", col_name)
    else:
        print("No duplicate values in column", col_name)

# %% [markdown]
# #### 1) Hospitals & CAPs

# %%
display(hospitals_caps_df.info())
print("\nSTATISTICS:\n")
#display(hospitals_caps_df.describe())
non_null_cols, info_df = null_function(hospitals_caps_df)
print("\nColumns with no null values:", non_null_cols)
print("\nColumns with null values:")
display(info_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   register_id                    142 non-null    object
#  1   name                           142 non-null    object
#  2   institution_id                 17 non-null     float64
#  3   institution_name               17 non-null     object
#  4   created                        142 non-null    object
#  5   modified                       142 non-null    object
#  6   addresses_roadtype_id          0 non-null      float64
#  7   addresses_roadtype_name        0 non-null      float64
#  8   addresses_road_id              141 non-null    float64
#  9   addresses_road_name            141 non-null    object
#  10  addresses_start_street_number  141 non-null    float64
#  11  addresses_end_street_number    13 non-null     float64
#  12  addresses_neighborhood_id      142 non-null    int64
#  13  addresses_neighborhood_name    142 non-null    object
#  14  addresses_district_id          142 non-null    int64
#  15  addresses_district_name        142 non-null    object
#  16  addresses_zip_code             141 non-null    float64
#  17  addresses_town                 142 non-null    object
#  18  addresses_main_address         142 non-null    bool
#  19  addresses_type                 0 non-null      float64
#  20  values_id                      141 non-null    float64
#  21  values_attribute_id            141 non-null    float64
#  22  values_category                141 non-null    object
#  23  values_attribute_name          141 non-null    object
#  24  values_value                   141 non-null    object
#  25  values_outstanding             141 non-null    object
#  26  values_description             5 non-null      object
#  27  secondary_filters_id           142 non-null    int64
#  28  secondary_filters_name         142 non-null    object
#  29  secondary_filters_fullpath     142 non-null    object
#  30  secondary_filters_tree         142 non-null    int64
#  31  secondary_filters_asia_id      142 non-null    int64
#  32  geo_epgs_25831_x               142 non-null    float64
#  33  geo_epgs_25831_y               142 non-null    float64
#  34  geo_epgs_4326_lat              142 non-null    float64
#  35  geo_epgs_4326_lon              142 non-null    float64
#  36  estimated_dates                0 non-null      float64
#  37  start_date                     0 non-null      float64
#  38  end_date                       0 non-null      float64
# dtypes: bool(1), float64(17), int64(5), object(16)
# memory usage: 42.4+ KB
# None
# STATISTICS:
#
#
# Columns with no null values: Index(['register_id', 'name', 'created', 'modified',
#        'addresses_neighborhood_id', 'addresses_neighborhood_name',
#        'addresses_district_id', 'addresses_district_name', 'addresses_town',
#        'addresses_main_address', 'secondary_filters_id',
#        'secondary_filters_name', 'secondary_filters_fullpath',
#        'secondary_filters_tree', 'secondary_filters_asia_id',
#        'geo_epgs_25831_x', 'geo_epgs_25831_y', 'geo_epgs_4326_lat',
#        'geo_epgs_4326_lon'],
#       dtype='object')
#
# Columns with null values:
#                            Column  Null Count  Null Percentage
# 0                  institution_id         125        88.028169
# 1                institution_name         125        88.028169
# 2           addresses_roadtype_id         142       100.000000
# 3         addresses_roadtype_name         142       100.000000
# 4               addresses_road_id           1         0.704225
# 5             addresses_road_name           1         0.704225
# 6   addresses_start_street_number           1         0.704225
# 7     addresses_end_street_number         129        90.845070
# 8              addresses_zip_code           1         0.704225
# 9                  addresses_type         142       100.000000
# 10                      values_id           1         0.704225
# 11            values_attribute_id           1         0.704225
# 12                values_category           1         0.704225
# 13          values_attribute_name           1         0.704225
# 14                   values_value           1         0.704225
# 15             values_outstanding           1         0.704225
# 16             values_description         137        96.478873
# 17                estimated_dates         142       100.000000
# 18                     start_date         142       100.000000
# 19                       end_date         142       100.000000

# %% [markdown]
# *Seeing the amount of NULL values for each column, we will drop: institution_id, institution_name, addresses_roadtype_id, addresses_roadtype_name	, addresses_end_street_number, addresses_type, values_description, estimated_dates, start_date, end_date. Also, the columns created and modified won't be used for the moment.*

# %%
# Drop columns with almost all null values
columns_to_drop_hospitals_caps = ['created', 'modified', 'institution_id', 'institution_name', 'addresses_roadtype_id', 'addresses_roadtype_name' ,
                                  'addresses_end_street_number', 'addresses_type', 'values_description', 'estimated_dates', 'start_date', 'end_date']

hospitals_caps_df.drop(columns=columns_to_drop_hospitals_caps, inplace=True)

# Useless: Identifiador Via, Indicador si l'adreça, Valor de l'atribut identificador, Valor de l'atribut, Valors d'atribut Destacat,
# Arbres d'equivalència Identificador, Arbres d'equivalència Ruta, Arbres d'equivalència, Arbres d'equivalència  Id Asia
#useless_cols = ['addresses_road_id', 'addresses_main_address', 'values_id', 'values_attribute_id', 'values_outstanding', 'secondary_filters_id',
#                'secondary_filters_fullpath', 'secondary_filters_tree', 'secondary_filters_asia_id', 'values_category', 'values_attribute_name']
useless_cols = ['addresses_main_address', 'values_id', 'values_attribute_id', 'values_outstanding', 'secondary_filters_id',
                'secondary_filters_fullpath', 'secondary_filters_tree', 'secondary_filters_asia_id', 'values_category', 'values_attribute_name']
hospitals_caps_df.drop(columns=useless_cols, inplace=True)
hospitals_caps_df.head(10)
# Out:
#     register_id                                        name  \
# 0   ﻿1015170605          Centre d'Atenció Primària Sardenya
# 1     ﻿68125439         Instituto Oftalmológico Tres Torres
# 2  ﻿75990049258                      Clínica Mi Tres Torres
# 3  ﻿93056132443         Centre d'Atenció Primària Montnegre
# 4  ﻿75990060288                       Hospital de Barcelona
# 5  ﻿75990027608         Hospital Universitari Quirón Dexeus
# 6  ﻿92086031184  Centre d'Atenció Primària Ciutat Meridiana
# 7  ﻿92086031184  Centre d'Atenció Primària Ciutat Meridiana
# 8  ﻿75990029810                            Clínica Corachan
# 9  ﻿99400187136                    Clinica del Son Estivill
#
#    addresses_road_id      addresses_road_name  addresses_start_street_number  \
# 0            76807.0               C Sardenya                          466.0
# 1            28000.0              Via Augusta                          281.0
# 2           103502.0            C Doctor Roux                           76.0
# 3           219100.0              C Montnegre                           21.0
# 4           144601.0              Av Diagonal                          660.0
# 5           285002.0           C Sabino Arana                            5.0
# 6           300503.0  C Sant Feliu de Codines                            2.0
# 7           300503.0  C Sant Feliu de Codines                            2.0
# 8            51500.0                 C Buïgas                           19.0
# 9           288601.0                C Rosales                            9.0
#
#    addresses_neighborhood_id addresses_neighborhood_name  \
# 0                         33            el Baix Guinardó
# 1                         24             les Tres Torres
# 2                         24             les Tres Torres
# 3                         19                   les Corts
# 4                         19                   les Corts
# 5                         20  la Maternitat i Sant Ramon
# 6                         54                  Torre Baró
# 7                         54                  Torre Baró
# 8                         24             les Tres Torres
# 9                         24             les Tres Torres
#
#    addresses_district_id addresses_district_name  addresses_zip_code  \
# 0                      7          Horta-Guinardó              8025.0
# 1                      5     Sarrià-Sant Gervasi              8017.0
# 2                      5     Sarrià-Sant Gervasi              8017.0
# 3                      4               Les Corts              8029.0
# 4                      4               Les Corts              8034.0
# 5                      4               Les Corts              8028.0
# 6                      8              Nou Barris              8033.0
# 7                      8              Nou Barris              8033.0
# 8                      5     Sarrià-Sant Gervasi              8017.0
# 9                      5     Sarrià-Sant Gervasi              8017.0
#
#   addresses_town values_value     secondary_filters_name  geo_epgs_25831_x  \
# 0      BARCELONA    935674380                       CAPs     430258.038349
# 1      BARCELONA    900842848      Hospitals i clíniques     427267.424673
# 2      BARCELONA    932041300      Hospitals i clíniques     427179.337491
# 3      BARCELONA    933632965                       CAPs     427992.371870
# 4      BARCELONA    932542400      Hospitals i clíniques     427228.518238
# 5      BARCELONA    932274747      Hospitals i clíniques     426932.169229
# 6      BARCELONA    933508889                       CAPs     431637.809801
# 7      BARCELONA    933508889  Centres urgències (CUAPs)     431637.809801
# 8      BARCELONA    932545800      Hospitals i clíniques     427330.726158
# 9      BARCELONA    932121354      Hospitals i clíniques     427155.105668
#
#    geo_epgs_25831_y  geo_epgs_4326_lat  geo_epgs_4326_lon
# 0      4.584550e+06          41.409469           2.165559
# 1      4.583269e+06          41.397670           2.129935
# 2      4.583445e+06          41.399249           2.128860
# 3      4.582146e+06          41.387618           2.138740
# 4      4.582406e+06          41.389892           2.129574
# 5      4.581895e+06          41.385265           2.126091
# 6      4.590193e+06          41.460414           2.181428
# 7      4.590193e+06          41.460414           2.181428
# 8      4.582808e+06          41.393523           2.130748
# 9      4.583714e+06          41.401672           2.128538

# %%
# Observe New Info
#display(hospitals_caps_df.info())

# Check if duplicates
#has_duplicates(hospitals_caps_df, 'register_id')

# %%
# Print unique values for characteristics column before merging stuff
print("Unique Characteristics:\n")
print(hospitals_caps_df['secondary_filters_name'].unique(), "\n")

# Remove weird characteristic (None)

# Aggregate secondary_filters_name (caract.) by register_id and replace column
aggregated_sec_filters = hospitals_caps_df.groupby('register_id')['secondary_filters_name'].transform(lambda x: ', '.join(x))
hospitals_caps_df['secondary_filters_name'] = aggregated_sec_filters
#display(schools_reglat_df.head(10))

# Drop duplicated register_id
hospitals_caps_df.drop_duplicates(subset='register_id', inplace=True)
display(hospitals_caps_df.head(10))
# Out:
# Unique Characteristics:
#
# ['CAPs' 'Hospitals i clíniques' 'Centres urgències (CUAPs)'
#  'Centres de dia gent gran' 'Residències gent gran']
#      register_id                                        name  \
# 0    ﻿1015170605          Centre d'Atenció Primària Sardenya
# 1      ﻿68125439         Instituto Oftalmológico Tres Torres
# 2   ﻿75990049258                      Clínica Mi Tres Torres
# 3   ﻿93056132443         Centre d'Atenció Primària Montnegre
# 4   ﻿75990060288                       Hospital de Barcelona
# 5   ﻿75990027608         Hospital Universitari Quirón Dexeus
# 6   ﻿92086031184  Centre d'Atenció Primària Ciutat Meridiana
# 8   ﻿75990029810                            Clínica Corachan
# 9   ﻿99400187136                    Clinica del Son Estivill
# 10  ﻿99400417756          Cliníca Axisclínic *Comte d'Urgell
#
#     addresses_road_id      addresses_road_name  addresses_start_street_number  \
# 0             76807.0               C Sardenya                          466.0
# 1             28000.0              Via Augusta                          281.0
# 2            103502.0            C Doctor Roux                           76.0
# 3            219100.0              C Montnegre                           21.0
# 4            144601.0              Av Diagonal                          660.0
# 5            285002.0           C Sabino Arana                            5.0
# 6            300503.0  C Sant Feliu de Codines                            2.0
# 8             51500.0                 C Buïgas                           19.0
# 9            288601.0                C Rosales                            9.0
# 10           349706.0         C Comte d'Urgell                          168.0
#
#     addresses_neighborhood_id      addresses_neighborhood_name  \
# 0                          33                 el Baix Guinardó
# 1                          24                  les Tres Torres
# 2                          24                  les Tres Torres
# 3                          19                        les Corts
# 4                          19                        les Corts
# 5                          20       la Maternitat i Sant Ramon
# 6                          54                       Torre Baró
# 8                          24                  les Tres Torres
# 9                          24                  les Tres Torres
# 10                          8  l'Antiga Esquerra de l'Eixample
#
#     addresses_district_id addresses_district_name  addresses_zip_code  \
# 0                       7          Horta-Guinardó              8025.0
# 1                       5     Sarrià-Sant Gervasi              8017.0
# 2                       5     Sarrià-Sant Gervasi              8017.0
# 3                       4               Les Corts              8029.0
# 4                       4               Les Corts              8034.0
# 5                       4               Les Corts              8028.0
# 6                       8              Nou Barris              8033.0
# 8                       5     Sarrià-Sant Gervasi              8017.0
# 9                       5     Sarrià-Sant Gervasi              8017.0
# 10                      2                Eixample              8036.0
#
#    addresses_town values_value           secondary_filters_name  \
# 0       BARCELONA    935674380                             CAPs
# 1       BARCELONA    900842848            Hospitals i clíniques
# 2       BARCELONA    932041300            Hospitals i clíniques
# 3       BARCELONA    933632965                             CAPs
# 4       BARCELONA    932542400            Hospitals i clíniques
# 5       BARCELONA    932274747            Hospitals i clíniques
# 6       BARCELONA    933508889  CAPs, Centres urgències (CUAPs)
# 8       BARCELONA    932545800            Hospitals i clíniques
# 9       BARCELONA    932121354            Hospitals i clíniques
# 10      BARCELONA    934546947            Hospitals i clíniques
#
#     geo_epgs_25831_x  geo_epgs_25831_y  geo_epgs_4326_lat  geo_epgs_4326_lon
# 0      430258.038349      4.584550e+06          41.409469           2.165559
# 1      427267.424673      4.583269e+06          41.397670           2.129935
# 2      427179.337491      4.583445e+06          41.399249           2.128860
# 3      427992.371870      4.582146e+06          41.387618           2.138740
# 4      427228.518238      4.582406e+06          41.389892           2.129574
# 5      426932.169229      4.581895e+06          41.385265           2.126091
# 6      431637.809801      4.590193e+06          41.460414           2.181428
# 8      427330.726158      4.582808e+06          41.393523           2.130748
# 9      427155.105668      4.583714e+06          41.401672           2.128538
# 10     429152.144616      4.582051e+06          41.386871           2.152621

# %%
# Rename Columns
hospitals_caps_df = hospitals_caps_df.rename(columns={"addresses_road_id": "Street ID", "name": "Name", "addresses_road_name": "Road Name", "addresses_start_street_number": "Street Number",
                                                      "addresses_neighborhood_id": "Neighborhood ID", "addresses_neighborhood_name": "Neighborhood Name",
                                                      "addresses_district_id": "District ID", "addresses_district_name": "District Name",
                                                      "addresses_zip_code": "ZipCode","addresses_town": "Town",
                                                      "values_value": "Phone Number", "secondary_filters_name": "Service Type",
                                                      "geo_epgs_4326_lat": "Latitude", "geo_epgs_4326_lon": "Longitude"})
display(hospitals_caps_df.head(10))
# Out:
#      register_id                                        Name  Street ID  \
# 0    ﻿1015170605          Centre d'Atenció Primària Sardenya    76807.0
# 1      ﻿68125439         Instituto Oftalmológico Tres Torres    28000.0
# 2   ﻿75990049258                      Clínica Mi Tres Torres   103502.0
# 3   ﻿93056132443         Centre d'Atenció Primària Montnegre   219100.0
# 4   ﻿75990060288                       Hospital de Barcelona   144601.0
# 5   ﻿75990027608         Hospital Universitari Quirón Dexeus   285002.0
# 6   ﻿92086031184  Centre d'Atenció Primària Ciutat Meridiana   300503.0
# 8   ﻿75990029810                            Clínica Corachan    51500.0
# 9   ﻿99400187136                    Clinica del Son Estivill   288601.0
# 10  ﻿99400417756          Cliníca Axisclínic *Comte d'Urgell   349706.0
#
#                   Road Name  Street Number  Neighborhood ID  \
# 0                C Sardenya          466.0               33
# 1               Via Augusta          281.0               24
# 2             C Doctor Roux           76.0               24
# 3               C Montnegre           21.0               19
# 4               Av Diagonal          660.0               19
# 5            C Sabino Arana            5.0               20
# 6   C Sant Feliu de Codines            2.0               54
# 8                  C Buïgas           19.0               24
# 9                 C Rosales            9.0               24
# 10         C Comte d'Urgell          168.0                8
#
#                   Neighborhood Name  District ID        District Name  \
# 0                  el Baix Guinardó            7       Horta-Guinardó
# 1                   les Tres Torres            5  Sarrià-Sant Gervasi
# 2                   les Tres Torres            5  Sarrià-Sant Gervasi
# 3                         les Corts            4            Les Corts
# 4                         les Corts            4            Les Corts
# 5        la Maternitat i Sant Ramon            4            Les Corts
# 6                        Torre Baró            8           Nou Barris
# 8                   les Tres Torres            5  Sarrià-Sant Gervasi
# 9                   les Tres Torres            5  Sarrià-Sant Gervasi
# 10  l'Antiga Esquerra de l'Eixample            2             Eixample
#
#     ZipCode       Town Phone Number                     Service Type  \
# 0    8025.0  BARCELONA    935674380                             CAPs
# 1    8017.0  BARCELONA    900842848            Hospitals i clíniques
# 2    8017.0  BARCELONA    932041300            Hospitals i clíniques
# 3    8029.0  BARCELONA    933632965                             CAPs
# 4    8034.0  BARCELONA    932542400            Hospitals i clíniques
# 5    8028.0  BARCELONA    932274747            Hospitals i clíniques
# 6    8033.0  BARCELONA    933508889  CAPs, Centres urgències (CUAPs)
# 8    8017.0  BARCELONA    932545800            Hospitals i clíniques
# 9    8017.0  BARCELONA    932121354            Hospitals i clíniques
# 10   8036.0  BARCELONA    934546947            Hospitals i clíniques
#
#     geo_epgs_25831_x  geo_epgs_25831_y   Latitude  Longitude
# 0      430258.038349      4.584550e+06  41.409469   2.165559
# 1      427267.424673      4.583269e+06  41.397670   2.129935
# 2      427179.337491      4.583445e+06  41.399249   2.128860
# 3      427992.371870      4.582146e+06  41.387618   2.138740
# 4      427228.518238      4.582406e+06  41.389892   2.129574
# 5      426932.169229      4.581895e+06  41.385265   2.126091
# 6      431637.809801      4.590193e+06  41.460414   2.181428
# 8      427330.726158      4.582808e+06  41.393523   2.130748
# 9      427155.105668      4.583714e+06  41.401672   2.128538
# 10     429152.144616      4.582051e+06  41.386871   2.152621

# %% [markdown]
# ### 2) Pharmacies
#
# Use pharmacies_bcn_df only

# %%
# PHARMACIES BARCELONA
display(pharmacies_bcn_df.info())
print("\nSTATISTICS:\n")
#display(pharmacies_bcn_df.describe())
non_null_cols, info_df = null_function(pharmacies_bcn_df)
print("\nColumns with no null values:", non_null_cols)
print("\nColumns with null values:")
display(info_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1133 entries, 0 to 1132
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   register_id                    1133 non-null   object
#  1   name                           1133 non-null   object
#  2   institution_id                 0 non-null      float64
#  3   institution_name               0 non-null      float64
#  4   created                        1133 non-null   object
#  5   modified                       1133 non-null   object
#  6   addresses_roadtype_id          0 non-null      float64
#  7   addresses_roadtype_name        0 non-null      float64
#  8   addresses_road_id              1133 non-null   int64
#  9   addresses_road_name            1133 non-null   object
#  10  addresses_start_street_number  1133 non-null   int64
#  11  addresses_end_street_number    33 non-null     float64
#  12  addresses_neighborhood_id      1133 non-null   int64
#  13  addresses_neighborhood_name    1133 non-null   object
#  14  addresses_district_id          1133 non-null   int64
#  15  addresses_district_name        1133 non-null   object
#  16  addresses_zip_code             1133 non-null   int64
#  17  addresses_town                 1133 non-null   object
#  18  addresses_main_address         1133 non-null   bool
#  19  addresses_type                 0 non-null      float64
#  20  values_id                      1133 non-null   int64
#  21  values_attribute_id            1133 non-null   int64
#  22  values_category                1133 non-null   object
#  23  values_attribute_name          1133 non-null   object
#  24  values_value                   1133 non-null   object
#  25  values_outstanding             1133 non-null   bool
#  26  values_description             29 non-null     object
#  27  secondary_filters_id           1133 non-null   int64
#  28  secondary_filters_name         1133 non-null   object
#  29  secondary_filters_fullpath     1133 non-null   object
#  30  secondary_filters_tree         1133 non-null   int64
#  31  secondary_filters_asia_id      1133 non-null   int64
#  32  geo_epgs_25831_x               1133 non-null   float64
#  33  geo_epgs_25831_y               1133 non-null   float64
#  34  geo_epgs_4326_lat              1133 non-null   float64
#  35  geo_epgs_4326_lon              1133 non-null   float64
#  36  estimated_dates                0 non-null      float64
#  37  start_date                     0 non-null      float64
#  38  end_date                       0 non-null      float64
# dtypes: bool(2), float64(13), int64(10), object(14)
# memory usage: 329.8+ KB
# None
# STATISTICS:
#
#
# Columns with no null values: Index(['register_id', 'name', 'created', 'modified', 'addresses_road_id',
#        'addresses_road_name', 'addresses_start_street_number',
#        'addresses_neighborhood_id', 'addresses_neighborhood_name',
#        'addresses_district_id', 'addresses_district_name',
#        'addresses_zip_code', 'addresses_town', 'addresses_main_address',
#        'values_id', 'values_attribute_id', 'values_category',
#        'values_attribute_name', 'values_value', 'values_outstanding',
#        'secondary_filters_id', 'secondary_filters_name',
#        'secondary_filters_fullpath', 'secondary_filters_tree',
#        'secondary_filters_asia_id', 'geo_epgs_25831_x', 'geo_epgs_25831_y',
#        'geo_epgs_4326_lat', 'geo_epgs_4326_lon'],
#       dtype='object')
#
# Columns with null values:
#                         Column  Null Count  Null Percentage
# 0               institution_id        1133       100.000000
# 1             institution_name        1133       100.000000
# 2        addresses_roadtype_id        1133       100.000000
# 3      addresses_roadtype_name        1133       100.000000
# 4  addresses_end_street_number        1100        97.087379
# 5               addresses_type        1133       100.000000
# 6           values_description        1104        97.440424
# 7              estimated_dates        1133       100.000000
# 8                   start_date        1133       100.000000
# 9                     end_date        1133       100.000000

# %% [markdown]
# *Seeing the amount of NULL values for each column, we will drop: institution_id, institution_name, addresses_roadtype_id, addresses_roadtype_name, addresses_end_street_number, addresses_type, values_description, estimated_dates, start_date, end_date. Also, the columns created and modified won't be used for the moment.*

# %%
# Drop columns with almost all null values
columns_to_drop_pharmacies_bcn = ['created', 'modified', 'institution_id', 'institution_name', 'addresses_roadtype_id', 'addresses_roadtype_name' ,
                                  'addresses_end_street_number', 'addresses_type', 'values_description', 'estimated_dates', 'start_date', 'end_date']

pharmacies_bcn_df.drop(columns=columns_to_drop_pharmacies_bcn, inplace=True)

# Useless: Identifiador Via, Indicador si l'adreça, Valor de l'atribut identificador, Valor de l'atribut, Valors d'atribut Destacat,
# Arbres d'equivalència Identificador, Arbres d'equivalència Ruta, Arbres d'equivalència, Arbres d'equivalència  Id Asia
#useless_cols = ['addresses_road_id', 'addresses_main_address', 'values_id', 'values_attribute_id', 'values_outstanding', 'secondary_filters_id',
#                'secondary_filters_fullpath', 'secondary_filters_tree', 'secondary_filters_asia_id', 'values_category', 'values_attribute_name']
useless_cols = ['addresses_main_address', 'values_id', 'values_attribute_id', 'values_outstanding', 'secondary_filters_id',
                'secondary_filters_fullpath', 'secondary_filters_tree', 'secondary_filters_asia_id', 'values_category', 'values_attribute_name']

pharmacies_bcn_df.drop(columns=useless_cols, inplace=True)
pharmacies_bcn_df.head(10)
# Out:
#     register_id                         name  addresses_road_id  \
# 0  ﻿75990017391      Farmàcia Hereus Lavilla              23200
# 1  ﻿75990017537    Farmàcia  Franquesa Massó              23403
# 2  ﻿75990017537    Farmàcia  Franquesa Massó              23403
# 3  ﻿75990048243    Farmàcia Bañeres Merinero             100800
# 4  ﻿75990048357        Farmàcia Sales Llavià             100800
# 5  ﻿75990064521       Farmàcia Pujol Pereita             148307
# 6  ﻿75990027321    Farmàcia Marta Homs Balló              44403
# 7  ﻿75990032969     Farmàcia Forcada Llamusí             700032
# 8  ﻿75990052487  Farmàcia Rodriguez Martinez             200000
# 9  ﻿75990038139       Farmàcia Sanchís Foret              74506
#
#       addresses_road_name  addresses_start_street_number  \
# 0       Carrer d'Argullós                             49
# 1                  Aribau                             18
# 2                  Aribau                             18
# 3  Carrer de la Diputació                            336
# 4               Diputació                            391
# 5               Pg Gràcia                            129
# 6               C Bolívia                             19
# 7          Ptge Andalusia                             14
# 8              C Marquesa                              3
# 9          Rbla Catalunya                            117
#
#    addresses_neighborhood_id            addresses_neighborhood_name  \
# 0                         52                         la Prosperitat
# 1                          8        l'Antiga Esquerra de l'Eixample
# 2                          8        l'Antiga Esquerra de l'Eixample
# 3                          7                 la Dreta de l'Eixample
# 4                          7                 la Dreta de l'Eixample
# 5                         31                      la Vila de Gràcia
# 6                         66      el Parc i la Llacuna del Poblenou
# 7                         16                             la Bordeta
# 8                          4  Sant Pere, Santa Caterina i la Ribera
# 9                          7                 la Dreta de l'Eixample
#
#    addresses_district_id addresses_district_name  addresses_zip_code  \
# 0                      8              Nou Barris                8016
# 1                      2                Eixample                8011
# 2                      2                Eixample                8011
# 3                      2                Eixample                8009
# 4                      2                Eixample                8013
# 5                      6                  Gràcia                8008
# 6                     10              Sant Martí                8018
# 7                      3          Sants-Montjuïc                8014
# 8                      1            Ciutat Vella                8003
# 9                      2                Eixample                8008
#
#   addresses_town  values_value                  secondary_filters_name  \
# 0      Barcelona     933540304                               Farmàcies
# 1      BARCELONA     933174684                               Farmàcies
# 2      BARCELONA     933174684  Farmàcies servei de 9 a 22 h tot l'any
# 3      Barcelona  93 232 81 65                               Farmàcies
# 4      BARCELONA     932454391                               Farmàcies
# 5      BARCELONA     932181993                               Farmàcies
# 6      BARCELONA     933007615                               Farmàcies
# 7      BARCELONA     933325745                               Farmàcies
# 8      BARCELONA     933199143                               Farmàcies
# 9      BARCELONA     932375556                               Farmàcies
#
#    geo_epgs_25831_x  geo_epgs_25831_y  geo_epgs_4326_lat  geo_epgs_4326_lon
# 0     431711.951527      4.587997e+06          41.440645           2.182564
# 1     429952.328850      4.581992e+06          41.386411           2.162198
# 2     429952.328850      4.581992e+06          41.386411           2.162198
# 3     431011.609336      4.583053e+06          41.396057           2.174745
# 4     431136.071095      4.583205e+06          41.397434           2.176216
# 5     429586.276147      4.583242e+06          41.397630           2.157675
# 6     432210.448565      4.583653e+06          41.401557           2.189017
# 7     427532.206744      4.580282e+06          41.370794           2.133459
# 8     431857.013416      4.581596e+06          41.383003           2.185021
# 9     429653.058572      4.582887e+06          41.394445           2.158515

# %%
# Observe New Info
#display(pharmacies_bcn_df.info())

# Check if duplicates
has_duplicates(pharmacies_bcn_df, 'register_id')
# Out:
# There's duplicate values in column register_id

# %%
# Print unique values for characteristics column before merging stuff
print("Unique Characteristics:\n")
print(pharmacies_bcn_df['secondary_filters_name'].unique(), "\n")

# Remove weird characteristic (None)

# Aggregate secondary_filters_name (caract.) by register_id and replace column
aggregated_sec_filters = pharmacies_bcn_df.groupby('register_id')['secondary_filters_name'].transform(lambda x: ', '.join(x))
pharmacies_bcn_df['secondary_filters_name'] = aggregated_sec_filters
#display(schools_no_reglat_df.head(10))

# Drop duplicated register_id
pharmacies_bcn_df.drop_duplicates(subset='register_id', inplace=True)
display(pharmacies_bcn_df.head(10))
# Out:
# Unique Characteristics:
#
# ['Farmàcies' "Farmàcies servei de 9 a 22 h tot l'any"
#  'Farmàcies permanents']
#      register_id                         name  addresses_road_id  \
# 0   ﻿75990017391      Farmàcia Hereus Lavilla              23200
# 1   ﻿75990017537    Farmàcia  Franquesa Massó              23403
# 3   ﻿75990048243    Farmàcia Bañeres Merinero             100800
# 4   ﻿75990048357        Farmàcia Sales Llavià             100800
# 5   ﻿75990064521       Farmàcia Pujol Pereita             148307
# 6   ﻿75990027321    Farmàcia Marta Homs Balló              44403
# 7   ﻿75990032969     Farmàcia Forcada Llamusí             700032
# 8   ﻿75990052487  Farmàcia Rodriguez Martinez             200000
# 9   ﻿75990038139       Farmàcia Sanchís Foret              74506
# 10  ﻿75990095731        Farmàcia Rubio Moreno             238400
#
#        addresses_road_name  addresses_start_street_number  \
# 0        Carrer d'Argullós                             49
# 1                   Aribau                             18
# 3   Carrer de la Diputació                            336
# 4                Diputació                            391
# 5                Pg Gràcia                            129
# 6                C Bolívia                             19
# 7           Ptge Andalusia                             14
# 8               C Marquesa                              3
# 9           Rbla Catalunya                            117
# 10               C Padilla                            378
#
#     addresses_neighborhood_id            addresses_neighborhood_name  \
# 0                          52                         la Prosperitat
# 1                           8        l'Antiga Esquerra de l'Eixample
# 3                           7                 la Dreta de l'Eixample
# 4                           7                 la Dreta de l'Eixample
# 5                          31                      la Vila de Gràcia
# 6                          66      el Parc i la Llacuna del Poblenou
# 7                          16                             la Bordeta
# 8                           4  Sant Pere, Santa Caterina i la Ribera
# 9                           7                 la Dreta de l'Eixample
# 10                         33                       el Baix Guinardó
#
#     addresses_district_id addresses_district_name  addresses_zip_code  \
# 0                       8              Nou Barris                8016
# 1                       2                Eixample                8011
# 3                       2                Eixample                8009
# 4                       2                Eixample                8013
# 5                       6                  Gràcia                8008
# 6                      10              Sant Martí                8018
# 7                       3          Sants-Montjuïc                8014
# 8                       1            Ciutat Vella                8003
# 9                       2                Eixample                8008
# 10                      7          Horta-Guinardó                8025
#
#    addresses_town  values_value  \
# 0       Barcelona     933540304
# 1       BARCELONA     933174684
# 3       Barcelona  93 232 81 65
# 4       BARCELONA     932454391
# 5       BARCELONA     932181993
# 6       BARCELONA     933007615
# 7       BARCELONA     933325745
# 8       BARCELONA     933199143
# 9       BARCELONA     932375556
# 10      BARCELONA     934558245
#
#                                secondary_filters_name  geo_epgs_25831_x  \
# 0                                           Farmàcies     431711.951527
# 1   Farmàcies, Farmàcies servei de 9 a 22 h tot l'any     429952.328850
# 3                                           Farmàcies     431011.609336
# 4                                           Farmàcies     431136.071095
# 5                                           Farmàcies     429586.276147
# 6                                           Farmàcies     432210.448565
# 7                                           Farmàcies     427532.206744
# 8                                           Farmàcies     431857.013416
# 9                                           Farmàcies     429653.058572
# 10                                          Farmàcies     430573.810227
#
#     geo_epgs_25831_y  geo_epgs_4326_lat  geo_epgs_4326_lon
# 0       4.587997e+06          41.440645           2.182564
# 1       4.581992e+06          41.386411           2.162198
# 3       4.583053e+06          41.396057           2.174745
# 4       4.583205e+06          41.397434           2.176216
# 5       4.583242e+06          41.397630           2.157675
# 6       4.583653e+06          41.401557           2.189017
# 7       4.580282e+06          41.370794           2.133459
# 8       4.581596e+06          41.383003           2.185021
# 9       4.582887e+06          41.394445           2.158515
# 10      4.584815e+06          41.411885           2.169306

# %%
# Rename Columns
pharmacies_bcn_df = pharmacies_bcn_df.rename(columns={"addresses_road_id": "Street ID", "name": "Name", "addresses_road_name": "Road Name", "addresses_start_street_number": "Street Number",
                                                      "addresses_neighborhood_id": "Neighborhood ID", "addresses_neighborhood_name": "Neighborhood Name",
                                                      "addresses_district_id": "District ID", "addresses_district_name": "District Name",
                                                      "addresses_zip_code": "ZipCode","addresses_town": "Town",
                                                      "values_value": "Phone Number", "secondary_filters_name": "Service Type",
                                                      "geo_epgs_4326_lat": "Latitude", "geo_epgs_4326_lon": "Longitude"})
display(pharmacies_bcn_df.head(10))
# Out:
#      register_id                         Name  Street ID  \
# 0   ﻿75990017391      Farmàcia Hereus Lavilla      23200
# 1   ﻿75990017537    Farmàcia  Franquesa Massó      23403
# 3   ﻿75990048243    Farmàcia Bañeres Merinero     100800
# 4   ﻿75990048357        Farmàcia Sales Llavià     100800
# 5   ﻿75990064521       Farmàcia Pujol Pereita     148307
# 6   ﻿75990027321    Farmàcia Marta Homs Balló      44403
# 7   ﻿75990032969     Farmàcia Forcada Llamusí     700032
# 8   ﻿75990052487  Farmàcia Rodriguez Martinez     200000
# 9   ﻿75990038139       Farmàcia Sanchís Foret      74506
# 10  ﻿75990095731        Farmàcia Rubio Moreno     238400
#
#                  Road Name  Street Number  Neighborhood ID  \
# 0        Carrer d'Argullós             49               52
# 1                   Aribau             18                8
# 3   Carrer de la Diputació            336                7
# 4                Diputació            391                7
# 5                Pg Gràcia            129               31
# 6                C Bolívia             19               66
# 7           Ptge Andalusia             14               16
# 8               C Marquesa              3                4
# 9           Rbla Catalunya            117                7
# 10               C Padilla            378               33
#
#                         Neighborhood Name  District ID   District Name  \
# 0                          la Prosperitat            8      Nou Barris
# 1         l'Antiga Esquerra de l'Eixample            2        Eixample
# 3                  la Dreta de l'Eixample            2        Eixample
# 4                  la Dreta de l'Eixample            2        Eixample
# 5                       la Vila de Gràcia            6          Gràcia
# 6       el Parc i la Llacuna del Poblenou           10      Sant Martí
# 7                              la Bordeta            3  Sants-Montjuïc
# 8   Sant Pere, Santa Caterina i la Ribera            1    Ciutat Vella
# 9                  la Dreta de l'Eixample            2        Eixample
# 10                       el Baix Guinardó            7  Horta-Guinardó
#
#     ZipCode       Town  Phone Number  \
# 0      8016  Barcelona     933540304
# 1      8011  BARCELONA     933174684
# 3      8009  Barcelona  93 232 81 65
# 4      8013  BARCELONA     932454391
# 5      8008  BARCELONA     932181993
# 6      8018  BARCELONA     933007615
# 7      8014  BARCELONA     933325745
# 8      8003  BARCELONA     933199143
# 9      8008  BARCELONA     932375556
# 10     8025  BARCELONA     934558245
#
#                                          Service Type  geo_epgs_25831_x  \
# 0                                           Farmàcies     431711.951527
# 1   Farmàcies, Farmàcies servei de 9 a 22 h tot l'any     429952.328850
# 3                                           Farmàcies     431011.609336
# 4                                           Farmàcies     431136.071095
# 5                                           Farmàcies     429586.276147
# 6                                           Farmàcies     432210.448565
# 7                                           Farmàcies     427532.206744
# 8                                           Farmàcies     431857.013416
# 9                                           Farmàcies     429653.058572
# 10                                          Farmàcies     430573.810227
#
#     geo_epgs_25831_y   Latitude  Longitude
# 0       4.587997e+06  41.440645   2.182564
# 1       4.581992e+06  41.386411   2.162198
# 3       4.583053e+06  41.396057   2.174745
# 4       4.583205e+06  41.397434   2.176216
# 5       4.583242e+06  41.397630   2.157675
# 6       4.583653e+06  41.401557   2.189017
# 7       4.580282e+06  41.370794   2.133459
# 8       4.581596e+06  41.383003   2.185021
# 9       4.582887e+06  41.394445   2.158515
# 10      4.584815e+06  41.411885   2.169306

# %%
# PHARMACIES CATALUNYA - NOT EXECUTE
#display(pharmacies_cat_df.info())
#print("\nSTATISTICS:\n")
#display(pharmacies_bcn_df.describe())
#non_null_cols, info_df = null_function(pharmacies_cat_df)
#print("\nColumns with no null values:", non_null_cols)
#print("\nColumns with null values:")
#display(info_df)

# Observe New Info
#display(pharmacies_cat_df.info())

# Check if duplicates
#has_duplicates(pharmacies_cat_df, 'CODI FARMACIA')

#display(pharmacies_cat_df)

# Rename Columns
#pharmacies_cat_df = pharmacies_cat_df.rename(columns={"CODI FARMACIA": "Id", "NOM FARMACIA": "Name", "CODI ABS": "ABS ID",
#                                                      "NOM ABS": "ABS Name", "CODI MUNICIPI": "Town ID", "NOM MUNICIPI": "Town",
#                                                      "CODI POSTAL": "ZipCode", "TIPUS VIA": "Roadtype", "NOM VIA": "Road Name",
#                                                      "NUMERO VIA": "Street Number"})
#display(pharmacies_cat_df.head(10))

# Create new dataset just containing those pharmacies in Barcelona
#pharmacies_cat_bcn_df = pharmacies_cat_df[pharmacies_cat_df['Town'] == 'BARCELONA']
#display(pharmacies_cat_bcn_df)

# Add 'Service Type' column and specify it is a pharmacy
#pharmacies_cat_bcn_df['Service Type'] = 'Farmàcia'
#display(pharmacies_cat_bcn_df)

# Merge datasets & rename columns
#pharmacies_merged_df = pd.merge(pharmacies_bcn_df, pharmacies_cat_bcn_df, on='Name', how='outer')
#display(pharmacies_merged_df.head(10))

# %% [markdown]
# ### 3) Day Centers

# %%
display(day_centers_df.info())
print("\nSTATISTICS:\n")
#display(day_centers_df.describe())
non_null_cols, info_df = null_function(day_centers_df)
print("\nColumns with no null values:", non_null_cols)
print("\nColumns with null values:")
display(info_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   register_id                    153 non-null    object
#  1   name                           153 non-null    object
#  2   institution_id                 114 non-null    float64
#  3   institution_name               114 non-null    object
#  4   created                        153 non-null    object
#  5   modified                       153 non-null    object
#  6   addresses_roadtype_id          0 non-null      float64
#  7   addresses_roadtype_name        0 non-null      float64
#  8   addresses_road_id              153 non-null    int64
#  9   addresses_road_name            153 non-null    object
#  10  addresses_start_street_number  153 non-null    int64
#  11  addresses_end_street_number    11 non-null     float64
#  12  addresses_neighborhood_id      153 non-null    int64
#  13  addresses_neighborhood_name    153 non-null    object
#  14  addresses_district_id          153 non-null    int64
#  15  addresses_district_name        153 non-null    object
#  16  addresses_zip_code             153 non-null    int64
#  17  addresses_town                 153 non-null    object
#  18  addresses_main_address         153 non-null    bool
#  19  addresses_type                 0 non-null      float64
#  20  values_id                      153 non-null    int64
#  21  values_attribute_id            153 non-null    int64
#  22  values_category                153 non-null    object
#  23  values_attribute_name          153 non-null    object
#  24  values_value                   153 non-null    object
#  25  values_outstanding             153 non-null    bool
#  26  values_description             0 non-null      float64
#  27  secondary_filters_id           153 non-null    int64
#  28  secondary_filters_name         153 non-null    object
#  29  secondary_filters_fullpath     153 non-null    object
#  30  secondary_filters_tree         153 non-null    int64
#  31  secondary_filters_asia_id      153 non-null    int64
#  32  geo_epgs_25831_x               153 non-null    float64
#  33  geo_epgs_25831_y               153 non-null    float64
#  34  geo_epgs_4326_lat              153 non-null    float64
#  35  geo_epgs_4326_lon              153 non-null    float64
#  36  estimated_dates                0 non-null      float64
#  37  start_date                     0 non-null      float64
#  38  end_date                       0 non-null      float64
# dtypes: bool(2), float64(13), int64(10), object(14)
# memory usage: 44.7+ KB
# None
# STATISTICS:
#
#
# Columns with no null values: Index(['register_id', 'name', 'created', 'modified', 'addresses_road_id',
#        'addresses_road_name', 'addresses_start_street_number',
#        'addresses_neighborhood_id', 'addresses_neighborhood_name',
#        'addresses_district_id', 'addresses_district_name',
#        'addresses_zip_code', 'addresses_town', 'addresses_main_address',
#        'values_id', 'values_attribute_id', 'values_category',
#        'values_attribute_name', 'values_value', 'values_outstanding',
#        'secondary_filters_id', 'secondary_filters_name',
#        'secondary_filters_fullpath', 'secondary_filters_tree',
#        'secondary_filters_asia_id', 'geo_epgs_25831_x', 'geo_epgs_25831_y',
#        'geo_epgs_4326_lat', 'geo_epgs_4326_lon'],
#       dtype='object')
#
# Columns with null values:
#                         Column  Null Count  Null Percentage
# 0               institution_id          39        25.490196
# 1             institution_name          39        25.490196
# 2        addresses_roadtype_id         153       100.000000
# 3      addresses_roadtype_name         153       100.000000
# 4  addresses_end_street_number         142        92.810458
# 5               addresses_type         153       100.000000
# 6           values_description         153       100.000000
# 7              estimated_dates         153       100.000000
# 8                   start_date         153       100.000000
# 9                     end_date         153       100.000000

# %% [markdown]
# *Seeing the amount of NULL values for each column, we will drop: institution_id, institution_name, addresses_roadtype_id, addresses_roadtype_name, addresses_end_street_number, addresses_type, values_description, estimated_dates, start_date, end_date. Also, the columns created and modified won't be used for the moment.*

# %%
# Drop columns with almost all null values
columns_to_drop_day_centers = ['created', 'modified', 'institution_id', 'institution_name', 'addresses_roadtype_id', 'addresses_roadtype_name' ,
                                  'addresses_end_street_number', 'addresses_type', 'values_description', 'estimated_dates', 'start_date', 'end_date']

day_centers_df.drop(columns=columns_to_drop_day_centers, inplace=True)

# Useless: Identifiador Via, Indicador si l'adreça, Valor de l'atribut identificador, Valor de l'atribut, Valors d'atribut Destacat,
# Arbres d'equivalència Identificador, Arbres d'equivalència Ruta, Arbres d'equivalència, Arbres d'equivalència  Id Asia
#useless_cols = ['addresses_road_id', 'addresses_main_address', 'values_id', 'values_attribute_id', 'values_outstanding', 'secondary_filters_id',
#                'secondary_filters_fullpath', 'secondary_filters_tree', 'secondary_filters_asia_id', 'values_category', 'values_attribute_name']
useless_cols = ['addresses_main_address', 'values_id', 'values_attribute_id', 'values_outstanding', 'secondary_filters_id',
                'secondary_filters_fullpath', 'secondary_filters_tree', 'secondary_filters_asia_id', 'values_category', 'values_attribute_name']

day_centers_df.drop(columns=useless_cols, inplace=True)
day_centers_df.head(10)
# Out:
#     register_id                                  name  addresses_road_id  \
# 0  ﻿99400472632                         Centre de Dia             268003
# 1  ﻿99400472636                         Centre de Dia             335100
# 2  ﻿99400473710  Centre de Dia per a Gent Gran Verdum             361508
# 3  ﻿99400622969                         Centre de Dia             226604
# 4  ﻿99400620504                         Centre de Dia              89004
# 5  ﻿99400622743                         Centre de Dia             362205
# 6  ﻿99400622844                         Centre de Dia             325005
# 7  ﻿99400109729          Centre de Dia La Torre Setze             339305
# 8  ﻿99400622701                         Centre de Dia             248800
# 9  ﻿99400622702                         Centre de Dia             187207
#
#   addresses_road_name  addresses_start_street_number  \
# 0          C Provença                            514
# 1           Pl Tetuan                              2
# 2         C Viladrosa                             86
# 3          C Natzaret                             16
# 4   C Consell de Cent                            210
# 5            C Vilana                             10
# 6           C Sicília                            402
# 7             C Torre                             16
# 8           C Pedrell                            111
# 9           Av Madrid                            210
#
#    addresses_neighborhood_id         addresses_neighborhood_name  \
# 0                          6                  la Sagrada Família
# 1                          7              la Dreta de l'Eixample
# 2                         51                              Verdun
# 3                         39            Sant Genís dels Agudells
# 4                          8     l'Antiga Esquerra de l'Eixample
# 5                         25          Sant Gervasi - la Bonanova
# 6                         32  el Camp d'en Grassot i Gràcia Nova
# 7                         27                el Putxet i el Farró
# 8                         36                la Font d'en Fargues
# 9                         18                               Sants
#
#    addresses_district_id addresses_district_name  addresses_zip_code  \
# 0                      2                Eixample                8025
# 1                      2                Eixample                8010
# 2                      8              Nou Barris                8042
# 3                      7          Horta-Guinardó                8035
# 4                      2                Eixample                8011
# 5                      5     Sarrià-Sant Gervasi                8022
# 6                      6                  Gràcia                8025
# 7                      5     Sarrià-Sant Gervasi                8006
# 8                      7          Horta-Guinardó                8032
# 9                      3          Sants-Montjuïc                8014
#
#   addresses_town values_value    secondary_filters_name  geo_epgs_25831_x  \
# 0      BARCELONA    934334180  Centres de dia gent gran     431326.451023
# 1      BARCELONA    932323915  Centres de dia gent gran     431135.148181
# 2      BARCELONA    932765995  Centres de dia gent gran     431218.828248
# 3      BARCELONA    934343095  Centres de dia gent gran     428079.700192
# 4      BARCELONA    933239692  Centres de dia gent gran     429600.651297
# 5      BARCELONA    934171922  Centres de dia gent gran     427171.996418
# 6      BARCELONA    934570984  Centres de dia gent gran     430398.403054
# 7      BARCELONA    932372642  Centres de dia gent gran     428853.709103
# 8      BARCELONA    933570055  Centres de dia gent gran     430055.406981
# 9      BARCELONA    933301135  Centres de dia gent gran     427634.918496
#
#    geo_epgs_25831_y  geo_epgs_4326_lat  geo_epgs_4326_lon
# 0      4.584296e+06          41.407278           2.178370
# 1      4.582831e+06          41.394069           2.176248
# 2      4.588311e+06          41.443434           2.176626
# 3      4.586023e+06          41.422547           2.139324
# 4      4.581859e+06          41.385177           2.158007
# 5      4.584115e+06          41.405278           2.128692
# 6      4.584214e+06          41.406461           2.167277
# 7      4.584010e+06          41.404482           2.148822
# 8      4.586166e+06          41.424009           2.162948
# 9      4.581437e+06          41.381205           2.134550

# %%
# Observe New Info
#display(day_centers_df.info())

# Check if duplicates
has_duplicates(day_centers_df, 'register_id')
# Out:
# There's duplicate values in column register_id

# %%
# Print unique values for characteristics column before merging stuff
print("Unique Characteristics:\n")
print(day_centers_df['secondary_filters_name'].unique(), "\n")

# Remove weird characteristic (None: Centres de dia gent gran, Residències gent gran, Hospitals i clíniques)

# Aggregate secondary_filters_name (caract.) by register_id and replace column
aggregated_sec_filters = day_centers_df.groupby('register_id')['secondary_filters_name'].transform(lambda x: ', '.join(x))
day_centers_df['secondary_filters_name'] = aggregated_sec_filters
#display(education_equip_df.head(10))

# Drop duplicated register_id
day_centers_df.drop_duplicates(subset='register_id', inplace=True)
display(day_centers_df.head(10))
# Out:
# Unique Characteristics:
#
# ['Centres de dia gent gran' 'Residències gent gran'
#  'Hospitals i clíniques']
#     register_id                                  name  addresses_road_id  \
# 0  ﻿99400472632                         Centre de Dia             268003
# 1  ﻿99400472636                         Centre de Dia             335100
# 2  ﻿99400473710  Centre de Dia per a Gent Gran Verdum             361508
# 3  ﻿99400622969                         Centre de Dia             226604
# 4  ﻿99400620504                         Centre de Dia              89004
# 5  ﻿99400622743                         Centre de Dia             362205
# 6  ﻿99400622844                         Centre de Dia             325005
# 7  ﻿99400109729          Centre de Dia La Torre Setze             339305
# 8  ﻿99400622701                         Centre de Dia             248800
# 9  ﻿99400622702                         Centre de Dia             187207
#
#   addresses_road_name  addresses_start_street_number  \
# 0          C Provença                            514
# 1           Pl Tetuan                              2
# 2         C Viladrosa                             86
# 3          C Natzaret                             16
# 4   C Consell de Cent                            210
# 5            C Vilana                             10
# 6           C Sicília                            402
# 7             C Torre                             16
# 8           C Pedrell                            111
# 9           Av Madrid                            210
#
#    addresses_neighborhood_id         addresses_neighborhood_name  \
# 0                          6                  la Sagrada Família
# 1                          7              la Dreta de l'Eixample
# 2                         51                              Verdun
# 3                         39            Sant Genís dels Agudells
# 4                          8     l'Antiga Esquerra de l'Eixample
# 5                         25          Sant Gervasi - la Bonanova
# 6                         32  el Camp d'en Grassot i Gràcia Nova
# 7                         27                el Putxet i el Farró
# 8                         36                la Font d'en Fargues
# 9                         18                               Sants
#
#    addresses_district_id addresses_district_name  addresses_zip_code  \
# 0                      2                Eixample                8025
# 1                      2                Eixample                8010
# 2                      8              Nou Barris                8042
# 3                      7          Horta-Guinardó                8035
# 4                      2                Eixample                8011
# 5                      5     Sarrià-Sant Gervasi                8022
# 6                      6                  Gràcia                8025
# 7                      5     Sarrià-Sant Gervasi                8006
# 8                      7          Horta-Guinardó                8032
# 9                      3          Sants-Montjuïc                8014
#
#   addresses_town values_value    secondary_filters_name  geo_epgs_25831_x  \
# 0      BARCELONA    934334180  Centres de dia gent gran     431326.451023
# 1      BARCELONA    932323915  Centres de dia gent gran     431135.148181
# 2      BARCELONA    932765995  Centres de dia gent gran     431218.828248
# 3      BARCELONA    934343095  Centres de dia gent gran     428079.700192
# 4      BARCELONA    933239692  Centres de dia gent gran     429600.651297
# 5      BARCELONA    934171922  Centres de dia gent gran     427171.996418
# 6      BARCELONA    934570984  Centres de dia gent gran     430398.403054
# 7      BARCELONA    932372642  Centres de dia gent gran     428853.709103
# 8      BARCELONA    933570055  Centres de dia gent gran     430055.406981
# 9      BARCELONA    933301135  Centres de dia gent gran     427634.918496
#
#    geo_epgs_25831_y  geo_epgs_4326_lat  geo_epgs_4326_lon
# 0      4.584296e+06          41.407278           2.178370
# 1      4.582831e+06          41.394069           2.176248
# 2      4.588311e+06          41.443434           2.176626
# 3      4.586023e+06          41.422547           2.139324
# 4      4.581859e+06          41.385177           2.158007
# 5      4.584115e+06          41.405278           2.128692
# 6      4.584214e+06          41.406461           2.167277
# 7      4.584010e+06          41.404482           2.148822
# 8      4.586166e+06          41.424009           2.162948
# 9      4.581437e+06          41.381205           2.134550

# %%
# Rename Columns
day_centers_df = day_centers_df.rename(columns={"addresses_road_id": "Street ID", "name": "Name", "addresses_road_name": "Road Name", "addresses_start_street_number": "Street Number",
                                                      "addresses_neighborhood_id": "Neighborhood ID", "addresses_neighborhood_name": "Neighborhood Name",
                                                      "addresses_district_id": "District ID", "addresses_district_name": "District Name",
                                                      "addresses_zip_code": "ZipCode","addresses_town": "Town",
                                                      "values_value": "Phone Number", "secondary_filters_name": "Service Type",
                                                      "geo_epgs_4326_lat": "Latitude", "geo_epgs_4326_lon": "Longitude"})
display(day_centers_df.head(10))
# Out:
#     register_id                                  Name  Street ID  \
# 0  ﻿99400472632                         Centre de Dia     268003
# 1  ﻿99400472636                         Centre de Dia     335100
# 2  ﻿99400473710  Centre de Dia per a Gent Gran Verdum     361508
# 3  ﻿99400622969                         Centre de Dia     226604
# 4  ﻿99400620504                         Centre de Dia      89004
# 5  ﻿99400622743                         Centre de Dia     362205
# 6  ﻿99400622844                         Centre de Dia     325005
# 7  ﻿99400109729          Centre de Dia La Torre Setze     339305
# 8  ﻿99400622701                         Centre de Dia     248800
# 9  ﻿99400622702                         Centre de Dia     187207
#
#            Road Name  Street Number  Neighborhood ID  \
# 0         C Provença            514                6
# 1          Pl Tetuan              2                7
# 2        C Viladrosa             86               51
# 3         C Natzaret             16               39
# 4  C Consell de Cent            210                8
# 5           C Vilana             10               25
# 6          C Sicília            402               32
# 7            C Torre             16               27
# 8          C Pedrell            111               36
# 9          Av Madrid            210               18
#
#                     Neighborhood Name  District ID        District Name  \
# 0                  la Sagrada Família            2             Eixample
# 1              la Dreta de l'Eixample            2             Eixample
# 2                              Verdun            8           Nou Barris
# 3            Sant Genís dels Agudells            7       Horta-Guinardó
# 4     l'Antiga Esquerra de l'Eixample            2             Eixample
# 5          Sant Gervasi - la Bonanova            5  Sarrià-Sant Gervasi
# 6  el Camp d'en Grassot i Gràcia Nova            6               Gràcia
# 7                el Putxet i el Farró            5  Sarrià-Sant Gervasi
# 8                la Font d'en Fargues            7       Horta-Guinardó
# 9                               Sants            3       Sants-Montjuïc
#
#    ZipCode       Town Phone Number              Service Type  \
# 0     8025  BARCELONA    934334180  Centres de dia gent gran
# 1     8010  BARCELONA    932323915  Centres de dia gent gran
# 2     8042  BARCELONA    932765995  Centres de dia gent gran
# 3     8035  BARCELONA    934343095  Centres de dia gent gran
# 4     8011  BARCELONA    933239692  Centres de dia gent gran
# 5     8022  BARCELONA    934171922  Centres de dia gent gran
# 6     8025  BARCELONA    934570984  Centres de dia gent gran
# 7     8006  BARCELONA    932372642  Centres de dia gent gran
# 8     8032  BARCELONA    933570055  Centres de dia gent gran
# 9     8014  BARCELONA    933301135  Centres de dia gent gran
#
#    geo_epgs_25831_x  geo_epgs_25831_y   Latitude  Longitude
# 0     431326.451023      4.584296e+06  41.407278   2.178370
# 1     431135.148181      4.582831e+06  41.394069   2.176248
# 2     431218.828248      4.588311e+06  41.443434   2.176626
# 3     428079.700192      4.586023e+06  41.422547   2.139324
# 4     429600.651297      4.581859e+06  41.385177   2.158007
# 5     427171.996418      4.584115e+06  41.405278   2.128692
# 6     430398.403054      4.584214e+06  41.406461   2.167277
# 7     428853.709103      4.584010e+06  41.404482   2.148822
# 8     430055.406981      4.586166e+06  41.424009   2.162948
# 9     427634.918496      4.581437e+06  41.381205   2.134550

# %% [markdown]
# ### 4) Elderly People Residences

# %%
display(residences_df.info())
print("\nSTATISTICS:\n")
#display(residences_df.describe())
non_null_cols, info_df = null_function(residences_df)
print("\nColumns with no null values:", non_null_cols)
print("\nColumns with null values:")
display(info_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   register_id                    267 non-null    object
#  1   name                           267 non-null    object
#  2   institution_id                 9 non-null      float64
#  3   institution_name               9 non-null      object
#  4   created                        267 non-null    object
#  5   modified                       267 non-null    object
#  6   addresses_roadtype_id          0 non-null      float64
#  7   addresses_roadtype_name        0 non-null      float64
#  8   addresses_road_id              267 non-null    int64
#  9   addresses_road_name            267 non-null    object
#  10  addresses_start_street_number  267 non-null    int64
#  11  addresses_end_street_number    5 non-null      float64
#  12  addresses_neighborhood_id      267 non-null    int64
#  13  addresses_neighborhood_name    267 non-null    object
#  14  addresses_district_id          267 non-null    int64
#  15  addresses_district_name        267 non-null    object
#  16  addresses_zip_code             267 non-null    int64
#  17  addresses_town                 267 non-null    object
#  18  addresses_main_address         267 non-null    bool
#  19  addresses_type                 0 non-null      float64
#  20  values_id                      265 non-null    float64
#  21  values_attribute_id            265 non-null    float64
#  22  values_category                265 non-null    object
#  23  values_attribute_name          265 non-null    object
#  24  values_value                   265 non-null    object
#  25  values_outstanding             265 non-null    object
#  26  values_description             1 non-null      object
#  27  secondary_filters_id           267 non-null    int64
#  28  secondary_filters_name         267 non-null    object
#  29  secondary_filters_fullpath     267 non-null    object
#  30  secondary_filters_tree         267 non-null    int64
#  31  secondary_filters_asia_id      267 non-null    int64
#  32  geo_epgs_25831_x               267 non-null    float64
#  33  geo_epgs_25831_y               267 non-null    float64
#  34  geo_epgs_4326_lat              267 non-null    float64
#  35  geo_epgs_4326_lon              267 non-null    float64
#  36  estimated_dates                0 non-null      float64
#  37  start_date                     0 non-null      float64
#  38  end_date                       0 non-null      float64
# dtypes: bool(1), float64(14), int64(8), object(16)
# memory usage: 79.7+ KB
# None
# STATISTICS:
#
#
# Columns with no null values: Index(['register_id', 'name', 'created', 'modified', 'addresses_road_id',
#        'addresses_road_name', 'addresses_start_street_number',
#        'addresses_neighborhood_id', 'addresses_neighborhood_name',
#        'addresses_district_id', 'addresses_district_name',
#        'addresses_zip_code', 'addresses_town', 'addresses_main_address',
#        'secondary_filters_id', 'secondary_filters_name',
#        'secondary_filters_fullpath', 'secondary_filters_tree',
#        'secondary_filters_asia_id', 'geo_epgs_25831_x', 'geo_epgs_25831_y',
#        'geo_epgs_4326_lat', 'geo_epgs_4326_lon'],
#       dtype='object')
#
# Columns with null values:
#                          Column  Null Count  Null Percentage
# 0                institution_id         258        96.629213
# 1              institution_name         258        96.629213
# 2         addresses_roadtype_id         267       100.000000
# 3       addresses_roadtype_name         267       100.000000
# 4   addresses_end_street_number         262        98.127341
# 5                addresses_type         267       100.000000
# 6                     values_id           2         0.749064
# 7           values_attribute_id           2         0.749064
# 8               values_category           2         0.749064
# 9         values_attribute_name           2         0.749064
# 10                 values_value           2         0.749064
# 11           values_outstanding           2         0.749064
# 12           values_description         266        99.625468
# 13              estimated_dates         267       100.000000
# 14                   start_date         267       100.000000
# 15                     end_date         267       100.000000

# %% [markdown]
# *Seeing the amount of NULL values for each column, we will drop: institution_id, institution_name, addresses_roadtype_id, addresses_roadtype_name, addresses_end_street_number, addresses_type, values_description, estimated_dates, start_date, end_date. Also, the columns created and modified won't be used for the moment.*

# %%
# Drop columns with almost all null values
columns_to_drop_residences = ['created', 'modified', 'institution_id', 'institution_name', 'addresses_roadtype_id', 'addresses_roadtype_name' ,
                                  'addresses_end_street_number', 'addresses_type', 'values_description', 'estimated_dates', 'start_date', 'end_date']

residences_df.drop(columns=columns_to_drop_residences, inplace=True)

# Useless: Identifiador Via, Indicador si l'adreça, Valor de l'atribut identificador, Valor de l'atribut, Valors d'atribut Destacat,
# Arbres d'equivalència Identificador, Arbres d'equivalència Ruta, Arbres d'equivalència, Arbres d'equivalència  Id Asia
#useless_cols = ['addresses_road_id', 'addresses_main_address', 'values_id', 'values_attribute_id', 'values_outstanding', 'secondary_filters_id',
#                'secondary_filters_fullpath', 'secondary_filters_tree', 'secondary_filters_asia_id', 'values_category', 'values_attribute_name']
useless_cols = ['addresses_main_address', 'values_id', 'values_attribute_id', 'values_outstanding', 'secondary_filters_id',
                'secondary_filters_fullpath', 'secondary_filters_tree', 'secondary_filters_asia_id', 'values_category', 'values_attribute_name']

residences_df.drop(columns=useless_cols, inplace=True)
residences_df.head(10)
# Out:
#     register_id                                               name  \
# 0  ﻿75990033549              Residència Assistida Francisco Darder
# 1  ﻿98334111453        Residència Assistida per a Gent Gran Venero
# 2  ﻿75990056448                  Residència Assistida Vil·la Salut
# 3  ﻿75990706118  Residència Assistida per a Gent Gran Las Violetas
# 4  ﻿98334113506                       Residència Assistida Ama-Lur
# 5  ﻿98334114740  Residència Assistida per a Gent Gran Urquinaon...
# 6  ﻿98336085708    Residència Assistida per a Gent Gran Royal Llar
# 7  ﻿98336090941      Residència Assistida per a Gent Gran Virreina
# 8  ﻿99400001162  Residència Assistida per a Gent Gran La Vostra...
# 9  ﻿99400468618  Residència Assistida per a Gent Gran Ballesol ...
#
#    addresses_road_id   addresses_road_name  addresses_start_street_number  \
# 0              66100            C Cardener                             49
# 1             356100              C Venero                              4
# 2             132806       Francesc Alegre                             26
# 3             169409  G.V. Corts Catalanes                            573
# 4             350308            C València                            281
# 5             232902         Pl Urquinaona                              1
# 6             169409  G.V. Corts Catalanes                            695
# 7             109203          C Encarnació                             31
# 8             169409  G.V. Corts Catalanes                            871
# 9              11200          C Almogàvers                             32
#
#    addresses_neighborhood_id        addresses_neighborhood_name  \
# 0                         30                           la Salut
# 1                         68                        el Poblenou
# 2                         34                           Can Baró
# 3                          8    l'Antiga Esquerra de l'Eixample
# 4                          7             la Dreta de l'Eixample
# 5                          7             la Dreta de l'Eixample
# 6                          5                      el Fort Pienc
# 7                         31                  la Vila de Gràcia
# 8                         65                            el Clot
# 9                         66  el Parc i la Llacuna del Poblenou
#
#    addresses_district_id addresses_district_name  addresses_zip_code  \
# 0                      6                  Gràcia                8024
# 1                     10              Sant Martí                8005
# 2                      7          Horta-Guinardó                8024
# 3                      2                Eixample                8011
# 4                      2                Eixample                8009
# 5                      2                Eixample                8010
# 6                      2                Eixample                8013
# 7                      6                  Gràcia                8012
# 8                     10              Sant Martí                8018
# 9                     10              Sant Martí                8018
#
#   addresses_town values_value secondary_filters_name  geo_epgs_25831_x  \
# 0      BARCELONA    932853558  Residències gent gran     429558.993120
# 1      BARCELONA    933002976  Residències gent gran     433292.910052
# 2      BARCELONA    932108787  Residències gent gran     430290.528859
# 3      BARCELONA    933238180  Residències gent gran     429941.005990
# 4      BARCELONA    934872875  Residències gent gran     430275.326517
# 5      BARCELONA    933014499  Residències gent gran     430814.061413
# 6      BARCELONA    932311118  Residències gent gran     431290.256604
# 7      BARCELONA    932198161  Residències gent gran     429725.930597
# 8      BARCELONA    933208455  Residències gent gran     432469.816911
# 9      BARCELONA    933569383  Residències gent gran     431809.992654
#
#    geo_epgs_25831_y  geo_epgs_4326_lat  geo_epgs_4326_lon
# 0      4.584637e+06          41.410198           2.157186
# 1      4.583631e+06          41.401453           2.201968
# 2      4.585389e+06          41.417036           2.165851
# 3      4.581848e+06          41.385113           2.162079
# 4      4.582925e+06          41.394839           2.165953
# 5      4.582287e+06          41.389138           2.172470
# 6      4.583169e+06          41.397125           2.178065
# 7      4.584166e+06          41.405968           2.159238
# 8      4.584322e+06          41.407612           2.192045
# 9      4.582677e+06          41.392737           2.184337

# %%
# Observe New Info
#display(residences_df.info())

# Check if duplicates
has_duplicates(residences_df, 'register_id')
# Out:
# There's duplicate values in column register_id

# %%
# Print unique values for characteristics column before merging stuff
print("Unique Characteristics:\n")
print(residences_df['secondary_filters_name'].unique(), "\n")

# Remove weird characteristic (TNone: Residències gent gran, Centres de dia gent gran, Hospitals i clíniques)

# Aggregate secondary_filters_name (caract.) by register_id and replace column
aggregated_sec_filters = residences_df.groupby('register_id')['secondary_filters_name'].transform(lambda x: ', '.join(x))
residences_df['secondary_filters_name'] = aggregated_sec_filters
#display(education_equip_df.head(10))

# Drop duplicated register_id
residences_df.drop_duplicates(subset='register_id', inplace=True)
display(residences_df.head(10))
# Out:
# Unique Characteristics:
#
# ['Residències gent gran' 'Centres de dia gent gran'
#  'Hospitals i clíniques']
#     register_id                                               name  \
# 0  ﻿75990033549              Residència Assistida Francisco Darder
# 1  ﻿98334111453        Residència Assistida per a Gent Gran Venero
# 2  ﻿75990056448                  Residència Assistida Vil·la Salut
# 3  ﻿75990706118  Residència Assistida per a Gent Gran Las Violetas
# 4  ﻿98334113506                       Residència Assistida Ama-Lur
# 5  ﻿98334114740  Residència Assistida per a Gent Gran Urquinaon...
# 6  ﻿98336085708    Residència Assistida per a Gent Gran Royal Llar
# 7  ﻿98336090941      Residència Assistida per a Gent Gran Virreina
# 8  ﻿99400001162  Residència Assistida per a Gent Gran La Vostra...
# 9  ﻿99400468618  Residència Assistida per a Gent Gran Ballesol ...
#
#    addresses_road_id   addresses_road_name  addresses_start_street_number  \
# 0              66100            C Cardener                             49
# 1             356100              C Venero                              4
# 2             132806       Francesc Alegre                             26
# 3             169409  G.V. Corts Catalanes                            573
# 4             350308            C València                            281
# 5             232902         Pl Urquinaona                              1
# 6             169409  G.V. Corts Catalanes                            695
# 7             109203          C Encarnació                             31
# 8             169409  G.V. Corts Catalanes                            871
# 9              11200          C Almogàvers                             32
#
#    addresses_neighborhood_id        addresses_neighborhood_name  \
# 0                         30                           la Salut
# 1                         68                        el Poblenou
# 2                         34                           Can Baró
# 3                          8    l'Antiga Esquerra de l'Eixample
# 4                          7             la Dreta de l'Eixample
# 5                          7             la Dreta de l'Eixample
# 6                          5                      el Fort Pienc
# 7                         31                  la Vila de Gràcia
# 8                         65                            el Clot
# 9                         66  el Parc i la Llacuna del Poblenou
#
#    addresses_district_id addresses_district_name  addresses_zip_code  \
# 0                      6                  Gràcia                8024
# 1                     10              Sant Martí                8005
# 2                      7          Horta-Guinardó                8024
# 3                      2                Eixample                8011
# 4                      2                Eixample                8009
# 5                      2                Eixample                8010
# 6                      2                Eixample                8013
# 7                      6                  Gràcia                8012
# 8                     10              Sant Martí                8018
# 9                     10              Sant Martí                8018
#
#   addresses_town values_value secondary_filters_name  geo_epgs_25831_x  \
# 0      BARCELONA    932853558  Residències gent gran     429558.993120
# 1      BARCELONA    933002976  Residències gent gran     433292.910052
# 2      BARCELONA    932108787  Residències gent gran     430290.528859
# 3      BARCELONA    933238180  Residències gent gran     429941.005990
# 4      BARCELONA    934872875  Residències gent gran     430275.326517
# 5      BARCELONA    933014499  Residències gent gran     430814.061413
# 6      BARCELONA    932311118  Residències gent gran     431290.256604
# 7      BARCELONA    932198161  Residències gent gran     429725.930597
# 8      BARCELONA    933208455  Residències gent gran     432469.816911
# 9      BARCELONA    933569383  Residències gent gran     431809.992654
#
#    geo_epgs_25831_y  geo_epgs_4326_lat  geo_epgs_4326_lon
# 0      4.584637e+06          41.410198           2.157186
# 1      4.583631e+06          41.401453           2.201968
# 2      4.585389e+06          41.417036           2.165851
# 3      4.581848e+06          41.385113           2.162079
# 4      4.582925e+06          41.394839           2.165953
# 5      4.582287e+06          41.389138           2.172470
# 6      4.583169e+06          41.397125           2.178065
# 7      4.584166e+06          41.405968           2.159238
# 8      4.584322e+06          41.407612           2.192045
# 9      4.582677e+06          41.392737           2.184337

# %%
# Rename Columns
residences_df = residences_df.rename(columns={"addresses_road_id": "Street ID", "name": "Name", "addresses_road_name": "Road Name", "addresses_start_street_number": "Street Number",
                                                      "addresses_neighborhood_id": "Neighborhood ID", "addresses_neighborhood_name": "Neighborhood Name",
                                                      "addresses_district_id": "District ID", "addresses_district_name": "District Name",
                                                      "addresses_zip_code": "ZipCode","addresses_town": "Town",
                                                      "values_value": "Phone Number", "secondary_filters_name": "Service Type",
                                                      "geo_epgs_4326_lat": "Latitude", "geo_epgs_4326_lon": "Longitude"})
display(residences_df.head(10))
# Out:
#     register_id                                               Name  Street ID  \
# 0  ﻿75990033549              Residència Assistida Francisco Darder      66100
# 1  ﻿98334111453        Residència Assistida per a Gent Gran Venero     356100
# 2  ﻿75990056448                  Residència Assistida Vil·la Salut     132806
# 3  ﻿75990706118  Residència Assistida per a Gent Gran Las Violetas     169409
# 4  ﻿98334113506                       Residència Assistida Ama-Lur     350308
# 5  ﻿98334114740  Residència Assistida per a Gent Gran Urquinaon...     232902
# 6  ﻿98336085708    Residència Assistida per a Gent Gran Royal Llar     169409
# 7  ﻿98336090941      Residència Assistida per a Gent Gran Virreina     109203
# 8  ﻿99400001162  Residència Assistida per a Gent Gran La Vostra...     169409
# 9  ﻿99400468618  Residència Assistida per a Gent Gran Ballesol ...      11200
#
#               Road Name  Street Number  Neighborhood ID  \
# 0            C Cardener             49               30
# 1              C Venero              4               68
# 2       Francesc Alegre             26               34
# 3  G.V. Corts Catalanes            573                8
# 4            C València            281                7
# 5         Pl Urquinaona              1                7
# 6  G.V. Corts Catalanes            695                5
# 7          C Encarnació             31               31
# 8  G.V. Corts Catalanes            871               65
# 9          C Almogàvers             32               66
#
#                    Neighborhood Name  District ID   District Name  ZipCode  \
# 0                           la Salut            6          Gràcia     8024
# 1                        el Poblenou           10      Sant Martí     8005
# 2                           Can Baró            7  Horta-Guinardó     8024
# 3    l'Antiga Esquerra de l'Eixample            2        Eixample     8011
# 4             la Dreta de l'Eixample            2        Eixample     8009
# 5             la Dreta de l'Eixample            2        Eixample     8010
# 6                      el Fort Pienc            2        Eixample     8013
# 7                  la Vila de Gràcia            6          Gràcia     8012
# 8                            el Clot           10      Sant Martí     8018
# 9  el Parc i la Llacuna del Poblenou           10      Sant Martí     8018
#
#         Town Phone Number           Service Type  geo_epgs_25831_x  \
# 0  BARCELONA    932853558  Residències gent gran     429558.993120
# 1  BARCELONA    933002976  Residències gent gran     433292.910052
# 2  BARCELONA    932108787  Residències gent gran     430290.528859
# 3  BARCELONA    933238180  Residències gent gran     429941.005990
# 4  BARCELONA    934872875  Residències gent gran     430275.326517
# 5  BARCELONA    933014499  Residències gent gran     430814.061413
# 6  BARCELONA    932311118  Residències gent gran     431290.256604
# 7  BARCELONA    932198161  Residències gent gran     429725.930597
# 8  BARCELONA    933208455  Residències gent gran     432469.816911
# 9  BARCELONA    933569383  Residències gent gran     431809.992654
#
#    geo_epgs_25831_y   Latitude  Longitude
# 0      4.584637e+06  41.410198   2.157186
# 1      4.583631e+06  41.401453   2.201968
# 2      4.585389e+06  41.417036   2.165851
# 3      4.581848e+06  41.385113   2.162079
# 4      4.582925e+06  41.394839   2.165953
# 5      4.582287e+06  41.389138   2.172470
# 6      4.583169e+06  41.397125   2.178065
# 7      4.584166e+06  41.405968   2.159238
# 8      4.584322e+06  41.407612   2.192045
# 9      4.582677e+06  41.392737   2.184337

# %% [markdown]
# ### 5) Other Health Equipments (only in Barcelona)

# %%
display(health_equip_bcn_df.info())
print("\nSTATISTICS:\n")
#display(health_equip_bcn_df.describe())
non_null_cols, info_df = null_function(health_equip_bcn_df)
print("\nColumns with no null values:", non_null_cols)
print("\nColumns with null values:")
display(info_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2312 entries, 0 to 2311
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   register_id                    2312 non-null   object
#  1   name                           2312 non-null   object
#  2   institution_id                 138 non-null    float64
#  3   institution_name               138 non-null    object
#  4   created                        2312 non-null   object
#  5   modified                       2312 non-null   object
#  6   addresses_roadtype_id          0 non-null      float64
#  7   addresses_roadtype_name        0 non-null      float64
#  8   addresses_road_id              2311 non-null   float64
#  9   addresses_road_name            2310 non-null   object
#  10  addresses_start_street_number  2310 non-null   float64
#  11  addresses_end_street_number    182 non-null    float64
#  12  addresses_neighborhood_id      2312 non-null   int64
#  13  addresses_neighborhood_name    2311 non-null   object
#  14  addresses_district_id          2312 non-null   int64
#  15  addresses_district_name        2311 non-null   object
#  16  addresses_zip_code             2309 non-null   float64
#  17  addresses_town                 2312 non-null   object
#  18  addresses_main_address         2312 non-null   bool
#  19  addresses_type                 0 non-null      float64
#  20  values_id                      2303 non-null   float64
#  21  values_attribute_id            2303 non-null   float64
#  22  values_category                2303 non-null   object
#  23  values_attribute_name          2303 non-null   object
#  24  values_value                   2303 non-null   object
#  25  values_outstanding             2303 non-null   object
#  26  values_description             54 non-null     object
#  27  secondary_filters_id           1306 non-null   float64
#  28  secondary_filters_name         1306 non-null   object
#  29  secondary_filters_fullpath     1306 non-null   object
#  30  secondary_filters_tree         1306 non-null   float64
#  31  secondary_filters_asia_id      1306 non-null   float64
#  32  geo_epgs_25831_x               2312 non-null   float64
#  33  geo_epgs_25831_y               2312 non-null   float64
#  34  geo_epgs_4326_lat              2312 non-null   float64
#  35  geo_epgs_4326_lon              2312 non-null   float64
#  36  estimated_dates                0 non-null      float64
#  37  start_date                     0 non-null      float64
#  38  end_date                       0 non-null      float64
# dtypes: bool(1), float64(20), int64(2), object(16)
# memory usage: 688.8+ KB
# None
# STATISTICS:
#
#
# Columns with no null values: Index(['register_id', 'name', 'created', 'modified',
#        'addresses_neighborhood_id', 'addresses_district_id', 'addresses_town',
#        'addresses_main_address', 'geo_epgs_25831_x', 'geo_epgs_25831_y',
#        'geo_epgs_4326_lat', 'geo_epgs_4326_lon'],
#       dtype='object')
#
# Columns with null values:
#                            Column  Null Count  Null Percentage
# 0                  institution_id        2174        94.031142
# 1                institution_name        2174        94.031142
# 2           addresses_roadtype_id        2312       100.000000
# 3         addresses_roadtype_name        2312       100.000000
# 4               addresses_road_id           1         0.043253
# 5             addresses_road_name           2         0.086505
# 6   addresses_start_street_number           2         0.086505
# 7     addresses_end_street_number        2130        92.128028
# 8     addresses_neighborhood_name           1         0.043253
# 9         addresses_district_name           1         0.043253
# 10             addresses_zip_code           3         0.129758
# 11                 addresses_type        2312       100.000000
# 12                      values_id           9         0.389273
# 13            values_attribute_id           9         0.389273
# 14                values_category           9         0.389273
# 15          values_attribute_name           9         0.389273
# 16                   values_value           9         0.389273
# 17             values_outstanding           9         0.389273
# 18             values_description        2258        97.664360
# 19           secondary_filters_id        1006        43.512111
# 20         secondary_filters_name        1006        43.512111
# 21     secondary_filters_fullpath        1006        43.512111
# 22         secondary_filters_tree        1006        43.512111
# 23      secondary_filters_asia_id        1006        43.512111
# 24                estimated_dates        2312       100.000000
# 25                     start_date        2312       100.000000
# 26                       end_date        2312       100.000000

# %% [markdown]
# *Seeing the amount of NULL values for each column, we will drop: institution_id, institution_name, addresses_roadtype_id, addresses_roadtype_name, addresses_end_street_number, addresses_type, values_description, estimated_dates, start_date, end_date. Also, the columns created and modified won't be used for the moment.*

# %%
# Drop columns with almost all null values
columns_to_drop_health_equip_bcn = ['created', 'modified', 'institution_id', 'institution_name', 'addresses_roadtype_id', 'addresses_roadtype_name' ,
                                  'addresses_end_street_number', 'addresses_type', 'values_description', 'estimated_dates', 'start_date', 'end_date']

health_equip_bcn_df.drop(columns=columns_to_drop_health_equip_bcn, inplace=True)

# Useless: Identifiador Via, Indicador si l'adreça, Valor de l'atribut identificador, Valor de l'atribut, Valors d'atribut Destacat,
# Arbres d'equivalència Identificador, Arbres d'equivalència Ruta, Arbres d'equivalència, Arbres d'equivalència  Id Asia
#useless_cols = ['addresses_road_id', 'addresses_main_address', 'values_id', 'values_attribute_id', 'values_outstanding', 'secondary_filters_id',
#                'secondary_filters_fullpath', 'secondary_filters_tree', 'secondary_filters_asia_id', 'values_category', 'values_attribute_name']
useless_cols = ['addresses_main_address', 'values_id', 'values_attribute_id', 'values_outstanding', 'secondary_filters_id',
                'secondary_filters_fullpath', 'secondary_filters_tree', 'secondary_filters_asia_id', 'values_category', 'values_attribute_name']

health_equip_bcn_df.drop(columns=useless_cols, inplace=True)
health_equip_bcn_df.head(10)
# Out:
#     register_id                                               name  \
# 0  ﻿75990003218                               Farmàcia Berge Sahli
# 1  ﻿75990023524             Laboratori Fornells Olo Crespo *Urgell
# 2  ﻿75990017609                         Farmàcia Urgelles Fabregas
# 3  ﻿75990017682                          Farmàcia Torres *24 hores
# 4  ﻿75990017682                          Farmàcia Torres *24 hores
# 5   ﻿1015170605                 Centre d'Atenció Primària Sardenya
# 6     ﻿68125439                Instituto Oftalmológico Tres Torres
# 7  ﻿75990034354                             Farmàcia Guasch Badell
# 8     ﻿11090446  Centre d’Atenció a la Salut Sexual i Reproduct...
# 9  ﻿75990048878                           Farmàcia Sabes Arenillas
#
#    addresses_road_id  addresses_road_name  addresses_start_street_number  \
# 0           230601.0  Mare de Déu de Port                          255.0
# 1           349706.0     C Comte d'Urgell                          288.0
# 2            23403.0               Aribau                           36.0
# 3            23403.0               Aribau                           62.0
# 4            23403.0               Aribau                           62.0
# 5            76807.0           C Sardenya                          466.0
# 6            28000.0          Via Augusta                          281.0
# 7            68401.0     Carreras i Candi                           49.0
# 8           140203.0         Av Drassanes                           17.0
# 9           102703.0   C Doctor Letamendi                           13.0
#
#    addresses_neighborhood_id      addresses_neighborhood_name  \
# 0                         13                la Marina de Port
# 1                          8  l'Antiga Esquerra de l'Eixample
# 2                          8  l'Antiga Esquerra de l'Eixample
# 3                          8  l'Antiga Esquerra de l'Eixample
# 4                          8  l'Antiga Esquerra de l'Eixample
# 5                         33                 el Baix Guinardó
# 6                         24                  les Tres Torres
# 7                         17                    Sants - Badal
# 8                          1                         el Raval
# 9                         43                            Horta
#
#    addresses_district_id addresses_district_name  addresses_zip_code  \
# 0                      3          Sants-Montjuïc              8038.0
# 1                      2                Eixample              8036.0
# 2                      2                Eixample              8011.0
# 3                      2                Eixample              8011.0
# 4                      2                Eixample              8011.0
# 5                      7          Horta-Guinardó              8025.0
# 6                      5     Sarrià-Sant Gervasi              8017.0
# 7                      3          Sants-Montjuïc              8028.0
# 8                      1            Ciutat Vella              8001.0
# 9                      7          Horta-Guinardó              8031.0
#
#   addresses_town values_value secondary_filters_name  geo_epgs_25831_x  \
# 0      BARCELONA    933311341              Farmàcies     428303.684524
# 1      BARCELONA    933219870                    NaN     428579.714057
# 2      BARCELONA    934523190              Farmàcies     429858.894739
# 3      BARCELONA    934539220              Farmàcies     429704.219209
# 4      BARCELONA    934539220   Farmàcies permanents     429704.219209
# 5      BARCELONA    935674380                   CAPs     430258.038349
# 6      BARCELONA    900842848  Hospitals i clíniques     427267.424673
# 7      BARCELONA    934224392              Farmàcies     427056.260311
# 8      BARCELONA    934431864  Planificació familiar     430878.786071
# 9      BARCELONA    934279094              Farmàcies     429739.770789
#
#    geo_epgs_25831_y  geo_epgs_4326_lat  geo_epgs_4326_lon
# 0      4.578954e+06          41.358896           2.142841
# 1      4.582635e+06          41.392077           2.145707
# 2      4.582088e+06          41.387260           2.161069
# 3      4.582246e+06          41.388671           2.159201
# 4      4.582246e+06          41.388671           2.159201
# 5      4.584550e+06          41.409469           2.165559
# 6      4.583269e+06          41.397670           2.129935
# 7      4.580566e+06          41.373308           2.127735
# 8      4.580889e+06          41.376550           2.173403
# 9      4.587393e+06          41.435032           2.159029

# %%
# Observe New Info
#display(health_equip_bcn_df.info())

# Check if duplicates
has_duplicates(health_equip_bcn_df, 'register_id')
# Out:
# There's duplicate values in column register_id

# %%
# Print unique values for characteristics column before merging stuff
print("Unique Characteristics:\n")
print(health_equip_bcn_df['secondary_filters_name'].unique(), "\n")

# Remove weird characteristic (NaN, Planificació familiar)
health_equip_bcn_df.dropna(subset=['secondary_filters_name'], inplace=True)
education_equip_df = health_equip_bcn_df[health_equip_bcn_df['secondary_filters_name'] != 'Planificació familiar']

# Aggregate secondary_filters_name (caract.) by register_id and replace column
aggregated_sec_filters = health_equip_bcn_df.groupby('register_id')['secondary_filters_name'].transform(lambda x: ', '.join(x))
health_equip_bcn_df['secondary_filters_name'] = aggregated_sec_filters
#display(education_equip_df.head(10))

# Drop duplicated register_id
health_equip_bcn_df.drop_duplicates(subset='register_id', inplace=True)
display(health_equip_bcn_df.head(10))
# Out:
# Unique Characteristics:
#
# ['Farmàcies' nan 'Farmàcies permanents' 'CAPs' 'Hospitals i clíniques'
#  'Planificació familiar' "Farmàcies servei de 9 a 22 h tot l'any"
#  'Centres urgències (CUAPs)' 'Centres de dia gent gran'
#  'Residències gent gran']
#      register_id                                               name  \
# 0   ﻿75990003218                               Farmàcia Berge Sahli
# 2   ﻿75990017609                         Farmàcia Urgelles Fabregas
# 3   ﻿75990017682                          Farmàcia Torres *24 hores
# 5    ﻿1015170605                 Centre d'Atenció Primària Sardenya
# 6      ﻿68125439                Instituto Oftalmológico Tres Torres
# 7   ﻿75990034354                             Farmàcia Guasch Badell
# 8      ﻿11090446  Centre d’Atenció a la Salut Sexual i Reproduct...
# 9   ﻿75990048878                           Farmàcia Sabes Arenillas
# 11  ﻿75990049258                             Clínica Mi Tres Torres
# 13  ﻿75990034430                              Farmàcia Genis Callol
#
#     addresses_road_id  addresses_road_name  addresses_start_street_number  \
# 0            230601.0  Mare de Déu de Port                          255.0
# 2             23403.0               Aribau                           36.0
# 3             23403.0               Aribau                           62.0
# 5             76807.0           C Sardenya                          466.0
# 6             28000.0          Via Augusta                          281.0
# 7             68401.0     Carreras i Candi                           49.0
# 8            140203.0         Av Drassanes                           17.0
# 9            102703.0   C Doctor Letamendi                           13.0
# 11           103502.0        C Doctor Roux                           76.0
# 13            68503.0           C Carretes                           35.0
#
#     addresses_neighborhood_id      addresses_neighborhood_name  \
# 0                          13                la Marina de Port
# 2                           8  l'Antiga Esquerra de l'Eixample
# 3                           8  l'Antiga Esquerra de l'Eixample
# 5                          33                 el Baix Guinardó
# 6                          24                  les Tres Torres
# 7                          17                    Sants - Badal
# 8                           1                         el Raval
# 9                          43                            Horta
# 11                         24                  les Tres Torres
# 13                          1                         el Raval
#
#     addresses_district_id addresses_district_name  addresses_zip_code  \
# 0                       3          Sants-Montjuïc              8038.0
# 2                       2                Eixample              8011.0
# 3                       2                Eixample              8011.0
# 5                       7          Horta-Guinardó              8025.0
# 6                       5     Sarrià-Sant Gervasi              8017.0
# 7                       3          Sants-Montjuïc              8028.0
# 8                       1            Ciutat Vella              8001.0
# 9                       7          Horta-Guinardó              8031.0
# 11                      5     Sarrià-Sant Gervasi              8017.0
# 13                      1            Ciutat Vella              8001.0
#
#    addresses_town values_value           secondary_filters_name  \
# 0       BARCELONA    933311341                        Farmàcies
# 2       BARCELONA    934523190                        Farmàcies
# 3       BARCELONA    934539220  Farmàcies, Farmàcies permanents
# 5       BARCELONA    935674380                             CAPs
# 6       BARCELONA    900842848            Hospitals i clíniques
# 7       BARCELONA    934224392                        Farmàcies
# 8       BARCELONA    934431864            Planificació familiar
# 9       BARCELONA    934279094                        Farmàcies
# 11      BARCELONA    932041300            Hospitals i clíniques
# 13      BARCELONA    934417184                        Farmàcies
#
#     geo_epgs_25831_x  geo_epgs_25831_y  geo_epgs_4326_lat  geo_epgs_4326_lon
# 0      428303.684524      4.578954e+06          41.358896           2.142841
# 2      429858.894739      4.582088e+06          41.387260           2.161069
# 3      429704.219209      4.582246e+06          41.388671           2.159201
# 5      430258.038349      4.584550e+06          41.409469           2.165559
# 6      427267.424673      4.583269e+06          41.397670           2.129935
# 7      427056.260311      4.580566e+06          41.373308           2.127735
# 8      430878.786071      4.580889e+06          41.376550           2.173403
# 9      429739.770789      4.587393e+06          41.435032           2.159029
# 11     427179.337491      4.583445e+06          41.399249           2.128860
# 13     430387.130830      4.580995e+06          41.377466           2.167512

# %%
# Rename Columns
health_equip_bcn_df = health_equip_bcn_df.rename(columns={"addresses_road_id": "Street ID", "name": "Name", "addresses_road_name": "Road Name", "addresses_start_street_number": "Street Number",
                                                      "addresses_neighborhood_id": "Neighborhood ID", "addresses_neighborhood_name": "Neighborhood Name",
                                                      "addresses_district_id": "District ID", "addresses_district_name": "District Name",
                                                      "addresses_zip_code": "ZipCode","addresses_town": "Town",
                                                      "values_value": "Phone Number", "secondary_filters_name": "Service Type",
                                                      "geo_epgs_4326_lat": "Latitude", "geo_epgs_4326_lon": "Longitude"})
display(health_equip_bcn_df.head(10))
# Out:
#      register_id                                               Name  \
# 0   ﻿75990003218                               Farmàcia Berge Sahli
# 2   ﻿75990017609                         Farmàcia Urgelles Fabregas
# 3   ﻿75990017682                          Farmàcia Torres *24 hores
# 5    ﻿1015170605                 Centre d'Atenció Primària Sardenya
# 6      ﻿68125439                Instituto Oftalmológico Tres Torres
# 7   ﻿75990034354                             Farmàcia Guasch Badell
# 8      ﻿11090446  Centre d’Atenció a la Salut Sexual i Reproduct...
# 9   ﻿75990048878                           Farmàcia Sabes Arenillas
# 11  ﻿75990049258                             Clínica Mi Tres Torres
# 13  ﻿75990034430                              Farmàcia Genis Callol
#
#     Street ID            Road Name  Street Number  Neighborhood ID  \
# 0    230601.0  Mare de Déu de Port          255.0               13
# 2     23403.0               Aribau           36.0                8
# 3     23403.0               Aribau           62.0                8
# 5     76807.0           C Sardenya          466.0               33
# 6     28000.0          Via Augusta          281.0               24
# 7     68401.0     Carreras i Candi           49.0               17
# 8    140203.0         Av Drassanes           17.0                1
# 9    102703.0   C Doctor Letamendi           13.0               43
# 11   103502.0        C Doctor Roux           76.0               24
# 13    68503.0           C Carretes           35.0                1
#
#                   Neighborhood Name  District ID        District Name  \
# 0                 la Marina de Port            3       Sants-Montjuïc
# 2   l'Antiga Esquerra de l'Eixample            2             Eixample
# 3   l'Antiga Esquerra de l'Eixample            2             Eixample
# 5                  el Baix Guinardó            7       Horta-Guinardó
# 6                   les Tres Torres            5  Sarrià-Sant Gervasi
# 7                     Sants - Badal            3       Sants-Montjuïc
# 8                          el Raval            1         Ciutat Vella
# 9                             Horta            7       Horta-Guinardó
# 11                  les Tres Torres            5  Sarrià-Sant Gervasi
# 13                         el Raval            1         Ciutat Vella
#
#     ZipCode       Town Phone Number                     Service Type  \
# 0    8038.0  BARCELONA    933311341                        Farmàcies
# 2    8011.0  BARCELONA    934523190                        Farmàcies
# 3    8011.0  BARCELONA    934539220  Farmàcies, Farmàcies permanents
# 5    8025.0  BARCELONA    935674380                             CAPs
# 6    8017.0  BARCELONA    900842848            Hospitals i clíniques
# 7    8028.0  BARCELONA    934224392                        Farmàcies
# 8    8001.0  BARCELONA    934431864            Planificació familiar
# 9    8031.0  BARCELONA    934279094                        Farmàcies
# 11   8017.0  BARCELONA    932041300            Hospitals i clíniques
# 13   8001.0  BARCELONA    934417184                        Farmàcies
#
#     geo_epgs_25831_x  geo_epgs_25831_y   Latitude  Longitude
# 0      428303.684524      4.578954e+06  41.358896   2.142841
# 2      429858.894739      4.582088e+06  41.387260   2.161069
# 3      429704.219209      4.582246e+06  41.388671   2.159201
# 5      430258.038349      4.584550e+06  41.409469   2.165559
# 6      427267.424673      4.583269e+06  41.397670   2.129935
# 7      427056.260311      4.580566e+06  41.373308   2.127735
# 8      430878.786071      4.580889e+06  41.376550   2.173403
# 9      429739.770789      4.587393e+06  41.435032   2.159029
# 11     427179.337491      4.583445e+06  41.399249   2.128860
# 13     430387.130830      4.580995e+06  41.377466   2.167512

# %%
# Other Health Equipments in Catalunya (NOT EXECUTE)
#display(health_equip_cat_df.info())
#print("\nSTATISTICS:\n")
#display(health_equip_cat_df.describe())
#non_null_cols, info_df = null_function(health_equip_cat_df)
#print("\nColumns with no null values:", non_null_cols)
#print("\nColumns with null values:")
#display(info_df)

# Drop columns with almost all null values
#columns_to_drop_health_equip_cat = ['Codi establiment pare', 'Quilòmetre', 'Bloc', 'Portal', 'Escala', 'Pis', 'Porta', 'Article municipi']

#health_equip_cat_df.drop(columns=columns_to_drop_health_equip_cat, inplace=True)

# Useless: Codi tipus establiment, Titular, Codi tipus de via
#useless_cols = ['Codi tipus establiment', 'Titular', 'Codi tipus de via', 'Georeferència']
#health_equip_cat_df.drop(columns=useless_cols, inplace=True)
#health_equip_cat_df.head(10)

# Observe New Info
#display(health_equip_cat_df.info())

# Check if duplicates
#has_duplicates(health_equip_cat_df, 'Número registre')

#health_equip_cat_bcn_df = health_equip_cat_df[health_equip_cat_df['Municipi'] == 'BARCELONA']
#display(health_equip_cat_bcn_df)

#health_equip_cat_bcn_df['Tipus establiment'].unique()

# Rename Columns
#health_equip_cat_bcn_df = health_equip_cat_bcn_df.rename(columns={"Número registre": "Id", "Nom establiment": "Name", "Tipus establiment": "Service Type",
#                                                                  "Telèfon": "Phone Number", "Tipus de via": "Roadtype", "Nom de la via": "Road Name",
#                                                                  "Número de la via": "Street Number", "Codi postal": "ZipCode", "Codi municipi": "Town ID",
#                                                                  "Municipi": "Town", "Codi comarca": "Region ID", "Comarca": "Region", "Codi província": "Province ID",
#                                                                  "Província": "Province", "Codi ABS": "ABS ID", "ABS": "ABS Name",
#                                                                  "Codi sector sanitari": "Sanitary Sector ID", "Sector sanitari": "Sanitary Sector",
#                                                                  "Codi regió sanitària": "Sanitary Region ID", "Regió sanitària": "Sanitary Region",
#                                                                  "Longitud": "Longitude", "Latitud": "Latitude"})
#
#display(health_equip_cat_bcn_df.head(10))

# %% [markdown]
# ### 6) Indicators

# %%
display(indicators_bcn_df.info())
print("\nSTATISTICS:\n")
#display(indicators_bcn_df.describe())
non_null_cols, info_df = null_function(indicators_bcn_df)
print("\nColumns with no null values:", non_null_cols)
print("\nColumns with null values:")
display(info_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146900 entries, 0 to 146899
# Data columns (total 8 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Data_Indicador        146900 non-null  object
#  1   Frequencia_Indicador  146900 non-null  object
#  2   Territori             146900 non-null  object
#  3   Nom_Indicador         146900 non-null  object
#  4   Nom_Variable          131577 non-null  object
#  5   Valor                 142783 non-null  object
#  6   Unitat                146900 non-null  object
#  7   Font                  146900 non-null  object
# dtypes: object(8)
# memory usage: 9.0+ MB
# None
# STATISTICS:
#
#
# Columns with no null values: Index(['Data_Indicador', 'Frequencia_Indicador', 'Territori', 'Nom_Indicador',
#        'Unitat', 'Font'],
#       dtype='object')
#
# Columns with null values:
#          Column  Null Count  Null Percentage
# 0  Nom_Variable       15323        10.430905
# 1         Valor        4117         2.802587

# %% [markdown]
# *For the moment, we won't drop any column.*

# %%
indicators_bcn_df.head(10)
# Out:
#   Data_Indicador Frequencia_Indicador  Territori  \
# 0     2020-02-25                diari  Barcelona
# 1     2020-02-26                diari  Barcelona
# 2     2020-02-27                diari  Barcelona
# 3     2020-02-28                diari  Barcelona
# 4     2020-02-29                diari  Barcelona
# 5     2020-03-01                diari  Barcelona
# 6     2020-03-02                diari  Barcelona
# 7     2020-03-03                diari  Barcelona
# 8     2020-03-04                diari  Barcelona
# 9     2020-03-05                diari  Barcelona
#
#                            Nom_Indicador Nom_Variable Valor  Unitat  \
# 0  Casos de COVID-19 a Barcelona (diari)          NaN   1.0  Nombre
# 1  Casos de COVID-19 a Barcelona (diari)          NaN   0.0  Nombre
# 2  Casos de COVID-19 a Barcelona (diari)          NaN   0.0  Nombre
# 3  Casos de COVID-19 a Barcelona (diari)          NaN   0.0  Nombre
# 4  Casos de COVID-19 a Barcelona (diari)          NaN   0.0  Nombre
# 5  Casos de COVID-19 a Barcelona (diari)          NaN   0.0  Nombre
# 6  Casos de COVID-19 a Barcelona (diari)          NaN   1.0  Nombre
# 7  Casos de COVID-19 a Barcelona (diari)          NaN   0.0  Nombre
# 8  Casos de COVID-19 a Barcelona (diari)          NaN   1.0  Nombre
# 9  Casos de COVID-19 a Barcelona (diari)          NaN   2.0  Nombre
#
#                                     Font
# 0  Agència de Salut Pública de Barcelona
# 1  Agència de Salut Pública de Barcelona
# 2  Agència de Salut Pública de Barcelona
# 3  Agència de Salut Pública de Barcelona
# 4  Agència de Salut Pública de Barcelona
# 5  Agència de Salut Pública de Barcelona
# 6  Agència de Salut Pública de Barcelona
# 7  Agència de Salut Pública de Barcelona
# 8  Agència de Salut Pública de Barcelona
# 9  Agència de Salut Pública de Barcelona

# %%
# Rename Columns
indicators_bcn_df = indicators_bcn_df.rename(columns={"Data_Indicador": "Date", "Frequencia_Indicador": "Frequency", "Territori": "Place",
                                                      "Nom_Indicador": "Indicator", "Nom_Variable": "Variable Name", "Valor": "Variable Value",
                                                      "Unitat": "Unit", "Font": "Source"})
display(indicators_bcn_df.head(10))
# Out:
#          Date Frequency      Place                              Indicator  \
# 0  2020-02-25     diari  Barcelona  Casos de COVID-19 a Barcelona (diari)
# 1  2020-02-26     diari  Barcelona  Casos de COVID-19 a Barcelona (diari)
# 2  2020-02-27     diari  Barcelona  Casos de COVID-19 a Barcelona (diari)
# 3  2020-02-28     diari  Barcelona  Casos de COVID-19 a Barcelona (diari)
# 4  2020-02-29     diari  Barcelona  Casos de COVID-19 a Barcelona (diari)
# 5  2020-03-01     diari  Barcelona  Casos de COVID-19 a Barcelona (diari)
# 6  2020-03-02     diari  Barcelona  Casos de COVID-19 a Barcelona (diari)
# 7  2020-03-03     diari  Barcelona  Casos de COVID-19 a Barcelona (diari)
# 8  2020-03-04     diari  Barcelona  Casos de COVID-19 a Barcelona (diari)
# 9  2020-03-05     diari  Barcelona  Casos de COVID-19 a Barcelona (diari)
#
#   Variable Name Variable Value    Unit                                 Source
# 0           NaN            1.0  Nombre  Agència de Salut Pública de Barcelona
# 1           NaN            0.0  Nombre  Agència de Salut Pública de Barcelona
# 2           NaN            0.0  Nombre  Agència de Salut Pública de Barcelona
# 3           NaN            0.0  Nombre  Agència de Salut Pública de Barcelona
# 4           NaN            0.0  Nombre  Agència de Salut Pública de Barcelona
# 5           NaN            0.0  Nombre  Agència de Salut Pública de Barcelona
# 6           NaN            1.0  Nombre  Agència de Salut Pública de Barcelona
# 7           NaN            0.0  Nombre  Agència de Salut Pública de Barcelona
# 8           NaN            1.0  Nombre  Agència de Salut Pública de Barcelona
# 9           NaN            2.0  Nombre  Agència de Salut Pública de Barcelona

# %%
indicators_bcn_df['Indicator'].unique()
# Out:
# array(['Casos de COVID-19 a Barcelona (diari)',
#        'Casos de COVID-19 a Catalunya (diari)',
#        'Casos de COVID-19 a Espanya (diari)',
#        'Casos de COVID-19 a Barcelona (acumulat)',
#        'Casos de COVID-19 a Catalunya (acumulat)',
#        'Casos de COVID-19 a Espanya (acumulat)',
#        'Casos de COVID-19 als hospitals de Barcelona',
#        'Professionals inhàbils del consorci sanitari',
#        'Nombre de dosis administrades de vacunes per al SARS-CoV-2 a Barcelona (diàries)',
#        'Nombre de dosis administrades de vacunes per al SARS-CoV-2 a Catalunya (diàries)',
#        'Nombre de dosis administrades de vacunes per al SARS-CoV-2 a Barcelona (acumulades)',
#        'Nombre de dosis administrades de vacunes per al SARS-CoV-2 a Catalunya (acumulades)',
#        'Alumnes confinats en centres educatius (diaris)',
#        'Alumnes confinats en centres educatius segons districte municipal (diaris)',
#        'Defuncions totals registrades a Barcelona',
#        'Defuncions totals a Barcelona (estimació)',
#        'Defuncions totals a Catalunya (estimació)',
#        'Defuncions totals a Espanya (estimació)',
#        "Visitants a museus de l'ICUB (dades setmanals)",
#        "Visitants a museus de l'ICUB segons tipus (dades setmanals)",
#        'Contaminants ambientals: NO₂ i PM₁₀ (Eixample)',
#        'Contaminants ambientals: NO₂ i PM₁₀ (Palau Reial)',
#        'Contaminació acústica: Decibels', 'Dades meteorològiques: Vent',
#        'Dades meteorològiques: Precipitació',
#        'Dades meteorològiques: Temperatura',
#        'Població estimada a Barcelona',
#        'Població estimada a Barcelona segons franja horària',
#        'Població estimada a Barcelona segons procedència',
#        "Operacions d'aeronaus a l'aeroport de Barcelona-El Prat",
#        "Operacions d'aeronaus a l'aeroport de Barcelona-El Prat segons origen/destinació",
#        'Escales realitzades al port de Barcelona',
#        'Escales realitzades al port de Barcelona per tipus de vaixell',
#        'Demanda de transport públic', 'Mobilitat de vehicles a Barcelona',
#        'Composició del trànsit a Zones de Baixes Emissions',
#        'Estat del trànsit', 'Estat del trànsit segons trams horaris',
#        'Visitants a Barcelona segons municipi d’origen',
#        'Visitants a Barcelona segons província d’origen',
#        'Visitants a Barcelona segons país d’origen', 'IPC interanual',
#        'IPC interanual/subjacent', 'Fruites i hortalisses', 'Carn i peix',
#        'Peix i marisc', 'Carn', 'Carburants: Gasolina 95 i diesel A',
#        'Preu electricitat (majorista)', 'Aturats registrats a Barcelona',
#        'Contractes laborals a Barcelona',
#        'Afiliats a la Seguretat Social de Barcelona',
#        'Treballadors afectats per ERTO a Catalunya',
#        "Expedients de Regulació Temporal d'Ocupació",
#        "Treballadors afectats per Expedients de Regulació Temporal d'Ocupació",
#        'Treballadors afectats per ERTO a Barcelona per sector',
#        'Consum elèctric a Barcelona', 'Consum aigua a Barcelona',
#        'Matriculacions de vehicles a Barcelona',
#        'Mercat bursàtil: IBEX-35',
#        "Compres amb targetes bancàries (% variació sobre el mateix periode de l'any anterior)",
#        "Compres amb targetes bancàries per sectors (% variació sobre el mateix periode de l'any anterior)",
#        "Compra-Venda d'habitatges a Barcelona (Nombre de transmissions)",
#        'Preu mitjà de venda dels habitatges a Barcelona (Preu €/m² mitjà)',
#        'Indicador de reserves hoteleres domèstiques (base = mitjana suavitzada gener/febrer 2020)',
#        'Indicador de reserves hoteleres internacionals (base = mitjana suavitzada gener/febrer 2020)',
#        'Nombre de casos positius per barri',
#        'Incidència de casos positius per barris: taxes per 100.000 habitants',
#        'Enquesta opinió: Ha tingut algun símptoma del coronavirus?',
#        'Enquesta opinió: Ha tingut símptomes, li han fet la prova de detecció del coronavirus?',
#        "Enquesta opinió: Situació dels treballadors per compte d'altri",
#        "Enquesta opinió: Formes de treball dels treballadors per compte d'altri",
#        'Enquesta opinió: % Persones confinades soles',
#        'Enquesta opinió: Mitjana de persones confinades a la llar',
#        'Enquesta opinió: Com està sent de dur el confinament?',
#        'Enquesta opinió: Ha de sortir de casa per atendre alguna persona que ho necessita?',
#        "Enquesta opinió: Vostè, necessita ajuda d'alguna persona?",
#        'Enquesta opinió: Com està de preocupat per la situació que estem vivint?',
#        'Enquesta opinió: Quin és per a vostè el problema més important que cal abordar en aquesta crisi? (Espontània)',
#        "Enquesta opinió: Valoració de la gestió de l'Ajuntament de Barcelona en la crisi del coronavirus",
#        'Enquesta opinió: Valoració de la gestió de la Generalitat de Catalunya en la crisi del coronavirus',
#        'Enquesta opinió: Valoració de la gestió del Govern espanyol en la crisi del coronavirus',
#        'Cronograma de notícies'], dtype=object)

# %%
indicators_bcn_df['Variable Name'].unique()
# Out:
# array([nan, 'Altes', 'Ingressats', 'AIS Nord', 'AIS Dreta',
#        'AIS Litoral Mar', 'AIS Esquerra', 'Dosi 1', 'Dosi 2', 'Dosi 3',
#        'Ciutat vella', 'Eixample', 'Gràcia', 'Horta - Guinardó',
#        'Les Corts', 'Nou Barris', 'Sant Andreu', 'Sant Martí',
#        'Sants - Montjuïc', 'Sarrià - Sant Gervasi',
#        'Serveis als cementiris', 'Recollides de funeràries',
#        'Defuncions padró', 'Observades', 'Esperades', 'Pagament',
#        'No pagament', 'No consta', 'Màxim horari NO2', 'Mitjana NO2',
#        'Mitjana PM10', '4h', '19h', 'Barcelona - Observatori Fabra',
#        'Barcelona - el Raval', 'Barcelona - Zona Universitària',
#        '00AM:03AM', '04AM:07AM', '08AM:11AM', '12PM:15PM', '16PM:19PM',
#        '20PM:23PM', 'Internacionals', 'Nacionals', 'Commuters',
#        'Residents', 'Europa', 'Espanya', 'Àsia', 'Amèrica', 'Àfrica',
#        'Oceania', 'Altres', 'Creuers i Iots', 'Càrrega', 'Ferris', 'FGC',
#        'Metro', 'Renfe', 'Bus', 'TRAM', 'Accessos', 'Interior ciutat',
#        'Rondes', 'Carrils bici', 'Motos', 'Turismes',
#        'Transport col·lectiu', 'Distribució mercaderies', 'Nit (0-5)',
#        'Matí (6-13)', 'Tarda (14-19)', 'Vespre (20-24)', 'Badalona',
#        "L'Hospitalet de Llobregat", 'Sabadell',
#        'Santa Coloma de Gramenet', 'Terrassa', 'Illes Balears', 'Girona',
#        'Lleida', 'Madrid', 'Tarragona', 'França', 'Regne Unit', 'Itàlia',
#        'Països Baixos', 'Estats Units', 'Barcelona', 'Catalunya',
#        'Espanya (IPC interanual)', 'Espanya (IPC subjacent)',
#        'Zona Euro (IPC interanual)', 'Zona Euro (IPC subjacent)', 'Ceba',
#        'Patata', 'Plàtan', 'Poma', 'Taronja', 'Llenguado', 'Llobarro',
#        'Lluç', 'Orada', 'Porcí', 'Pollastre', 'Oví', 'Vaquí',
#        'Gasolina 95', 'Diesel A', 'Hostaleria', 'Comerç',
#        'Activitats artístiques', 'Activitats administratives', 'Educació',
#        'Indústries manufactureres', 'Activitats professionals',
#        'Altres serveis', 'Activitats sanitàries', 'Construcció',
#        'Resta de sectors', 'Vehicles',
#        'Béns i serveis de primera necessitat', 'Vestit, calçat i moda',
#        'Transport i automoció', 'Tecnologia',
#        'Serveis turístics i de restauració', 'Cultura, lleure i esports',
#        'Resta béns i serveis', 'Habitatges', 'Tendència', 'Preu mig m²',
#        'el Raval', 'el Barri Gòtic', 'la Barceloneta',
#        'Sant Pere, Santa Caterina i la Ribera', 'el Fort Pienc',
#        'la Sagrada Família', "la Dreta de l'Eixample",
#        "l'Antiga Esquerra de l'Eixample",
#        "la Nova Esquerra de l'Eixample", 'Sant Antoni', 'el Poble Sec',
#        'la Marina del Prat Vermell', 'la Marina de Port',
#        'la Font de la Guatlla', 'Hostafrancs', 'la Bordeta',
#        'Sants - Badal', 'Sants', 'les Corts',
#        'la Maternitat i Sant Ramon', 'Pedralbes',
#        'Vallvidrera, el Tibidabo i les Planes', 'Sarrià',
#        'les Tres Torres', 'Sant Gervasi - la Bonanova',
#        'Sant Gervasi - Galvany', 'el Putget i el Farró',
#        'Vallcarca i els Penitents', 'el Coll', 'la Salut',
#        'la Vila de Gràcia', "el Camp d'en Grassot i Gràcia Nova",
#        'el Baix Guinardó', 'Can Baró', 'el Guinardó',
#        "la Font d'en Fargues", 'el Carmel', 'la Teixonera',
#        'Sant Genís dels Agudells', 'Montbau', "la Vall d'Hebron",
#        'la Clota', 'Horta', 'Vilapicina i la Torre Llobeta', 'Porta',
#        'el Turó de la Peira', 'Can Peguera', 'la Guineueta', 'Canyelles',
#        'les Roquetes', 'Verdun', 'la Prosperitat', 'la Trinitat Nova',
#        'Torre Baró', 'Ciutat Meridiana', 'Vallbona', 'la Trinitat Vella',
#        'Baró de Viver', 'el Bon Pastor', 'la Sagrera',
#        'el Congrés i els Indians', 'Navas', "el Camp de l'Arpa del Clot",
#        'el Clot', 'el Parc i la Llacuna del Poblenou',
#        'la Vila Olímpica del Poblenou', 'el Poblenou',
#        'Diagonal Mar i el Front Marítim del Poblenou',
#        'el Besòs i el Maresme', 'Provençals del Poblenou',
#        'Sant Martí de Provençals', 'la Verneda i la Pau', 'Si',
#        'Ha tingut símptomes i ha fet el test',
#        'Ha tingut símptomes i no ha fet el test', 'ERTO', 'Acomiadats',
#        'Sense canvis - No poden treballar',
#        'Sense canvis - Poden treballar', 'Presencialment', 'Teletreball',
#        'Presencialment + teletreball', 'Molt / Bastant dur',
#        'Poc / Gens dur', 'Molt / Bastant', 'Normal / Regular',
#        'Poc / Gens', 'Economia',
#        'Complir les mesures de confinament i prevenció',
#        'Millorar el sistema sanitari / més recursos / revertir les retallades',
#        'Buscar la curació de la malaltia', 'Cohesió social',
#        'Millorar la prevenció / detecció en la malaltia',
#        'La manca de material sanitari', 'Gestionar el desconfinament',
#        'No ho sap', 'Salut (en general)',
#        'La gestió política (coordinació, entesa, previsió)',
#        'Cura de les persones grans', 'Els nens', 'Millorar la informació',
#        'Incertesa del futur', 'Res', 'No contesta', 'Molt bona / bona',
#        'Normal / regular', 'Dolenta / molt dolenta',
#        'OMS declaracions emergència', 'Internacional actuacions',
#        "Govern d'Espanya Actuacions", 'Primer cas a Espanya',
#        'Cancel·lacions esdeveniments', 'Espanya actuacions',
#        'Primera mesura de confinament massiu',
#        'Concentracions massives als carrers', 'Generalitat de Catalunya',
#        'Ajuntament de Barcelona Actuacions', 'Congrés dels Diputats',
#        "Confinament Conca d'Òdena",
#        'Aplicació del pla de transició després del confinament',
#        'Transició a la nova normalitat', 'Unió Europea',
#        'Noves mesures de confinament'], dtype=object)

# %% [markdown]
# ### 1.3. Dataset Merging

# %% [markdown]
# - Datasets with same columns: hospitals_caps_df, pharmacies_bcn_df, day_centers_df, residences_df, health_equip_bcn_df
#
# - Datasets with different columns: indicators_bcn_df, pharmacies_cat_bcn_df, health_equip_cat_bcn_df

# %%
# Data Merging (same columns)
health_df = pd.concat([hospitals_caps_df, pharmacies_bcn_df, day_centers_df, residences_df, health_equip_bcn_df], ignore_index=True)

# Drop duplicates
health_df = health_df.drop_duplicates(subset='register_id', keep='first')
display(health_df)
# Out:
#        register_id                                               Name  \
# 0      ﻿1015170605                 Centre d'Atenció Primària Sardenya
# 1        ﻿68125439                Instituto Oftalmológico Tres Torres
# 2     ﻿75990049258                             Clínica Mi Tres Torres
# 3     ﻿93056132443                Centre d'Atenció Primària Montnegre
# 4     ﻿75990060288                              Hospital de Barcelona
# ...            ...                                                ...
# 2747  ﻿99400706843  Centre d’Atenció a la Salut Sexual i Reproduct...
# 2764  ﻿99400706848  Centre d’Atenció a la Salut Sexual i Reproduct...
# 2765  ﻿99400706838  Centre d’Atenció a la Salut Sexual i Reproduct...
# 2766  ﻿99400706854  Centre d’Atenció a la Salut Sexual i Reproduct...
# 2767  ﻿99400706845  Centre d’Atenció a la Salut Sexual i Reproduct...
#
#       Street ID                  Road Name  Street Number  Neighborhood ID  \
# 0       76807.0                 C Sardenya          466.0               33
# 1       28000.0                Via Augusta          281.0               24
# 2      103502.0              C Doctor Roux           76.0               24
# 3      219100.0                C Montnegre           21.0               19
# 4      144601.0                Av Diagonal          660.0               19
# ...         ...                        ...            ...              ...
# 2747    86902.0    Carrer Nou de la Rambla          169.0               11
# 2764   140804.0       Carrer de Garigliano           23.0               50
# 2765   286504.0    Carrer de Roger de Flor          194.0                7
# 2766   700957.0      Carrer de Pere Vergés            3.0               73
# 2767   334403.0  Carrer de Teodor Llorente           26.0               35
#
#            Neighborhood Name  District ID        District Name  ZipCode  \
# 0           el Baix Guinardó            7       Horta-Guinardó   8025.0
# 1            les Tres Torres            5  Sarrià-Sant Gervasi   8017.0
# 2            les Tres Torres            5  Sarrià-Sant Gervasi   8017.0
# 3                  les Corts            4            Les Corts   8029.0
# 4                  les Corts            4            Les Corts   8034.0
# ...                      ...          ...                  ...      ...
# 2747            el Poble-sec            3       Sants-Montjuïc   8004.0
# 2764            les Roquetes            8           Nou Barris   8042.0
# 2765  la Dreta de l'Eixample            2             Eixample   8013.0
# 2766     la Verneda i la Pau           10           Sant Martí   8020.0
# 2767             el Guinardó            7       Horta-Guinardó   8041.0
#
#            Town Phone Number           Service Type  geo_epgs_25831_x  \
# 0     BARCELONA    935674380                   CAPs     430258.038349
# 1     BARCELONA    900842848  Hospitals i clíniques     427267.424673
# 2     BARCELONA    932041300  Hospitals i clíniques     427179.337491
# 3     BARCELONA    933632965                   CAPs     427992.371870
# 4     BARCELONA    932542400  Hospitals i clíniques     427228.518238
# ...         ...          ...                    ...               ...
# 2747  Barcelona  933 249 100  Planificació familiar     430319.122000
# 2764  Barcelona  932 768 066  Planificació familiar     430993.757000
# 2765  Barcelona  934 585 980  Planificació familiar     430845.936000
# 2766  Barcelona  932 788 660  Planificació familiar     433893.712000
# 2767  Barcelona  933 489 901  Planificació familiar     431370.330000
#
#       geo_epgs_25831_y   Latitude  Longitude
# 0         4.584550e+06  41.409469   2.165559
# 1         4.583269e+06  41.397670   2.129935
# 2         4.583445e+06  41.399249   2.128860
# 3         4.582146e+06  41.387618   2.138740
# 4         4.582406e+06  41.389892   2.129574
# ...                ...        ...        ...
# 2747      4.580348e+06  41.371628   2.166773
# 2764      4.588615e+06  41.446149   2.173897
# 2765      4.583368e+06  41.398874   2.172728
# 2766      4.586013e+06  41.422953   2.208895
# 2767      4.585597e+06  41.419000   2.178747
#
# [1601 rows x 17 columns]

# %%
# NOT EXECUTE
#indicators_bcn_df, pharmacies_cat_bcn_df, health_equip_cat_bcn_df

# Pharmacies
#drop_merge_pharmacies = ['Id', 'Roadtype', 'Town ID', 'Town']
# Concatenar las columnas 'roadtype' y 'roadname'
#pharmacies_cat_bcn_df['Road Name'] = pharmacies_cat_bcn_df['Roadtype'] + ' ' + pharmacies_cat_bcn_df['Road Name']
#pharmacies_cat_bcn_df.drop(columns=drop_merge_pharmacies, inplace=True)
#pharmacies_cat_bcn_df.info()
#display(pharmacies_cat_bcn_df)

# Health Equipment
#drop_merge_health_equip = ['Id', 'Phone Number', 'Roadtype', 'Town ID', 'Town', 'Region ID', 'Region', 'Province ID', 'Province',
#                           'Sanitary Region', 'Sanitary Region ID']
# Concatenar las columnas 'roadtype' y 'roadname'
#health_equip_cat_bcn_df['Road Name'] = health_equip_cat_bcn_df['Roadtype'] + ' ' + health_equip_cat_bcn_df['Road Name']
#health_equip_cat_bcn_df.drop(columns=drop_merge_health_equip, inplace=True)
#health_equip_cat_bcn_df.info()
#display(health_equip_cat_bcn_df)


# Final Data Merging (dif columns)
# health_df.drop(columns=['register_id', 'Town', 'Phone Number'], inplace=True)
# health_df = pd.concat([health_df, pharmacies_cat_bcn_df, health_equip_cat_bcn_df], ignore_index=True)

# All names in minus (some are mayus)
# health_df['Name'] = health_df['Name'].str.lower()
# Convertir la columna 'Neighborhood ID', 'District ID', 'ZipCode', 'ABS ID' and 'Sanitary Sector ID' a tipo entero (1º NaN a 0, 2º Values to int)
# Street Number NO, because there can be 'bis'

# health_df['Neighborhood ID'].fillna(value=0, inplace=True)
# health_df['Neighborhood ID'] = health_df['Neighborhood ID'].astype(int)
# health_df['District ID'].fillna(value=0, inplace=True)
# health_df['District ID'] = health_df['District ID'].astype(int)
# health_df['ZipCode'].fillna(value=0, inplace=True)
# health_df['ZipCode'] = health_df['ZipCode'].astype(int)
# health_df['ABS ID'].fillna(value=0, inplace=True)
# health_df['ABS ID'] = health_df['ABS ID'].astype(int)
# health_df['Sanitary Sector ID'].fillna(value=0, inplace=True)
# health_df['Sanitary Sector ID'] = health_df['Sanitary Sector ID'].astype(int)

# Drop duplicates
# health_df = health_df.drop_duplicates(subset='Name', keep='first')
# display(health_df)

# %%
cols = health_df.columns.tolist()

for col in cols:
    print(col,"Nulls:",health_df[col].isnull().sum())
# Out:
# Name Nulls: 0
# Street ID Nulls: 1
# Road Name Nulls: 1
# Street Number Nulls: 1
# Neighborhood ID Nulls: 0
# Neighborhood Name Nulls: 0
# District ID Nulls: 0
# District Name Nulls: 0
# ZipCode Nulls: 1
# Service Type Nulls: 0
# geo_epgs_25831_x Nulls: 0
# geo_epgs_25831_y Nulls: 0
# Latitude Nulls: 0
# Longitude Nulls: 0

# %% [markdown]
# ### Revise services

# %%
health_df['Service Type'].unique()
# Out:
# array(['CAPs', 'Hospitals i clíniques', 'CAPs, Centres urgències (CUAPs)',
#        'Centres urgències (CUAPs)',
#        'Hospitals i clíniques, Centres de dia gent gran',
#        'Hospitals i clíniques, Residències gent gran', 'Farmàcies',
#        "Farmàcies, Farmàcies servei de 9 a 22 h tot l'any",
#        'Farmàcies, Farmàcies permanents', 'Centres de dia gent gran',
#        'Centres de dia gent gran, Residències gent gran',
#        'Residències gent gran', 'Planificació familiar'], dtype=object)

# %%
health_df = health_df[health_df['Service Type'] != 'Planificació familiar']

# %% [markdown]
# ### Service Type Grouping

# %%
# DataFrame: health_df
# Define the mapping for replacement
pharmacy_mapping = {
    'Farmàcies': 'Farmàcia',
    "Farmàcies, Farmàcies servei de 9 a 22 h tot l'any": 'Farmàcia',
    'Farmàcies, Farmàcies permanents': 'Farmàcia',
    'Farmaciola': 'Farmàcia',
    # Add more mappings as needed
}

# Replace values in the 'ServiceType' column
health_df['Service Type'] = health_df['Service Type'].replace(pharmacy_mapping)

display(health_df)
# Out:
#                                                    Name  Street ID  \
# 0                    Centre d'Atenció Primària Sardenya    76807.0
# 1                   Instituto Oftalmológico Tres Torres    28000.0
# 2                                Clínica Mi Tres Torres   103502.0
# 3                   Centre d'Atenció Primària Montnegre   219100.0
# 4                                 Hospital de Barcelona   144601.0
# ...                                                 ...        ...
# 1571  Residència Assistencial per a Gent Gran San Pedro   309406.0
# 1572  Residència Assistida per a Gent Gran Institut ...   315500.0
# 1573  Residència Assistida per a Gent Gran Vibentia ...   263600.0
# 1574  Residència Assitida per a Gent Gran La Vostra ...   137300.0
# 1575         Residència Assistida per a Gent Gran Orpea   152905.0
#
#                  Road Name  Street Number  Neighborhood ID  \
# 0               C Sardenya          466.0               33
# 1              Via Augusta          281.0               24
# 2            C Doctor Roux           76.0               24
# 3              C Montnegre           21.0               19
# 4              Av Diagonal          660.0               19
# ...                    ...            ...              ...
# 1571         Rda Sant Pere           60.0                7
# 1572      Pg Santa Eulàlia           23.0               23
# 1573             C Portell           11.0               37
# 1574  Carrer de la Foneria           29.0               13
# 1575    Ronda del Guinardó           48.0               33
#
#            Neighborhood Name  District ID        District Name  ZipCode  \
# 0           el Baix Guinardó            7       Horta-Guinardó   8025.0
# 1            les Tres Torres            5  Sarrià-Sant Gervasi   8017.0
# 2            les Tres Torres            5  Sarrià-Sant Gervasi   8017.0
# 3                  les Corts            4            Les Corts   8029.0
# 4                  les Corts            4            Les Corts   8034.0
# ...                      ...          ...                  ...      ...
# 1571  la Dreta de l'Eixample            2             Eixample   8010.0
# 1572                  Sarrià            5  Sarrià-Sant Gervasi   8017.0
# 1573               el Carmel            7       Horta-Guinardó   8023.0
# 1574       la Marina de Port            3       Sants-Montjuïc   8038.0
# 1575        el Baix Guinardó            7       Horta-Guinardó   8025.0
#
#                Service Type  geo_epgs_25831_x  geo_epgs_25831_y   Latitude  \
# 0                      CAPs     430258.038349      4.584550e+06  41.409469
# 1     Hospitals i clíniques     427267.424673      4.583269e+06  41.397670
# 2     Hospitals i clíniques     427179.337491      4.583445e+06  41.399249
# 3                      CAPs     427992.371870      4.582146e+06  41.387618
# 4     Hospitals i clíniques     427228.518238      4.582406e+06  41.389892
# ...                     ...               ...               ...        ...
# 1571  Residències gent gran     431283.357815      4.582468e+06  41.390806
# 1572  Residències gent gran     425956.699256      4.583965e+06  41.403816
# 1573  Residències gent gran     429053.952844      4.585498e+06  41.417910
# 1574  Residències gent gran     427900.987000      4.579122e+06  41.360380
# 1575  Residències gent gran     430407.357000      4.584836e+06  41.412063
#
#       Longitude
# 0      2.165559
# 1      2.129935
# 2      2.128860
# 3      2.138740
# 4      2.129574
# ...         ...
# 1571   2.178062
# 1572   2.114172
# 1573   2.151043
# 1574   2.138007
# 1575   2.167313
#
# [1572 rows x 14 columns]

# %%
health_df['Service Type'].unique()
# Out:
# array(['CAPs', 'Hospitals i clíniques', 'CAPs, Centres urgències (CUAPs)',
#        'Centres urgències (CUAPs)',
#        'Hospitals i clíniques, Centres de dia gent gran',
#        'Hospitals i clíniques, Residències gent gran', 'Farmàcia',
#        'Centres de dia gent gran',
#        'Centres de dia gent gran, Residències gent gran',
#        'Residències gent gran'], dtype=object)

# %%
#display(health_df[health_df['Street ID'].isna()])
health_df = health_df.dropna(subset=['Street ID'])

# %%
health_df['Street ID'] = health_df['Street ID'].astype(int)
#display(health_df)

# %% [markdown]
# ### Rename Service Type options into english or group

# %%
health_df['Service Type'].unique()
# Out:
# array(['CAPs', 'Hospitals i clíniques', 'CAPs, Centres urgències (CUAPs)',
#        'Centres urgències (CUAPs)',
#        'Hospitals i clíniques, Centres de dia gent gran',
#        'Hospitals i clíniques, Residències gent gran', 'Farmàcia',
#        'Centres de dia gent gran',
#        'Centres de dia gent gran, Residències gent gran',
#        'Residències gent gran'], dtype=object)

# %%
display(health_df[health_df['Service Type'] == 'Hospitals i clíniques, Centres de dia gent gran'])
# Out:
#                                                  Name  Street ID  \
# 15  Centre de Dia Serveis Geriàtrics de Barcelona ...     209900
#
#        Road Name  Street Number  Neighborhood ID Neighborhood Name  \
# 15  Av Meridiana          328.0               61        la Sagrera
#
#     District ID District Name  ZipCode  \
# 15            9   Sant Andreu   8027.0
#
#                                        Service Type  geo_epgs_25831_x  \
# 15  Hospitals i clíniques, Centres de dia gent gran     432077.120325
#
#     geo_epgs_25831_y   Latitude  Longitude
# 15      4.586307e+06  41.425457   2.187124

# %%
display(health_df[health_df['Service Type'] == 'Hospitals i clíniques, Residències gent gran'])
# Out:
#                                                  Name  Street ID  \
# 71  Residència Sociosanitaria Assistida Psicoclíni...     349105
#
#        Road Name  Street Number  Neighborhood ID Neighborhood Name  \
# 71  Pg Universal           34.0               43             Horta
#
#     District ID   District Name  ZipCode  \
# 71            7  Horta-Guinardó   8042.0
#
#                                     Service Type  geo_epgs_25831_x  \
# 71  Hospitals i clíniques, Residències gent gran     429990.319293
#
#     geo_epgs_25831_y   Latitude  Longitude
# 71      4.587706e+06  41.437877   2.161991

# %%
display(health_df[health_df['Service Type'] == 'Centres de dia gent gran, Residències gent gran'])
# Out:
#                                                    Name  Street ID  \
# 1177               Centre Residencial Mutuam Collserola     352507
# 1231  Residència Assistida per a Gent Gran Acollimen...     270901
#
#               Road Name  Street Number  Neighborhood ID Neighborhood Name  \
# 1177   Pg Vall d'Hebron          159.0               40           Montbau
# 1231  Carrer de Pujades          273.0               68       el Poblenou
#
#       District ID   District Name  ZipCode  \
# 1177            7  Horta-Guinardó   8007.0
# 1231           10      Sant Martí   8005.0
#
#                                          Service Type  geo_epgs_25831_x  \
# 1177  Centres de dia gent gran, Residències gent gran     428724.599637
# 1231  Centres de dia gent gran, Residències gent gran     433588.468093
#
#       geo_epgs_25831_y   Latitude  Longitude
# 1177      4.587410e+06  41.435098   2.146877
# 1231      4.584073e+06  41.405456   2.205455

# %%
# MAPPING
mappings = {
    'CAPs': 'CAP (Primary Healthcare Center)',
    'CAPs, Centres urgències (CUAPs)': 'CAP (Primary Healthcare Center)',
    'Centres urgències (CUAPs)': 'CAP (Primary Healthcare Center)',
    'Hospitals i clíniques': 'Hospital & Clinic',
    # Geriatric
    'Hospitals i clíniques, Centres de dia gent gran': 'Day center for the elderly',
    'Centres de dia gent gran': 'Day center for the elderly',
    'Residències gent gran': 'Residence for the elderly',
    # Sociosanitariy
    'Hospitals i clíniques, Residències gent gran': 'Residence for the elderly',
    'Centres de dia gent gran, Residències gent gran': 'Residence for the elderly',
    'Farmàcia': 'Pharmacy',
}

health_df['Service Type'] = health_df['Service Type'].replace(mappings)
display(health_df)
# Out:
#                                                    Name  Street ID  \
# 0                    Centre d'Atenció Primària Sardenya      76807
# 1                   Instituto Oftalmológico Tres Torres      28000
# 2                                Clínica Mi Tres Torres     103502
# 3                   Centre d'Atenció Primària Montnegre     219100
# 4                                 Hospital de Barcelona     144601
# ...                                                 ...        ...
# 1571  Residència Assistencial per a Gent Gran San Pedro     309406
# 1572  Residència Assistida per a Gent Gran Institut ...     315500
# 1573  Residència Assistida per a Gent Gran Vibentia ...     263600
# 1574  Residència Assitida per a Gent Gran La Vostra ...     137300
# 1575         Residència Assistida per a Gent Gran Orpea     152905
#
#                  Road Name  Street Number  Neighborhood ID  \
# 0               C Sardenya          466.0               33
# 1              Via Augusta          281.0               24
# 2            C Doctor Roux           76.0               24
# 3              C Montnegre           21.0               19
# 4              Av Diagonal          660.0               19
# ...                    ...            ...              ...
# 1571         Rda Sant Pere           60.0                7
# 1572      Pg Santa Eulàlia           23.0               23
# 1573             C Portell           11.0               37
# 1574  Carrer de la Foneria           29.0               13
# 1575    Ronda del Guinardó           48.0               33
#
#            Neighborhood Name  District ID        District Name  ZipCode  \
# 0           el Baix Guinardó            7       Horta-Guinardó   8025.0
# 1            les Tres Torres            5  Sarrià-Sant Gervasi   8017.0
# 2            les Tres Torres            5  Sarrià-Sant Gervasi   8017.0
# 3                  les Corts            4            Les Corts   8029.0
# 4                  les Corts            4            Les Corts   8034.0
# ...                      ...          ...                  ...      ...
# 1571  la Dreta de l'Eixample            2             Eixample   8010.0
# 1572                  Sarrià            5  Sarrià-Sant Gervasi   8017.0
# 1573               el Carmel            7       Horta-Guinardó   8023.0
# 1574       la Marina de Port            3       Sants-Montjuïc   8038.0
# 1575        el Baix Guinardó            7       Horta-Guinardó   8025.0
#
#                          Service Type  geo_epgs_25831_x  geo_epgs_25831_y  \
# 0     CAP (Primary Healthcare Center)     430258.038349      4.584550e+06
# 1                   Hospital & Clinic     427267.424673      4.583269e+06
# 2                   Hospital & Clinic     427179.337491      4.583445e+06
# 3     CAP (Primary Healthcare Center)     427992.371870      4.582146e+06
# 4                   Hospital & Clinic     427228.518238      4.582406e+06
# ...                               ...               ...               ...
# 1571        Residence for the elderly     431283.357815      4.582468e+06
# 1572        Residence for the elderly     425956.699256      4.583965e+06
# 1573        Residence for the elderly     429053.952844      4.585498e+06
# 1574        Residence for the elderly     427900.987000      4.579122e+06
# 1575        Residence for the elderly     430407.357000      4.584836e+06
#
#        Latitude  Longitude
# 0     41.409469   2.165559
# 1     41.397670   2.129935
# 2     41.399249   2.128860
# 3     41.387618   2.138740
# 4     41.389892   2.129574
# ...         ...        ...
# 1571  41.390806   2.178062
# 1572  41.403816   2.114172
# 1573  41.417910   2.151043
# 1574  41.360380   2.138007
# 1575  41.412063   2.167313
#
# [1571 rows x 14 columns]

# %%
health_df['Service Type'].unique()
# Out:
# array(['CAP (Primary Healthcare Center)', 'Hospital & Clinic',
#        'Day center for the elderly', 'Residence for the elderly',
#        'Pharmacy'], dtype=object)

# %% [markdown]
# ### Asignar District ID and Neighborhood ID para aquellos con valor 0

# %%
# Load Codes & Streets dataset
#roads_codes_file = "roads_codes.csv"
#path_files = "/content/drive/MyDrive/TFG/2. Ejecución/CODE/HealthDatasets/"

# Read CSVs
#roads_codes_df = pd.read_csv(path_files + roads_codes_file, encoding='utf-8')
#display(roads_codes_df)

# %%
health_df.to_csv('cleaned_health.csv')
